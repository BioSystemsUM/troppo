# %%
import sys;sys.path.extend(['E:\\reconstruction', 'E:\\cobamp', 'E:\\reconstruction\\src', 'E:\\cobamp\\src', 'E:/reconstruction'])
import cobra
import cobamp
import pandas as pd
import numpy as np
import pickle
import scipy as sci

# for testing the algorithms
from cobamp.wrappers import MatFormatReader
from cobamp.wrappers import COBRAModelObjectReader
from troppo.methods.reconstruction.imat import IMAT, IMATProperties
from troppo.methods.reconstruction.gimme import GIMME, GIMMEProperties
from troppo.methods.reconstruction.tINIT import tINIT, tINITProperties
from troppo.methods.reconstruction.fastcore import FASTcore, FastcoreProperties
from troppo.utilities.statistics import normalize, z_score

# %% [markdown]
# Here we are going to import the .mat file used for testing in the MATLAB COBRA package and will serve as basis for all the analysis and load some help functions to process the data

# %%
def load_glial_data(path):
    data = pd.read_csv(path, index_col=0)
    normalized_data = normalize(data)
    z = None

    return normalized_data, z

def get_index_core(reactions_ids, data, threshold):
    rx_names = data.index[data['0'] > threshold].tolist()
    index_core = [np.where(reactions_ids == r)[0][0] for r in rx_names]
    return index_core, rx_names

def get_index_values():
    pass

# %%
mat = sci.io.loadmat('C:/Users/biosy/cobratoolbox/test/verifiedTests/analysis/testFASTCORE/FastCoreTest.mat')['ConsistentRecon2']
model_cobra = cobra.io.load_matlab_model('C:/Users/biosy/cobratoolbox/test/verifiedTests/analysis/testFASTCORE/FastCoreTest.mat')
# Out:
# This model seems to have metCharge instead of metCharges field. Will use metCharge for what metCharges represents.
# This model seems to have metHMDB instead of metHMDBID field. Will use metHMDB for what metHMDBID represents.
# Some problem with the model, causing error Invalid MATLAB struct.
# Some problem with the model, causing error Invalid MATLAB struct.
# No defined compartments in model ConsistentRecon2. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x

# %%
len(model_cobra.reactions)
# Out:
# 5317

# %% [markdown]
# Since the .mat file contains all the information needed for the TROPPO package to work (the S matrix, lower and upper bounds), we are going to parse it

# %%
model = MatFormatReader(mat)
S = model.S
lb, ub = model.get_model_bounds(False, True)
rx_names = model.get_reaction_and_metabolite_ids()[0]
idx_objective = rx_names.index('biomass_reaction')
idx_objective
# Out:
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8639__COBAMPGPRDOT__1) or (_26__COBAMPGPRDOT__1) or (_314__COBAMPGPRDOT__2) or (_314__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1591__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2638__COBAMPGPRDOT__1) and (_4036__COBAMPGPRDOT__1) and (_8029__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10993__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6818__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_89874__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_92483__COBAMPGPRDOT__1) or (_3948__COBAMPGPRDOT__2) or (_55293__COBAMPGPRDOT__1) or (_3945__COBAMPGPRDOT__1 and _3939__COBAMPGPRDOT__1) or (_3939__COBAMPGPRDOT__1) or (_160287__COBAMPGPRDOT__1) or (_3945__COBAMPGPRDOT__1) or (_3948__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9123__COBAMPGPRDOT__1) or (_9194__COBAMPGPRDOT__1) or (_6566__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_57835__COBAMPGPRDOT__3) or (_8671__COBAMPGPRDOT__1) or (_57835__COBAMPGPRDOT__2) or (_57835__COBAMPGPRDOT__1) or (_57835__COBAMPGPRDOT__4)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4967__COBAMPGPRDOT__1) and (_1738__COBAMPGPRDOT__1 and _8050__COBAMPGPRDOT__1) and (_1743__COBAMPGPRDOT__1) or (_4967__COBAMPGPRDOT__2) and (_1738__COBAMPGPRDOT__1 and _8050__COBAMPGPRDOT__1) and (_1743__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _89874__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_130__COBAMPGPRDOT__1) or (_127__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_131__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_128__COBAMPGPRDOT__1) or (_137872__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_117247__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_218__COBAMPGPRDOT__1) or (_222__COBAMPGPRDOT__1) or (_220__COBAMPGPRDOT__1) or (_221__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_222__COBAMPGPRDOT__1) or (_221__COBAMPGPRDOT__1) or (_218__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_221__COBAMPGPRDOT__1) or (_218__COBAMPGPRDOT__1) or (_220__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_221__COBAMPGPRDOT__1) or (_222__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3242__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_18__COBAMPGPRDOT__1) or (_18__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2531__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _23498__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_55268__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_51166__COBAMPGPRDOT__1) or (_883__COBAMPGPRDOT__1) or (_51166__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1644__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_222__COBAMPGPRDOT__1) or (_220__COBAMPGPRDOT__1) or (_221__COBAMPGPRDOT__1) or (_218__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10165__COBAMPGPRDOT__1) or (_8604__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_51380__COBAMPGPRDOT__1) or (_2571__COBAMPGPRDOT__1) or (_2572__COBAMPGPRDOT__1) or (_2571__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2805__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2806__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4128__COBAMPGPRDOT__1) or (_4129__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8659__COBAMPGPRDOT__1) or (_8659__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6799__COBAMPGPRDOT__1) or (_6817__COBAMPGPRDOT__3) or (_6799__COBAMPGPRDOT__2) or (_6818__COBAMPGPRDOT__2) or (_6817__COBAMPGPRDOT__2) or (_6818__COBAMPGPRDOT__1) or (_6817__COBAMPGPRDOT__1) or (_6817__COBAMPGPRDOT__4) or (_6818__COBAMPGPRDOT__3) or (_6817__COBAMPGPRDOT__5)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4363__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6822__COBAMPGPRDOT__1) or (_6818__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6573__COBAMPGPRDOT__1) or (_6573__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_316__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6570__COBAMPGPRDOT__1) or (_6571__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2348__COBAMPGPRDOT__5) or (_2348__COBAMPGPRDOT__3) or (_2348__COBAMPGPRDOT__1) or (_2348__COBAMPGPRDOT__6) or (_2352__COBAMPGPRDOT__1) or (_2348__COBAMPGPRDOT__4) or (_2348__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4125__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_53947__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_51146__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _65985__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8639__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_51166__COBAMPGPRDOT__1) or (_51166__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_28__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_223__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_206358__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6529__COBAMPGPRDOT__1) or (_6538__COBAMPGPRDOT__1) or (_6540__COBAMPGPRDOT__1) or (_6539__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_38__COBAMPGPRDOT__1) or (_3032__COBAMPGPRDOT__1) or (_10449__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _39__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3030__COBAMPGPRDOT__1) and (_3032__COBAMPGPRDOT__1) or (_38__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6566__COBAMPGPRDOT__1) or (_9194__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6566__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _30__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_31__COBAMPGPRDOT__5) or (_31__COBAMPGPRDOT__4) or (_31__COBAMPGPRDOT__2 and _32__COBAMPGPRDOT__1) or (_31__COBAMPGPRDOT__4 and _32__COBAMPGPRDOT__1) or (_31__COBAMPGPRDOT__2) or (_32__COBAMPGPRDOT__1 and _31__COBAMPGPRDOT__3) or (_31__COBAMPGPRDOT__1 and _32__COBAMPGPRDOT__1) or (_31__COBAMPGPRDOT__1) or (_31__COBAMPGPRDOT__5 and _32__COBAMPGPRDOT__1) or (_31__COBAMPGPRDOT__3)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _32__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9197__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_55902__COBAMPGPRDOT__1) or (_55902__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_84532__COBAMPGPRDOT__1) or (_79611__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6566__COBAMPGPRDOT__1) or (_9123__COBAMPGPRDOT__1) or (_9194__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5973__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _64841__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _55577__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5238__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9487__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_43__COBAMPGPRDOT__1) or (_43__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6572__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_47__COBAMPGPRDOT__1) or (_47__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54187__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_54187__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_26503__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_140838__COBAMPGPRDOT__1) or (_54__COBAMPGPRDOT__1) or (_51205__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_36__COBAMPGPRDOT__1) or (_34__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_80724__COBAMPGPRDOT__1) or (_36__COBAMPGPRDOT__1) or (_35__COBAMPGPRDOT__1) or (_34__COBAMPGPRDOT__1) or (_84129__COBAMPGPRDOT__1) or (_27034__COBAMPGPRDOT__1) or (_28976__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3712__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_34__COBAMPGPRDOT__1) or (_27034__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _134526__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_51__COBAMPGPRDOT__1) or (_51__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3658__COBAMPGPRDOT__1) or (_48__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_50__COBAMPGPRDOT__1) or (_48__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8309__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_52__COBAMPGPRDOT__1) or (_52__COBAMPGPRDOT__3) or (_52__COBAMPGPRDOT__2) or (_55__COBAMPGPRDOT__1) or (_51205__COBAMPGPRDOT__1) or (_54__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_788__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_65985__COBAMPGPRDOT__1) or (_55902__COBAMPGPRDOT__2) or (_55902__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_55902__COBAMPGPRDOT__1) or (_65985__COBAMPGPRDOT__1) or (_55902__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _84532__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1571__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_112611__COBAMPGPRDOT__1) or (_98__COBAMPGPRDOT__1) or (_97__COBAMPGPRDOT__2) or (_97__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_100__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3177__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_122481__COBAMPGPRDOT__1) or (_203__COBAMPGPRDOT__1) or (_26289__COBAMPGPRDOT__1) or (_26289__COBAMPGPRDOT__2) or (_204__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_205__COBAMPGPRDOT__3) or (_205__COBAMPGPRDOT__1) or (_204__COBAMPGPRDOT__1) or (_204__COBAMPGPRDOT__3) or (_204__COBAMPGPRDOT__2) or (_205__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_26289__COBAMPGPRDOT__1) or (_26289__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_50808__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_26289__COBAMPGPRDOT__2) or (_26289__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_262__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_112__COBAMPGPRDOT__1) or (_55811__COBAMPGPRDOT__1) or (_109__COBAMPGPRDOT__1) or (_112__COBAMPGPRDOT__2) or (_114__COBAMPGPRDOT__1) or (_108__COBAMPGPRDOT__1) or (_113__COBAMPGPRDOT__1) or (_107__COBAMPGPRDOT__1) or (_196883__COBAMPGPRDOT__1) or (_115__COBAMPGPRDOT__1) or (_111__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_132__COBAMPGPRDOT__1) or (_132__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3177__COBAMPGPRDOT__1) or (_2030__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9154__COBAMPGPRDOT__2) or (_9154__COBAMPGPRDOT__1) or (_64078__COBAMPGPRDOT__1) or (_9153__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2030__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_11164__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_952__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _353__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1375__COBAMPGPRDOT__1) or (_1375__COBAMPGPRDOT__3) or (_1375__COBAMPGPRDOT__4) or (_126129__COBAMPGPRDOT__1) or (_1374__COBAMPGPRDOT__1) or (_1375__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1376__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_788__COBAMPGPRDOT__1) or (_788__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9060__COBAMPGPRDOT__1) or (_9061__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_158__COBAMPGPRDOT__1) or (_158__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_159__COBAMPGPRDOT__1) or (_122622__COBAMPGPRDOT__1) or (_122622__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_79369__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__1) or (_11041__COBAMPGPRDOT__1) or (_146712__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__1) or (_93010__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__2) or (_10331__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_79369__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__1) or (_11041__COBAMPGPRDOT__1) or (_146712__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__2) or (_93010__COBAMPGPRDOT__1) or (_10331__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_79369__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__1) or (_11041__COBAMPGPRDOT__1) or (_146712__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__1) or (_93010__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__2) or (_10678__COBAMPGPRDOT__2) or (_10331__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10678__COBAMPGPRDOT__2) or (_11041__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__2) or (_93010__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__1) or (_146712__COBAMPGPRDOT__1) or (_79369__COBAMPGPRDOT__1) or (_10331__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_11041__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__1) or (_93010__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__2) or (_374907__COBAMPGPRDOT__1) or (_146712__COBAMPGPRDOT__1) or (_10331__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__2) or (_79369__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10331__COBAMPGPRDOT__1) or (_11041__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__2) or (_10678__COBAMPGPRDOT__1) or (_79369__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__2) or (_93010__COBAMPGPRDOT__1) or (_146712__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_11041__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__1) or (_93010__COBAMPGPRDOT__1) or (_10331__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__1) or (_146712__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__2) or (_10678__COBAMPGPRDOT__2) or (_79369__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_146712__COBAMPGPRDOT__1) or (_79369__COBAMPGPRDOT__1) or (_10331__COBAMPGPRDOT__1) or (_374907__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__2) or (_374907__COBAMPGPRDOT__2) or (_10678__COBAMPGPRDOT__1) or (_11041__COBAMPGPRDOT__1) or (_93010__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51005__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _79814__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10555__COBAMPGPRDOT__1) or (_137964__COBAMPGPRDOT__1) or (_56895__COBAMPGPRDOT__1) or (_56894__COBAMPGPRDOT__2) or (_56894__COBAMPGPRDOT__1) or (_55326__COBAMPGPRDOT__1) or (_10554__COBAMPGPRDOT__1) or (_129642__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_64902__COBAMPGPRDOT__1) or (_64850__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_189__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_191__COBAMPGPRDOT__1) or (_10768__COBAMPGPRDOT__2) or (_10768__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3074__COBAMPGPRDOT__1) or (_3073__COBAMPGPRDOT__1) or (_3073__COBAMPGPRDOT__1 and _3074__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3073__COBAMPGPRDOT__1) or (_3074__COBAMPGPRDOT__1) or (_3073__COBAMPGPRDOT__1 and _3074__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_471__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10606__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4967__COBAMPGPRDOT__2) and (_1738__COBAMPGPRDOT__1 and _8050__COBAMPGPRDOT__1) and (_1743__COBAMPGPRDOT__1) or (_4967__COBAMPGPRDOT__1) and (_1738__COBAMPGPRDOT__1 and _8050__COBAMPGPRDOT__1) and (_1743__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8402__COBAMPGPRDOT__1) or (_1468__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_64849__COBAMPGPRDOT__1) or (_64849__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1645__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1109__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6718__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6510__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6509__COBAMPGPRDOT__1) or (_6510__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_56301__COBAMPGPRDOT__1) and (_6520__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6520__COBAMPGPRDOT__1) and (_56301__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_11212__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_212__COBAMPGPRDOT__1) or (_23464__COBAMPGPRDOT__1) or (_211__COBAMPGPRDOT__2) or (_211__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_153201__COBAMPGPRDOT__1 or _206358__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_54407__COBAMPGPRDOT__1) or (_6542__COBAMPGPRDOT__1) or (_11254__COBAMPGPRDOT__1) or (_6541__COBAMPGPRDOT__1) or (_81539__COBAMPGPRDOT__1) or (_55089__COBAMPGPRDOT__1) or (_84889__COBAMPGPRDOT__1) or ((_340024__COBAMPGPRDOT__1) and (_57393__COBAMPGPRDOT__1 or _59272__COBAMPGPRDOT__1))
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2875__COBAMPGPRDOT__1) or (_84706__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_92745__COBAMPGPRDOT__1) or (_10991__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_124__COBAMPGPRDOT__1) or (_131__COBAMPGPRDOT__1) or (_130__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1) or (_128__COBAMPGPRDOT__1) or (_127__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1) or (_137872__COBAMPGPRDOT__1) or (_284273__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1) or (_284273__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_127__COBAMPGPRDOT__1) or (_284273__COBAMPGPRDOT__2) or (_125__COBAMPGPRDOT__1) or (_128__COBAMPGPRDOT__1) or (_131__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_124__COBAMPGPRDOT__1) or (_130__COBAMPGPRDOT__1) or (_137872__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_284273__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_130__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_128__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1) or (_284273__COBAMPGPRDOT__2) or (_137872__COBAMPGPRDOT__1) or (_127__COBAMPGPRDOT__1) or (_124__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_284273__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1) or (_131__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_126__COBAMPGPRDOT__1) or (_137872__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_127__COBAMPGPRDOT__1) or (_130__COBAMPGPRDOT__1) or (_284273__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_128__COBAMPGPRDOT__1) or (_124__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1) or (_284273__COBAMPGPRDOT__2) or (_131__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1) or (_137872__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or (_127__COBAMPGPRDOT__1) or (_130__COBAMPGPRDOT__1) or (_284273__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1) or (_124__COBAMPGPRDOT__1) or (_128__COBAMPGPRDOT__1) or (_125__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1) or (_284273__COBAMPGPRDOT__2) or (_131__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10327__COBAMPGPRDOT__1) or (_10327__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_224__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_218__COBAMPGPRDOT__1) or (_501__COBAMPGPRDOT__1) or (_8854__COBAMPGPRDOT__2) or (_224__COBAMPGPRDOT__1) or (_222__COBAMPGPRDOT__1) or (_8854__COBAMPGPRDOT__1) or (_221__COBAMPGPRDOT__1) or (_216__COBAMPGPRDOT__1) or (_8854__COBAMPGPRDOT__3) or (_223__COBAMPGPRDOT__1) or (_220__COBAMPGPRDOT__1) or (_219__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_219__COBAMPGPRDOT__1) or (_217__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_223__COBAMPGPRDOT__1) or (_221__COBAMPGPRDOT__1) or (_218__COBAMPGPRDOT__1) or (_8854__COBAMPGPRDOT__1) or (_8854__COBAMPGPRDOT__3) or (_222__COBAMPGPRDOT__1) or (_8854__COBAMPGPRDOT__2) or (_224__COBAMPGPRDOT__1) or (_219__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_240__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10327__COBAMPGPRDOT__2) or (_8574__COBAMPGPRDOT__1) or (_10327__COBAMPGPRDOT__1) or (_231__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_23600__COBAMPGPRDOT__1) or (_23600__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_23600__COBAMPGPRDOT__2) or (_23600__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10020__COBAMPGPRDOT__1) or (_55577__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_115286__COBAMPGPRDOT__3) or (_115286__COBAMPGPRDOT__2) or (_115286__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_271__COBAMPGPRDOT__2) or (_270__COBAMPGPRDOT__1) or (_271__COBAMPGPRDOT__1) or (_272__COBAMPGPRDOT__1) or (_271__COBAMPGPRDOT__3)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _290__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6520__COBAMPGPRDOT__1) or (_280__COBAMPGPRDOT__1) or (_278__COBAMPGPRDOT__1) or (_276__COBAMPGPRDOT__1) or (_277__COBAMPGPRDOT__1) or (_6519__COBAMPGPRDOT__1 and _11136__COBAMPGPRDOT__1) or (_276__COBAMPGPRDOT__2) or (_279__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1375__COBAMPGPRDOT__3) or (_1374__COBAMPGPRDOT__1) or (_1375__COBAMPGPRDOT__2) or (_1375__COBAMPGPRDOT__4) or (_1375__COBAMPGPRDOT__1) or (_126129__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10998__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _113451__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9057__COBAMPGPRDOT__1 and _6520__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_383__COBAMPGPRDOT__1) or (_384__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_384__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_435__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_445__COBAMPGPRDOT__1) or (_445__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_11254__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6541__COBAMPGPRDOT__1) or (_6542__COBAMPGPRDOT__1) or (_55089__COBAMPGPRDOT__1) or (_84889__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_83884__COBAMPGPRDOT__1) or (_10166__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_410__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_427__COBAMPGPRDOT__1) or (_427__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9962__COBAMPGPRDOT__2) or (_9963__COBAMPGPRDOT__1) or (_9962__COBAMPGPRDOT__1) or (_9963__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_80150__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_440__COBAMPGPRDOT__1) or (_440__COBAMPGPRDOT__3) or (_440__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_81539__COBAMPGPRDOT__1) or (_11254__COBAMPGPRDOT__1) or (_54407__COBAMPGPRDOT__1) or (_55089__COBAMPGPRDOT__1) or ((_340024__COBAMPGPRDOT__1) and (_57393__COBAMPGPRDOT__1 or _59272__COBAMPGPRDOT__1))
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2571__COBAMPGPRDOT__1) or (_2571__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_790__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6511__COBAMPGPRDOT__1) or (_6505__COBAMPGPRDOT__1) or (_6507__COBAMPGPRDOT__1) or (_6506__COBAMPGPRDOT__1) or (_6512__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8604__COBAMPGPRDOT__1) or (_10165__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2805__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2806__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:116: UserWarning: Will not normalize rules with more than 20 average tokens per gene
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_954__COBAMPGPRDOT__1) or (_954__COBAMPGPRDOT__2) or (_953__COBAMPGPRDOT__1) or (_956__COBAMPGPRDOT__1) or (_955__COBAMPGPRDOT__1) or (_957__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_954__COBAMPGPRDOT__2) or (_954__COBAMPGPRDOT__1) or (_953__COBAMPGPRDOT__1) or (_956__COBAMPGPRDOT__1) or (_955__COBAMPGPRDOT__1) or (_957__COBAMPGPRDOT__1) or (_377841__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_291__COBAMPGPRDOT__1) or (_293__COBAMPGPRDOT__1) or (_292__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_949__COBAMPGPRDOT__1) and (_29881__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4126__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8706__COBAMPGPRDOT__4) or (_8706__COBAMPGPRDOT__1) or (_8706__COBAMPGPRDOT__3) or (_8706__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8705__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10317__COBAMPGPRDOT__4) or (_10317__COBAMPGPRDOT__1) or (_10317__COBAMPGPRDOT__3) or (_10317__COBAMPGPRDOT__2) or (_10317__COBAMPGPRDOT__5)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10678__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10678__COBAMPGPRDOT__1) or (_10678__COBAMPGPRDOT__2)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10331__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_84002__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_570__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3141__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_140679__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8854__COBAMPGPRDOT__2) or (_501__COBAMPGPRDOT__1) or (_216__COBAMPGPRDOT__1) or (_224__COBAMPGPRDOT__1) or (_8854__COBAMPGPRDOT__3) or (_223__COBAMPGPRDOT__1) or (_8854__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_53630__COBAMPGPRDOT__1)
# ...
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_217__COBAMPGPRDOT__1) or (_219__COBAMPGPRDOT__1) or (_501__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2880__COBAMPGPRDOT__1) or (_257202__COBAMPGPRDOT__1) or (_2882__COBAMPGPRDOT__1) or (_2878__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _284111__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9152__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9497__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_115584__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6574__COBAMPGPRDOT__1) or (_6575__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_142680__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6534__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3293__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1622__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10005__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1374__COBAMPGPRDOT__1 or _1375__COBAMPGPRDOT__1 or _126129__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_215__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1376__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_215__COBAMPGPRDOT__1 and _225__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_376497__COBAMPGPRDOT__1 or _11001__COBAMPGPRDOT__1 or _11000__COBAMPGPRDOT__1 or _10999__COBAMPGPRDOT__1 or _10998__COBAMPGPRDOT__1 or _28965__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_23205__COBAMPGPRDOT__1 or _81616__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_51__COBAMPGPRDOT__1) or (_34__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1892__COBAMPGPRDOT__1 and _3033__COBAMPGPRDOT__1 and _10449__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1962__COBAMPGPRDOT__1 and _3295__COBAMPGPRDOT__1 and _30__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1632__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1962__COBAMPGPRDOT__1 or _10455__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1666__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _26063__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_34__COBAMPGPRDOT__1 and _1892__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_34__COBAMPGPRDOT__1 and _1892__COBAMPGPRDOT__1 and _3033__COBAMPGPRDOT__1 and _10449__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_51__COBAMPGPRDOT__1 and _1962__COBAMPGPRDOT__1 and _3295__COBAMPGPRDOT__1 and _30__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_37__COBAMPGPRDOT__1 and _3030__COBAMPGPRDOT__1 and _3032__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_37__COBAMPGPRDOT__1 and _3030__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_26061__COBAMPGPRDOT__1 and _224__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _37__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3030__COBAMPGPRDOT__1 and _3032__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51703__COBAMPGPRDOT__1
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8529__COBAMPGPRDOT__1 and _4051__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_35__COBAMPGPRDOT__1 and _1892__COBAMPGPRDOT__1 and _3033__COBAMPGPRDOT__1 and _10449__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_128__COBAMPGPRDOT__1 and _224__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_122970__COBAMPGPRDOT__1 or _10005__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8140__COBAMPGPRDOT__1 and _6520__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_54716__COBAMPGPRDOT__1 and _57393__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6564__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9056__COBAMPGPRDOT__1 or _9057__COBAMPGPRDOT__1) and (_6520__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9963__COBAMPGPRDOT__1 or _9962__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_23428__COBAMPGPRDOT__1 and _6520__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2694__COBAMPGPRDOT__1 and _8029__COBAMPGPRDOT__1 and _81693__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_11136__COBAMPGPRDOT__1 and _6519__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_113235__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1800__COBAMPGPRDOT__1 or _55748__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_5184__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1200__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6541__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2168__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_51056__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10999__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9390__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_79581__COBAMPGPRDOT__1 or _55065__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_19__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_1594__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _57835__COBAMPGPRDOT__3 or _8671__COBAMPGPRDOT__1 or _57835__COBAMPGPRDOT__2 or _57835__COBAMPGPRDOT__1 or _57835__COBAMPGPRDOT__4
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6509__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_64078__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_8435__COBAMPGPRDOT__1) or (_6646__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3988__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4597__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_5167__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2110__COBAMPGPRDOT__1) and (_2109__COBAMPGPRDOT__1) and (_2108__COBAMPGPRDOT__1) or (_2109__COBAMPGPRDOT__2) and (_2108__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4891__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_30061__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_9843__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_52__COBAMPGPRDOT__1) or (_52__COBAMPGPRDOT__3) or (_52__COBAMPGPRDOT__2) or (_248__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_2539__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6514__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3156__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4598__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4524__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_29920__COBAMPGPRDOT__1) or (_65263__COBAMPGPRDOT__1) or (_5831__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_25796__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_113235__COBAMPGPRDOT__1) or (_28982__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_6580__COBAMPGPRDOT__1)
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\cobamp-0.2.0-py3.7.egg\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_10864__COBAMPGPRDOT__1)
# 4686

# %% [markdown]
# Since the algorithms need expression data to begin the pruning of the original model, we are going to import data from glial cells (complete the rest of the story here).
# We are also going to make different inputs accordingly to the needs of the algorithms that are goint to be tested.

# %%
original_data,_ = load_glial_data('grade2_calls.csv') # import of the omics data before/after preprocessing
core, names_core = get_index_core(np.array(model.r_ids), original_data, 0.9) # this is for the FASTCORE algorithm
reactions_scores = original_data.fillna(0) # this is the input for tINIT; reactions with NaN for score were replaced with the score of 0
gimme_data = original_data.fillna(-1) #GIMME; reactions without expression values are not considered for the algorithm
iMAT_data = original_data.fillna((0.2+0.5)/2)#iMAT; fillna is used with the mean of both thresholds
# CORDA data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38772\1239373644.py in <module>
#       3 reactions_scores = original_data.fillna(0) # this is the input for tINIT; reactions with NaN for score were replaced with the score of 0
#       4 gimme_data = original_data.fillna(-1) #GIMME; reactions without expression values are not considered for the algorithm
# ----> 5 iMAT_data = original_data.fillna((0.2+0.5)/2)#iMAT; fillna is used with the mean of both thresholds
#       6 # CORDA data
#
# ~\AppData\Local\Temp\ipykernel_38772\1239373644.py in <module>
#       3 reactions_scores = original_data.fillna(0) # this is the input for tINIT; reactions with NaN for score were replaced with the score of 0
#       4 gimme_data = original_data.fillna(-1) #GIMME; reactions without expression values are not considered for the algorithm
# ----> 5 iMAT_data = original_data.fillna((0.2+0.5)/2)#iMAT; fillna is used with the mean of both thresholds
#       6 # CORDA data
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.SafeCallWrapper.__call__()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.do_wait_suspend()
#
# C:\Program Files\JetBrains\PyCharm 2022.1.3\plugins\python\helpers\pydev\pydevd.py in do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1158
#    1159         with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1160             self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#    1161
#    1162     def _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread):
#
# C:\Program Files\JetBrains\PyCharm 2022.1.3\plugins\python\helpers\pydev\pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1173
#    1174                 self.process_internal_commands()
# -> 1175                 time.sleep(0.01)
#    1176
#    1177         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %% [markdown]
# From here, we are going to test the already implement algorithms for tissue reconstruction.

# %% [markdown]
# First, we are going to be testing the FASTcore algorithm

# %%
fastcore = FASTcore(S, lb, ub, FastcoreProperties(solver = 'CPLEX', core=core))
tissue_reactions = fastcore.fastcore()
# Out:
# J size209
# [  12   43   64  155  156  185  204  244  253  254  255  256  257  258
#   259  260  261  262  263  264  265  266  267  268  269  270  278  279
#   287  315  317  354  402  405  483  487  488  492  495  498  502  543
#   592  642  717  784  942  978  982 1441 1442 1443 1444 1496 1497 1498
#  1499 1500 1701 1724 1815 1895 1935 1936 1980 2018 2022 2026 2059 2080
#  2081 2114 2118 2122 2126 2129 2157 2162 2169 2185 2218 2219 2224 2257
#  2271 2273 2274 2275 2276 2277 2278 2279 2280 2281 2282 2283 2284 2285
#  2286 2287 2288 2289 2290 2291 2292 2293 2294 2295 2296 2297 2298 2299
#  2300 2301 2302 2303 2304 2305 2306 2307 2308 2309 2310 2311 2312 2313
#  2314 2315 2316 2317 2318 2319 2320 2321 2323 2418 2420 2421 2424 2426
#  2427 2428 2429 2431 2433 2434 2435 2436 2482 2483 2553 2561 2579 2603
#  2613 2619 2621 2626 2630 2644 2645 2712 2718 2728 2731 2732 2736 2755
#  2893 2913 2931 2934 2935 2938 2970 2982 3046 3049 3077 3160 3197 3234
#  3242 3251 3259 3264 3267 3272 3299 3347 3356 3384 3486 3488 3490 4425
#  4432 4433 4434 4437 4438 4457 4501 4576 4577 4597 4685 5221 5256]
# before LP7
# LP7
# F:\Conda\envs\reconstruction\lib\site-packages\scipy\sparse\compressed.py:746 SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
# -0.02089999999999993
# done LP7
# LP9
# 70871.93398691867
# done LP9
# 20 1099
# before LP7
# LP7
# -0.0019000000000000006
# done LP7
# LP9
# 625.0
# Warning, Solution is not optimal
# done LP9
# 20 1181
# before LP7
# LP7
# 0.0
# done LP7
# 1 1181
# Flipped
# before LP7
# LP7
# -0.0001
# done LP7
# LP9
# 10.0
# done LP9
# 1 1183
# before LP7
# LP7
# -0.0001
# done LP7
# LP9
# 0.0
# Warning, Solution is not optimal
# done LP9
# 1 1183
# Flipped
# before LP7
# LP7
# 0.0
# done LP7
# 1 1183
# Error: Global network is not consistent
# [46]

# %%
model_fastcore = model_cobra.copy() # this is done since it alters the original model_cobra; this way is to guarantee that a new model is changed instead of the original model
r_ids = [r.id for r in model_fastcore.reactions]
model_fastcore.remove_reactions([r_ids[r] for r in tissue_reactions],True) # this is to get the ids of the reactions to be removed in the model; True is to remove the pending genes/metabolites that with the removal of the reaction can no longer be connected in the network
# Out:
# Read LP format model from file C:\Users\Jorge\AppData\Local\Temp\tmpo6p3g58w.lp
# Reading time = 0.05 seconds
# : 2960 rows, 10634 columns, 42212 nonzeros

# %% [markdown]
# With the FASTcore algorithm, we obtained a model with 4134 reactions, 1345 genes and 2458 metabolites, not capable of producing biomass.

# %%
print('Genes: ' + str(len(model_fastcore.genes)))
print('Metabolites: ' + str(len(model_fastcore.metabolites)))
print('Reactions: ' + str(len(model_fastcore.reactions)))
print(model_fastcore.objective._get_expression())
print(model_fastcore.optimize())
# Out:
# Genes: 1345
# Metabolites: 2458
# Reactions: 4134
# 1.0*biomass_reaction - 1.0*biomass_reaction_reverse_32a6c
# <Solution 0.000 at 0x181c3284780>

# %% [markdown]
# Now we're going to test the tINIT algorithm. For this case, as an input we are going to only provide reactions scores. The other properties of the algorithm are set to default (including the solver).

# %%
tinit = tINIT(S, np.array(lb), np.array(ub),
          tINITProperties(reactions_scores=list(reactions_scores['0']), present_metabolites=[], essential_reactions=[],
                          production_weight=0.5, allow_excretion=False, no_reverse_loops=False, solver = "GUROBI"))
reactions_to_remove_from_the_model = tinit.run_tINIT()
# Out:
# Changed value of parameter OutputFlag to 1
#    Prev: 0  Min: 0  Max: 1  Default: 1
#
# Warning: excessive time spent in model updates.
# Consider calling update less frequently.
#
# Optimize a model with 10692 rows, 26156 columns and 54200 nonzeros
# Variable types: 18424 continuous, 7732 integer (7732 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   Objective range  [1e-01, 1e+00]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1112 rows and 2151 columns
# Presolve time: 0.23s
# Presolved: 9580 rows, 24005 columns, 50512 nonzeros
# Variable types: 16551 continuous, 7454 integer (7452 binary)
# Presolve removed 6860 rows and 16174 columns
# Presolved: 2720 rows, 7831 columns, 23386 nonzeros
#
# Extra 3 simplex iterations after uncrush
#
# Root relaxation: objective -1.055183e+03, 16336 iterations, 0.86 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -1055.1826    0  987          - -1055.1826      -     -    2s
#      0     0 -1046.3123    0  683          - -1046.3123      -     -    3s
#      0     0 -1046.3123    0  750          - -1046.3123      -     -    4s
#      0     0 -1046.3112    0  541          - -1046.3112      -     -    4s
#      0     0 -1046.3112    0  534          - -1046.3112      -     -    4s
#      0     0 -1046.2123    0  520          - -1046.2123      -     -    5s
#      0     0 -1046.2123    0  517          - -1046.2123      -     -    5s
#      0     0 -1046.2123    0  521          - -1046.2123      -     -    5s
#      0     0 -1046.2123    0  510          - -1046.2123      -     -    5s
#      0     0 -1046.2123    0  308          - -1046.2123      -     -    7s
#      0     0 -1046.2123    0  303          - -1046.2123      -     -    8s
#      0     0 -1046.2123    0  291          - -1046.2123      -     -    9s
#      0     0 -1046.2123    0  284          - -1046.2123      -     -   10s
#      0     2 -1046.2123    0  278          - -1046.2123      -     -   13s
#     19    19 -1002.0587    5  356          - -1045.7917      -   283   15s
#     90    86 -1043.5587   19  299          - -1045.7917      -   256   20s
#    145   142 -1043.5587   32  361          - -1045.7917      -   274   25s
#    232   227 -1043.5587   51  502          - -1045.7917      -   297   31s
#    288   285 -1043.5587   71  518          - -1045.7917      -   290   35s
#    470   466 -1043.5587  126  555          - -1045.7917      -   266   44s
#    584   581 -1043.5587  170  574          - -1045.7917      -   253   49s
#    700   693 -1043.5587  212  546          - -1045.7917      -   248   54s
#    831   825 -1043.5587  263  550          - -1045.7917      -   236   58s
#    954   946 -1043.5587  300  559          - -1045.7917      -   229   63s
#   1106  1098 -1043.5587  347  522          - -1045.7917      -   219   67s
#   1252  1244 -1043.5587  382  554          - -1045.7917      -   213   72s
#   1505  1493 -1042.5814  487  472          - -1045.7917      -   194   76s
#   1798  1788 -1041.5814  633  367          - -1045.7917      -   174   80s
#   2092  2073 -1040.5814  791  264          - -1045.7917      -   157   85s
# * 2551  1559            1083    -1041.081439 -1045.7917  0.45%   137   88s
#   2640  1599     cutoff   14      -1041.0814 -1045.7917  0.45%   140   92s
#   2857  1800 -1045.7917   30  418 -1041.0814 -1045.7917  0.45%   138   96s
# H 2993  1131                    -1043.558712 -1045.7917  0.21%   136   96s
#   3135  1370 -1045.7917   41  452 -1043.5587 -1045.7917  0.21%   132  100s
# * 3406   809            1082    -1045.720931 -1045.7917  0.01%   125  100s
#   3439   829 -1045.7917  198  496 -1045.7209 -1045.7917  0.01%   127  105s
#   3442   831 -1045.7917  506  108 -1045.7209 -1045.7917  0.01%   127  111s
#   3446   834 -1045.7639  619   42 -1045.7209 -1045.7917  0.01%   127  115s
#   3452   838 -1045.7917  181   28 -1045.7209 -1045.7917  0.01%   127  120s
#   3460   843 -1045.7917  477   11 -1045.7209 -1045.7917  0.01%   126  125s
#   3466   852 -1045.7917   16   85 -1045.7209 -1045.7917  0.01%   137  130s
#   3491   866 -1045.7917   19  103 -1045.7209 -1045.7917  0.01%   136  136s
#   3513   880 -1045.7917   23  152 -1045.7209 -1045.7917  0.01%   137  142s
#   3532   891 -1045.7917   25    7 -1045.7209 -1045.7917  0.01%   139  148s
#   3631   932 -1045.7917   48    3 -1045.7209 -1045.7917  0.01%   139  154s
# * 3651   751              58    -1045.791667 -1045.7917  0.00%   138  154s
#
# Cutting planes:
#   Gomory: 268
#   Cover: 124
#   Implied bound: 335
#   Clique: 54
#   MIR: 19
#   Flow cover: 160
#   Zero half: 1
#   Network: 1
#
# Explored 3944 nodes (547680 simplex iterations) in 154.26 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: -1045.79 -1045.72 -1045.72 ... -1041.08
#
# Optimal solution found (tolerance 1.00e-09)
# Best objective -1.045791666667e+03, best bound -1.045791666667e+03, gap 0.0000%
# -1045.7916666666742

# %%
reactions_to_remove_from_the_model = np.unique(np.int_(reactions_to_remove_from_the_model)).tolist()
model_tINIT = model_cobra.copy() # this is done since it alters the original model_cobra; this way is to guarantee that a new model is changed instead of the original model
r_ids = [r.id for r in model_tINIT.reactions]
to_remove_ids = [r_ids[r] for r in reactions_to_remove_from_the_model]
model_tINIT.remove_reactions(to_remove_ids,True) # this is to get the ids of the reactions to be removed in the model; True is to remove the pending genes/metabolites that with the removal of the reaction can no longer be connected in the network
# Out:
# Read LP format model from file C:\Users\Jorge\AppData\Local\Temp\tmp_7u2lh6i.lp
# Reading time = 0.05 seconds
# : 2960 rows, 10634 columns, 42212 nonzeros

# %%
print('Genes: ' + str(len(model_tINIT.genes)))
print('Metabolites: ' + str(len(model_tINIT.metabolites)))
print('Reactions: ' + str(len(model_tINIT.reactions)))
print(model_tINIT.objective._get_expression())
print(model_tINIT.optimize())
# Out:
# Genes: 1139
# Metabolites: 2185
# Reactions: 1915
# 0
# <Solution 0.000 at 0x21c81340d68>

# %% [markdown]
# With the tINIT algorithm, we obtained X specific reactions for the data provided, generatung a model with X reactions, Y genes and Z metabolites, capable (or not) of producing biomass.

# %% [markdown]
# For the CORDA algorithm, we needed four different types of sets of reactions (input_data3, input_data3_1, input_data3_2, input_data3_3).

# %%
# code for the CORDA test

# %% [markdown]
# Regarding the CORDA reconstructed model, it has X reactions, Y genes and Z metabolites, and also capable(or not) of producing biomass

# %% [markdown]
# For GIMME, we apply a threshold to the expression values originally from the expression dataset.

# %%
# code for the GIMME test
idx_objective = rx_names.index('biomass_reaction')
properties = GIMMEProperties(
	exp_vector=np.array(gimme_data['0']),
    obj_frac=0.8,
    objectives= [{idx_objective:1}],
    preprocess=True,
    flux_threshold=0.8
)
algorithm = GIMME(S, lb.astype(float), ub.astype(float), properties)
model_GIMME = algorithm.run()
# Out:
# '__init__'  2058.51 ms
# '__init__'  2857.57 ms
# '__init__'  3389.56 ms

# %%
model_GIMME_final = model_cobra.copy() # this is done since it alters the original model_cobra; this way is to guarantee that a new model is changed instead of the original model
r_ids = [r.id for r in model_GIMME_final.reactions]
to_remove_ids = [r_ids[r] for r in np.where(model_GIMME==0)[0]]
model_GIMME_final.remove_reactions(to_remove_ids,True) # this is to get the ids of the reactions to be removed in the model; True is to remove the pending genes/metabolites that with the removal of the reaction can no longer be connected in the network
# Out:
# Read LP format model from file C:\Users\Jorge\AppData\Local\Temp\tmpew68h5co.lp
# Reading time = 0.05 seconds
# : 2960 rows, 10634 columns, 42212 nonzeros

# %%
print('1\'s: ' + str(len(np.where(model_GIMME==1)[0])))
print('2\'s: ' + str(len(np.where(model_GIMME==2)[0])))
print('Genes: ' + str(len(model_GIMME_final.genes)))
print('Metabolites: ' + str(len(model_GIMME_final.metabolites)))
print('Reactions: ' + str(len(model_GIMME_final.reactions)))
print(model_GIMME_final.objective._get_expression())
print(model_GIMME_final.optimize())
# Out:
# 1's: 5154
# 2's: 6
# Genes: 1895
# Metabolites: 2951
# Reactions: 5160
# 1.0*biomass_reaction - 1.0*biomass_reaction_reverse_32a6c
# <Solution 3.198 at 0x1fa08044f98>

# %% [markdown]
# With GIMME we are capable of obtaining both a flux distribution and a reconstructed model.
# For the flux distribution, ...
# As for the model, it is comprised with X reactions, Y genes and Z metabolites, capable (or not) of producing biomass.

# %% [markdown]
# For the iMAT algorihtm, we have to provide two different thresholds (...).

# %%
# code for the iMAT test
properties = IMATProperties(
    exp_vector = np.array(iMAT_data['0'].tolist()), # check what input to here
    exp_thresholds=(0.2,0.5)
)

method = IMAT(S, lb.astype(float), ub.astype(float), properties)
to_remove = np.setdiff1d(list(range(S.shape[1])), method.run())

# %%
model_iMAT = model_cobra.copy() # this is done since it alters the original model_cobra; this way is to guarantee that a new model is changed instead of the original model
r_ids = [r.id for r in model_iMAT.reactions]
to_remove_ids = [r_ids[r] for r in to_remove]
model_iMAT.remove_reactions(to_remove_ids,True) # this is to get the ids of the reactions to be removed in the model; True is to remove the pending genes/metabolites that with the removal of the reaction can no longer be connected in the network
# Out:
# Read LP format model from file C:\Users\Jorge\AppData\Local\Temp\tmpjw601stq.lp
# Reading time = 0.05 seconds
# : 2960 rows, 10634 columns, 42212 nonzeros

# %%
print('Genes: ' + str(len(model_iMAT.genes)))
print('Metabolites: ' + str(len(model_iMAT.metabolites)))
print('Reactions: ' + str(len(model_iMAT.reactions)))
print(model_iMAT.objective._get_expression())
print(model_iMAT.optimize())
# Out:
# Genes: 1253
# Metabolites: 1829
# Reactions: 2569
# 0
# <Solution 0.000 at 0x1fa2238c710>

# %% [markdown]
# With iMAT, we obtained a reconstructed model with X reactions, Y genes and Z metabolites, and capable(or not) of producing biomass.

# %% [markdown]
# The following table represents the final summary of the tested algorithms.

# %%
# code for the table (do this with pandas or markdown)

# %% [markdown]
# Since we are implementing the algoirhtms based on the code of COBRA toolbox, the next table is a comparison of speed of execution. The computer used was running Windows 10 version, with a processor i7-3630QM CPU @ 2.40 GHz (8 CPU), 16GB of RAM and Python 3.5.6.

# %%
# code for the table with the benchmarks

# %% [markdown]
# With this, we can see that the implementation in Pyhton is ...
# (mostly should run faster when compared to MATLAB)

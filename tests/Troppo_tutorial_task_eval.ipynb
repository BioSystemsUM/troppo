# %% [markdown]
# # Task performance evaluation

# %% [markdown]
# *Troppo* includes a module that allows for the evaluation of metabolic tasks performance.
# The class responsible for this is called `TaskEvaluator`.
# This class is a wrapper around a model that allows the evaluation of tasks on the model. It can be used to evaluate a single task, or to evaluate a batch of tasks on a batch of models.
#
# To initialize a `TaskEvaluator` object, you need to pass a model object and the tasks to evaluate.
# The tasks should be instances of the `Task` class, which is a simple data structure that contains the following fields:
#
#
# - `reaction_dict`: a dictionary with the reaction identifiers as keys and a dictionary with the metabolites and their respective stoichiometry as values. (eg. rxd = {'r1':({'m1':-1, 'm2':2}, (lb, ub)), ... })
# - `inflow_dict`: a dictionary with the metabolite identifiers as keys and the inflow rate as values. (eg. inflow = {'m1':(1, 1), ... })
# - `outflow_dict`: a dictionary with the metabolite identifiers as keys and the outflow rate as values. (eg. outflow = {'m5':(5, 5), ... })

# %% [markdown]
# ### Imports

# %%
from troppo.tasks.core import TaskEvaluator
from troppo.tasks.task_io import JSONTaskIO
import pandas as pd
from json import JSONEncoder, JSONDecoder
from cobamp.utilities.parallel import batch_run
from cobra.io import read_sbml_model

from numpy import log
import re

# %% [markdown]
# ### Initial setup

# %%
#load the model
task_model = read_sbml_model('data/Recon3D_301_consistent.xml')
task_model
# Out:
# 'M_10fthf5glu[c]' is not a valid SBML 'SId'.
# 'M_10fthf5glu[l]' is not a valid SBML 'SId'.
# 'M_10fthf5glu[m]' is not a valid SBML 'SId'.
# 'M_10fthf6glu[c]' is not a valid SBML 'SId'.
# 'M_10fthf6glu[l]' is not a valid SBML 'SId'.
# 'M_10fthf6glu[m]' is not a valid SBML 'SId'.
# 'M_10fthf7glu[c]' is not a valid SBML 'SId'.
# 'M_10fthf7glu[l]' is not a valid SBML 'SId'.
# 'M_10fthf7glu[m]' is not a valid SBML 'SId'.
# 'M_10fthf[c]' is not a valid SBML 'SId'.
# 'M_10fthf[l]' is not a valid SBML 'SId'.
# 'M_10fthf[m]' is not a valid SBML 'SId'.
# 'M_11docrtsl[c]' is not a valid SBML 'SId'.
# 'M_11docrtsl[m]' is not a valid SBML 'SId'.
# 'M_11docrtsl[r]' is not a valid SBML 'SId'.
# 'M_11docrtstrn[c]' is not a valid SBML 'SId'.
# 'M_11docrtstrn[m]' is not a valid SBML 'SId'.
# 'M_11docrtstrn[r]' is not a valid SBML 'SId'.
# 'M_13dampp[c]' is not a valid SBML 'SId'.
# 'M_h2o[c]' is not a valid SBML 'SId'.
# 'M_o2[c]' is not a valid SBML 'SId'.
# 'M_bamppald[c]' is not a valid SBML 'SId'.
# 'M_h2o2[c]' is not a valid SBML 'SId'.
# 'M_nh4[c]' is not a valid SBML 'SId'.
# 'M_h2o[m]' is not a valid SBML 'SId'.
# 'M_o2[m]' is not a valid SBML 'SId'.
# 'M_2425dhvitd2[m]' is not a valid SBML 'SId'.
# 'M_h[m]' is not a valid SBML 'SId'.
# 'M_nadph[m]' is not a valid SBML 'SId'.
# 'M_nadp[m]' is not a valid SBML 'SId'.
# 'M_2425dhvitd3[m]' is not a valid SBML 'SId'.
# 'M_1a25dhvitd2[m]' is not a valid SBML 'SId'.
# 'M_1a25dhvitd3[m]' is not a valid SBML 'SId'.
# 'M_h[c]' is not a valid SBML 'SId'.
# 'M_1mncam[c]' is not a valid SBML 'SId'.
# 'M_1mncam[e]' is not a valid SBML 'SId'.
# 'M_atp[c]' is not a valid SBML 'SId'.
# 'M_adp[c]' is not a valid SBML 'SId'.
# 'M_pi[c]' is not a valid SBML 'SId'.
# 'M_h[x]' is not a valid SBML 'SId'.
# 'M_1pipdn2c[x]' is not a valid SBML 'SId'.
# 'M_nadh[x]' is not a valid SBML 'SId'.
# 'M_Lpipecol[x]' is not a valid SBML 'SId'.
# 'M_nad[x]' is not a valid SBML 'SId'.
# 'M_2425dhvitd2[c]' is not a valid SBML 'SId'.
# 'M_2425dhvitd2[e]' is not a valid SBML 'SId'.
# 'M_2425dhvitd3[c]' is not a valid SBML 'SId'.
# 'M_2425dhvitd3[e]' is not a valid SBML 'SId'.
# 'M_25hvitd2[m]' is not a valid SBML 'SId'.
# 'M_25hvitd3[m]' is not a valid SBML 'SId'.
# 'M_24nph[e]' is not a valid SBML 'SId'.
# 'M_24nph[c]' is not a valid SBML 'SId'.
# 'M_25hvitd2[c]' is not a valid SBML 'SId'.
# 'M_25hvitd2[e]' is not a valid SBML 'SId'.
# 'M_25hvitd3[c]' is not a valid SBML 'SId'.
# 'M_25hvitd3[e]' is not a valid SBML 'SId'.
# 'M_2amac[c]' is not a valid SBML 'SId'.
# 'M_pyr[c]' is not a valid SBML 'SId'.
# 'M_nadph[c]' is not a valid SBML 'SId'.
# 'M_nadp[c]' is not a valid SBML 'SId'.
# 'M_paps[c]' is not a valid SBML 'SId'.
# 'M_Lcyst[c]' is not a valid SBML 'SId'.
# 'M_pap[c]' is not a valid SBML 'SId'.
# 'M_L2aadp[c]' is not a valid SBML 'SId'.
# 'M_L2aadp[m]' is not a valid SBML 'SId'.
# 'M_akg[m]' is not a valid SBML 'SId'.
# 'M_akg[c]' is not a valid SBML 'SId'.
# 'M_2dr1p[c]' is not a valid SBML 'SId'.
# 'M_drib[c]' is not a valid SBML 'SId'.
# 'M_nadh[c]' is not a valid SBML 'SId'.
# 'M_nad[c]' is not a valid SBML 'SId'.
# 'M_2hb[c]' is not a valid SBML 'SId'.
# 'M_2obut[c]' is not a valid SBML 'SId'.
# 'M_h[e]' is not a valid SBML 'SId'.
# 'M_2hb[e]' is not a valid SBML 'SId'.
# 'M_hco3[e]' is not a valid SBML 'SId'.
# 'M_hco3[c]' is not a valid SBML 'SId'.
# 'M_na1[e]' is not a valid SBML 'SId'.
# 'M_na1[c]' is not a valid SBML 'SId'.
# 'M_2mcit[c]' is not a valid SBML 'SId'.
# 'M_2mcit[e]' is not a valid SBML 'SId'.
# 'M_nadh[m]' is not a valid SBML 'SId'.
# 'M_nad[m]' is not a valid SBML 'SId'.
# 'M_2oxoadp[m]' is not a valid SBML 'SId'.
# 'M_coa[m]' is not a valid SBML 'SId'.
# 'M_co2[m]' is not a valid SBML 'SId'.
# 'M_glutcoa[m]' is not a valid SBML 'SId'.
# 'M_2oxoadp[c]' is not a valid SBML 'SId'.
# 'M_34dhmald[c]' is not a valid SBML 'SId'.
# 'M_34dhoxpeg[c]' is not a valid SBML 'SId'.
# 'M_34dhoxpeg[e]' is not a valid SBML 'SId'.
# 'M_34dhpha[c]' is not a valid SBML 'SId'.
# 'M_amet[c]' is not a valid SBML 'SId'.
# 'M_ahcys[c]' is not a valid SBML 'SId'.
# 'M_homoval[c]' is not a valid SBML 'SId'.
# 'M_34dhphe[e]' is not a valid SBML 'SId'.
# 'M_34dhphe[c]' is not a valid SBML 'SId'.
# 'M_34dhpac[c]' is not a valid SBML 'SId'.
# 'M_34dhoxmand[c]' is not a valid SBML 'SId'.
# 'M_34hpp[m]' is not a valid SBML 'SId'.
# 'M_34hpl[m]' is not a valid SBML 'SId'.
# 'M_co2[c]' is not a valid SBML 'SId'.
# 'M_34hpp[c]' is not a valid SBML 'SId'.
# 'M_hgentis[c]' is not a valid SBML 'SId'.
# 'M_35cgmp[c]' is not a valid SBML 'SId'.
# 'M_35cgmp[n]' is not a valid SBML 'SId'.
# 'M_3aib[m]' is not a valid SBML 'SId'.
# 'M_2mop[m]' is not a valid SBML 'SId'.
# 'M_glu_L[m]' is not a valid SBML 'SId'.
# 'M_3aib[c]' is not a valid SBML 'SId'.
# 'M_3dphb[m]' is not a valid SBML 'SId'.
# 'M_3dpdhb[m]' is not a valid SBML 'SId'.
# 'M_3dsphgn[c]' is not a valid SBML 'SId'.
# 'M_sphgn[c]' is not a valid SBML 'SId'.
# 'M_3hanthrn[c]' is not a valid SBML 'SId'.
# 'M_cmusa[c]' is not a valid SBML 'SId'.
# 'M_b2coa[m]' is not a valid SBML 'SId'.
# 'M_3hbcoa_R[m]' is not a valid SBML 'SId'.
# 'M_3hibutcoa[m]' is not a valid SBML 'SId'.
# 'M_3hmp[m]' is not a valid SBML 'SId'.
# 'M_glu_L[c]' is not a valid SBML 'SId'.
# 'M_hLkynr[c]' is not a valid SBML 'SId'.
# 'M_42A3HP24DB[c]' is not a valid SBML 'SId'.
# 'M_dopa[c]' is not a valid SBML 'SId'.
# 'M_coa[c]' is not a valid SBML 'SId'.
# 'M_3hpp[c]' is not a valid SBML 'SId'.
# 'M_3hxkynam[c]' is not a valid SBML 'SId'.
# 'M_48dhoxquin[c]' is not a valid SBML 'SId'.
# 'M_3mox4hpac[c]' is not a valid SBML 'SId'.
# 'M_3mlda[c]' is not a valid SBML 'SId'.
# 'M_3mlda[e]' is not a valid SBML 'SId'.
# 'M_3mob[c]' is not a valid SBML 'SId'.
# 'M_3mob[m]' is not a valid SBML 'SId'.
# 'M_3mop[c]' is not a valid SBML 'SId'.
# 'M_3mop[m]' is not a valid SBML 'SId'.
# 'M_3m4hpga[c]' is not a valid SBML 'SId'.
# 'M_3mox4hoxm[c]' is not a valid SBML 'SId'.
# 'M_3moxtyr[c]' is not a valid SBML 'SId'.
# 'M_h2o[l]' is not a valid SBML 'SId'.
# 'M_pi[l]' is not a valid SBML 'SId'.
# 'M_adn[l]' is not a valid SBML 'SId'.
# 'M_3sala[m]' is not a valid SBML 'SId'.
# 'M_3sala[c]' is not a valid SBML 'SId'.
# 'M_asp_L[c]' is not a valid SBML 'SId'.
# 'M_asp_L[m]' is not a valid SBML 'SId'.
# 'M_hyptaur[c]' is not a valid SBML 'SId'.
# 'M_3snpyr[c]' is not a valid SBML 'SId'.
# 'M_3snpyr[m]' is not a valid SBML 'SId'.
# 'M_so3[c]' is not a valid SBML 'SId'.
# 'M_pyr[m]' is not a valid SBML 'SId'.
# 'M_so3[m]' is not a valid SBML 'SId'.
# 'M_adrnl[c]' is not a valid SBML 'SId'.
# 'M_mma[c]' is not a valid SBML 'SId'.
# 'M_nrpphr[c]' is not a valid SBML 'SId'.
# 'M_4abut[c]' is not a valid SBML 'SId'.
# 'M_4abut[m]' is not a valid SBML 'SId'.
# 'M_coucoa[m]' is not a valid SBML 'SId'.
# 'M_4hbzcoa[m]' is not a valid SBML 'SId'.
# 'M_accoa[m]' is not a valid SBML 'SId'.
# 'M_4hbz[m]' is not a valid SBML 'SId'.
# 'M_4hdebrisoquine[e]' is not a valid SBML 'SId'.
# 'M_4hdebrisoquine[c]' is not a valid SBML 'SId'.
# 'M_4hglusa[m]' is not a valid SBML 'SId'.
# 'M_e4hglu[m]' is not a valid SBML 'SId'.
# 'M_4hoxpacd[c]' is not a valid SBML 'SId'.
# 'M_4hphac[c]' is not a valid SBML 'SId'.
# 'M_4mop[c]' is not a valid SBML 'SId'.
# 'M_4mop[m]' is not a valid SBML 'SId'.
# 'M_4mptnl[c]' is not a valid SBML 'SId'.
# 'M_4mptnl[e]' is not a valid SBML 'SId'.
# 'M_4mptnl[m]' is not a valid SBML 'SId'.
# 'M_4mtolbutamide[e]' is not a valid SBML 'SId'.
# 'M_4mtolbutamide[c]' is not a valid SBML 'SId'.
# 'M_4nphsf[e]' is not a valid SBML 'SId'.
# 'M_4nphsf[c]' is not a valid SBML 'SId'.
# 'M_4nph[c]' is not a valid SBML 'SId'.
# 'M_4nph[e]' is not a valid SBML 'SId'.
# 'M_4pyrdx[c]' is not a valid SBML 'SId'.
# 'M_4pyrdx[e]' is not a valid SBML 'SId'.
# 'M_5adtststeroneglc[c]' is not a valid SBML 'SId'.
# 'M_5adtststeroneglc[e]' is not a valid SBML 'SId'.
# 'M_5adtststeroneglc[r]' is not a valid SBML 'SId'.
# 'M_5adtststerones[c]' is not a valid SBML 'SId'.
# 'M_5adtststerones[e]' is not a valid SBML 'SId'.
# 'M_5adtststerone[c]' is not a valid SBML 'SId'.
# 'M_5adtststerone[e]' is not a valid SBML 'SId'.
# 'M_5adtststerone[r]' is not a valid SBML 'SId'.
# 'M_5aop[c]' is not a valid SBML 'SId'.
# 'M_5aop[m]' is not a valid SBML 'SId'.
# 'M_5dhf[c]' is not a valid SBML 'SId'.
# 'M_5dhf[l]' is not a valid SBML 'SId'.
# 'M_h2o[e]' is not a valid SBML 'SId'.
# 'M_5fthf[e]' is not a valid SBML 'SId'.
# 'M_5fthf[c]' is not a valid SBML 'SId'.
# 'M_5htrp[c]' is not a valid SBML 'SId'.
# 'M_srtn[c]' is not a valid SBML 'SId'.
# 'M_5homeprazole[e]' is not a valid SBML 'SId'.
# 'M_5homeprazole[c]' is not a valid SBML 'SId'.
# 'M_5hoxindact[c]' is not a valid SBML 'SId'.
# 'M_5hoxindoa[c]' is not a valid SBML 'SId'.
# 'M_5hoxnfkyn[c]' is not a valid SBML 'SId'.
# 'M_5htrp[e]' is not a valid SBML 'SId'.
# 'M_5hxkyn[c]' is not a valid SBML 'SId'.
# 'M_5hxkynam[c]' is not a valid SBML 'SId'.
# 'M_46dhoxquin[c]' is not a valid SBML 'SId'.
# 'M_5mthf[e]' is not a valid SBML 'SId'.
# 'M_5mthf[c]' is not a valid SBML 'SId'.
# 'M_5thf[c]' is not a valid SBML 'SId'.
# 'M_5thf[l]' is not a valid SBML 'SId'.
# 'M_5thf[m]' is not a valid SBML 'SId'.
# 'M_6dhf[c]' is not a valid SBML 'SId'.
# 'M_6dhf[l]' is not a valid SBML 'SId'.
# 'M_6dhf[m]' is not a valid SBML 'SId'.
# 'M_6htststerone[c]' is not a valid SBML 'SId'.
# 'M_6htststerone[e]' is not a valid SBML 'SId'.
# 'M_6htststerone[r]' is not a valid SBML 'SId'.
# 'M_6thf[c]' is not a valid SBML 'SId'.
# 'M_6thf[l]' is not a valid SBML 'SId'.
# 'M_6thf[m]' is not a valid SBML 'SId'.
# 'M_7dhchsterol[r]' is not a valid SBML 'SId'.
# 'M_7dhchsterol[c]' is not a valid SBML 'SId'.
# 'M_7dhf[c]' is not a valid SBML 'SId'.
# 'M_7dhf[l]' is not a valid SBML 'SId'.
# 'M_7dhf[m]' is not a valid SBML 'SId'.
# 'M_7thf[c]' is not a valid SBML 'SId'.
# 'M_7thf[l]' is not a valid SBML 'SId'.
# 'M_7thf[m]' is not a valid SBML 'SId'.
# 'M_man[c]' is not a valid SBML 'SId'.
# 'M_m2mn[l]' is not a valid SBML 'SId'.
# 'M_man[l]' is not a valid SBML 'SId'.
# 'M_mn[l]' is not a valid SBML 'SId'.
# 'M_galgluside_hs[c]' is not a valid SBML 'SId'.
# 'M_udpgal[c]' is not a valid SBML 'SId'.
# 'M_thcrm_hs[c]' is not a valid SBML 'SId'.
# 'M_udp[c]' is not a valid SBML 'SId'.
# 'M_h[g]' is not a valid SBML 'SId'.
# 'M_galgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_udpgal[g]' is not a valid SBML 'SId'.
# 'M_thcrm_hs[g]' is not a valid SBML 'SId'.
# 'M_udp[g]' is not a valid SBML 'SId'.
# 'M_T_antigen[g]' is not a valid SBML 'SId'.
# 'M_uacgam[g]' is not a valid SBML 'SId'.
# 'M_gncore1[g]' is not a valid SBML 'SId'.
# 'M_core2[g]' is not a valid SBML 'SId'.
# 'M_gncore2[g]' is not a valid SBML 'SId'.
# 'M_aact[c]' is not a valid SBML 'SId'.
# 'M_mthgxl[c]' is not a valid SBML 'SId'.
# 'M_aact[m]' is not a valid SBML 'SId'.
# 'M_L2aadp6sa[m]' is not a valid SBML 'SId'.
# 'M_fucgalacglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_udpacgal[g]' is not a valid SBML 'SId'.
# 'M_acgalfucgalacglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galfucgalacglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_fuc12gal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galfuc12gal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_acgalfuc12gal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_fucgalacgalfuc12gal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_acgalfucgalacgalfuc12gal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_fucgalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_acgalfucgalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_fucgalacgalfucgalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galfucgalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_fucfucgalacglcgalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_sucsal[m]' is not a valid SBML 'SId'.
# 'M_abt[c]' is not a valid SBML 'SId'.
# 'M_xylu_L[c]' is not a valid SBML 'SId'.
# 'M_abt[e]' is not a valid SBML 'SId'.
# 'M_h[l]' is not a valid SBML 'SId'.
# 'M_4abut[e]' is not a valid SBML 'SId'.
# 'M_2maacoa[m]' is not a valid SBML 'SId'.
# 'M_ppcoa[m]' is not a valid SBML 'SId'.
# 'M_aacoa[m]' is not a valid SBML 'SId'.
# 'M_coa[x]' is not a valid SBML 'SId'.
# 'M_accoa[x]' is not a valid SBML 'SId'.
# 'M_aacoa[x]' is not a valid SBML 'SId'.
# 'M_acac[c]' is not a valid SBML 'SId'.
# 'M_acac[m]' is not a valid SBML 'SId'.
# 'M_3odcoa[x]' is not a valid SBML 'SId'.
# 'M_occoa[x]' is not a valid SBML 'SId'.
# 'M_3oddcoa[x]' is not a valid SBML 'SId'.
# 'M_dcacoa[x]' is not a valid SBML 'SId'.
# 'M_3otdcoa[x]' is not a valid SBML 'SId'.
# 'M_ddcacoa[x]' is not a valid SBML 'SId'.
# 'M_3ohdcoa[x]' is not a valid SBML 'SId'.
# 'M_tdcoa[x]' is not a valid SBML 'SId'.
# 'M_3ohodcoa[x]' is not a valid SBML 'SId'.
# 'M_pmtcoa[x]' is not a valid SBML 'SId'.
# 'M_3ohxccoa[x]' is not a valid SBML 'SId'.
# 'M_ttccoa[x]' is not a valid SBML 'SId'.
# 'M_acac[x]' is not a valid SBML 'SId'.
# 'M_acald[m]' is not a valid SBML 'SId'.
# 'M_acald[c]' is not a valid SBML 'SId'.
# 'M_acald[r]' is not a valid SBML 'SId'.
# 'M_acald[x]' is not a valid SBML 'SId'.
# 'M_atp[m]' is not a valid SBML 'SId'.
# 'M_adp[m]' is not a valid SBML 'SId'.
# 'M_pi[m]' is not a valid SBML 'SId'.
# 'M_hco3[m]' is not a valid SBML 'SId'.
# 'M_malcoa[m]' is not a valid SBML 'SId'.
# 'M_accoa[c]' is not a valid SBML 'SId'.
# 'M_accoa[g]' is not a valid SBML 'SId'.
# 'M_amp[m]' is not a valid SBML 'SId'.
# 'M_ppi[m]' is not a valid SBML 'SId'.
# 'M_ppa[m]' is not a valid SBML 'SId'.
# 'M_accoa[n]' is not a valid SBML 'SId'.
# 'M_accoa[r]' is not a valid SBML 'SId'.
# 'M_acetone[e]' is not a valid SBML 'SId'.
# 'M_acetone[c]' is not a valid SBML 'SId'.
# 'M_acetone[m]' is not a valid SBML 'SId'.
# 'M_acgagbside_hs[c]' is not a valid SBML 'SId'.
# 'M_acgagbside_hs[g]' is not a valid SBML 'SId'.
# 'M_acgagbside_hs[l]' is not a valid SBML 'SId'.
# 'M_acgalfucgalacgalfuc12gal14acglcgalgluside_hs[e]' is not a valid SBML 'SId'.
# 'M_acgalfucgalacgalfuc12gal14acglcgalgluside_hs[c]' is not a valid SBML 'SId'.
# 'M_acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs[e]' is not a valid SBML 'SId'.
# 'M_acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs[c]' is not a valid SBML 'SId'.
# 'M_acgal[c]' is not a valid SBML 'SId'.
# 'M_acgal1p[c]' is not a valid SBML 'SId'.
# 'M_itp[c]' is not a valid SBML 'SId'.
# 'M_idp[c]' is not a valid SBML 'SId'.
# 'M_acgal[g]' is not a valid SBML 'SId'.
# 'M_acgal[l]' is not a valid SBML 'SId'.
# 'M_gam6p[c]' is not a valid SBML 'SId'.
# 'M_acgam6p[c]' is not a valid SBML 'SId'.
# 'M_acgam[c]' is not a valid SBML 'SId'.
# 'M_acgam1p[c]' is not a valid SBML 'SId'.
# 'M_acgam[l]' is not a valid SBML 'SId'.
# 'M_acgbgbside_hs[c]' is not a valid SBML 'SId'.
# 'M_acgbgbside_hs[g]' is not a valid SBML 'SId'.
# 'M_acgbgbside_hs[l]' is not a valid SBML 'SId'.
# 'M_ac[c]' is not a valid SBML 'SId'.
# 'M_acglu[m]' is not a valid SBML 'SId'.
# 'M_ac[e]' is not a valid SBML 'SId'.
# 'M_ach[e]' is not a valid SBML 'SId'.
# 'M_chol[e]' is not a valid SBML 'SId'.
# 'M_ach[n]' is not a valid SBML 'SId'.
# 'M_ach[c]' is not a valid SBML 'SId'.
# 'M_cit[c]' is not a valid SBML 'SId'.
# 'M_oaa[c]' is not a valid SBML 'SId'.
# 'M_acn13acngalgbside_hs[c]' is not a valid SBML 'SId'.
# 'M_acn13acngalgbside_hs[e]' is not a valid SBML 'SId'.
# 'M_acn13acngalgbside_hs[g]' is not a valid SBML 'SId'.
# 'M_acn23acngalgbside_hs[c]' is not a valid SBML 'SId'.
# 'M_acn23acngalgbside_hs[e]' is not a valid SBML 'SId'.
# 'M_acn23acngalgbside_hs[g]' is not a valid SBML 'SId'.
# 'M_acnacngal14acglcgalgluside_hs[e]' is not a valid SBML 'SId'.
# 'M_acnacngal14acglcgalgluside_hs[c]' is not a valid SBML 'SId'.
# 'M_acnacngal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_acnacngalgbside_hs[c]' is not a valid SBML 'SId'.
# 'M_acnacngalgbside_hs[e]' is not a valid SBML 'SId'.
# 'M_acnacngalgbside_hs[g]' is not a valid SBML 'SId'.
# 'M_acmanap[c]' is not a valid SBML 'SId'.
# 'M_pep[c]' is not a valid SBML 'SId'.
# 'M_acnamp[c]' is not a valid SBML 'SId'.
# 'M_man6p[c]' is not a valid SBML 'SId'.
# 'M_kdnp[c]' is not a valid SBML 'SId'.
# 'M_acnam[c]' is not a valid SBML 'SId'.
# 'M_acnam[l]' is not a valid SBML 'SId'.
# 'M_acnam[n]' is not a valid SBML 'SId'.
# 'M_acngalacglcgal14acglcgalgluside_hs[e]' is not a valid SBML 'SId'.
# 'M_acngalacglcgal14acglcgalgluside_hs[c]' is not a valid SBML 'SId'.
# 'M_acngalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_acmana[c]' is not a valid SBML 'SId'.
# 'M_2mbcoa[m]' is not a valid SBML 'SId'.
# 'M_fad[m]' is not a valid SBML 'SId'.
# 'M_2mb2coa[m]' is not a valid SBML 'SId'.
# 'M_fadh2[m]' is not a valid SBML 'SId'.
# 'M_btcoa[m]' is not a valid SBML 'SId'.
# 'M_ivcoa[m]' is not a valid SBML 'SId'.
# 'M_3mb2coa[m]' is not a valid SBML 'SId'.
# 'M_ibcoa[m]' is not a valid SBML 'SId'.
# 'M_2mp2coa[m]' is not a valid SBML 'SId'.
# 'M_o2[x]' is not a valid SBML 'SId'.
# 'M_h2o2[x]' is not a valid SBML 'SId'.
# 'M_hdd2coa[x]' is not a valid SBML 'SId'.
# 'M_acorn[c]' is not a valid SBML 'SId'.
# 'M_orn[c]' is not a valid SBML 'SId'.
# 'M_cit[m]' is not a valid SBML 'SId'.
# 'M_icit[m]' is not a valid SBML 'SId'.
# 'M_fad[x]' is not a valid SBML 'SId'.
# 'M_fadh2[x]' is not a valid SBML 'SId'.
# 'M_dhcholoylcoa[x]' is not a valid SBML 'SId'.
# 'M_thcholoylcoa[x]' is not a valid SBML 'SId'.
# 'M_h2o[x]' is not a valid SBML 'SId'.
# 'M_cholcoas[x]' is not a valid SBML 'SId'.
# 'M_cholcoads[x]' is not a valid SBML 'SId'.
# 'M_fmn[c]' is not a valid SBML 'SId'.
# 'M_ribflv[c]' is not a valid SBML 'SId'.
# 'M_acrn[c]' is not a valid SBML 'SId'.
# 'M_acrn[m]' is not a valid SBML 'SId'.
# 'M_amp[c]' is not a valid SBML 'SId'.
# 'M_ppi[c]' is not a valid SBML 'SId'.
# 'M_ppcoa[c]' is not a valid SBML 'SId'.
# 'M_ppa[c]' is not a valid SBML 'SId'.
# 'M_ac[m]' is not a valid SBML 'SId'.
# 'M_Nacsertn[c]' is not a valid SBML 'SId'.
# 'M_melatn[c]' is not a valid SBML 'SId'.
# 'M_ac[g]' is not a valid SBML 'SId'.
# 'M_acetol[c]' is not a valid SBML 'SId'.
# 'M_adn[c]' is not a valid SBML 'SId'.
# 'M_ins[c]' is not a valid SBML 'SId'.
# 'M_nh4[e]' is not a valid SBML 'SId'.
# 'M_adn[e]' is not a valid SBML 'SId'.
# 'M_ins[e]' is not a valid SBML 'SId'.
# 'M_ade[e]' is not a valid SBML 'SId'.
# 'M_ade[c]' is not a valid SBML 'SId'.
# 'M_adhap_hs[c]' is not a valid SBML 'SId'.
# 'M_adhap_hs[x]' is not a valid SBML 'SId'.
# 'M_gtp[c]' is not a valid SBML 'SId'.
# 'M_gdp[c]' is not a valid SBML 'SId'.
# 'M_gtp[m]' is not a valid SBML 'SId'.
# 'M_gdp[m]' is not a valid SBML 'SId'.
# 'M_damp[c]' is not a valid SBML 'SId'.
# 'M_datp[c]' is not a valid SBML 'SId'.
# 'M_dadp[c]' is not a valid SBML 'SId'.
# 'M_ametam[c]' is not a valid SBML 'SId'.
# 'M_camp[c]' is not a valid SBML 'SId'.
# 'M_adn[m]' is not a valid SBML 'SId'.
# 'M_g1p[c]' is not a valid SBML 'SId'.
# 'M_adpman[c]' is not a valid SBML 'SId'.
# 'M_man1p[c]' is not a valid SBML 'SId'.
# 'M_adprib[e]' is not a valid SBML 'SId'.
# 'M_adprib[c]' is not a valid SBML 'SId'.
# 'M_adp[x]' is not a valid SBML 'SId'.
# 'M_adrncoa[c]' is not a valid SBML 'SId'.
# 'M_adrncoa[x]' is not a valid SBML 'SId'.
# 'M_crn[c]' is not a valid SBML 'SId'.
# 'M_adrncrn[c]' is not a valid SBML 'SId'.
# 'M_adrncoa[m]' is not a valid SBML 'SId'.
# 'M_crn[m]' is not a valid SBML 'SId'.
# 'M_adrncrn[m]' is not a valid SBML 'SId'.
# 'M_adrnl[e]' is not a valid SBML 'SId'.
# 'M_adrn[e]' is not a valid SBML 'SId'.
# 'M_adrn[c]' is not a valid SBML 'SId'.
# 'M_aps[c]' is not a valid SBML 'SId'.
# 'M_dcamp[c]' is not a valid SBML 'SId'.
# 'M_fum[c]' is not a valid SBML 'SId'.
# 'M_25aics[c]' is not a valid SBML 'SId'.
# 'M_aicar[c]' is not a valid SBML 'SId'.
# 'M_aflatoxin[e]' is not a valid SBML 'SId'.
# 'M_aflatoxin[c]' is not a valid SBML 'SId'.
# 'M_ksi_pre18[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre19[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre21[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre22[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre24[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre25[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre27[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre28[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre30[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre31[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre33[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre34[g]' is not a valid SBML 'SId'.
# 'M_ksii_core4_pre2[g]' is not a valid SBML 'SId'.
# 'M_ksii_core4_pre3[g]' is not a valid SBML 'SId'.
# 'M_ksii_core4_pre4[g]' is not a valid SBML 'SId'.
# 'M_ksii_core4_pre5[g]' is not a valid SBML 'SId'.
# 'M_ksii_core4_pre7[g]' is not a valid SBML 'SId'.
# 'M_ksii_core4_pre8[g]' is not a valid SBML 'SId'.
# 'M_ksii_core2_pre2[g]' is not a valid SBML 'SId'.
# 'M_ksii_core2_pre3[g]' is not a valid SBML 'SId'.
# 'M_ksii_core2_pre4[g]' is not a valid SBML 'SId'.
# 'M_ksii_core2_pre5[g]' is not a valid SBML 'SId'.
# 'M_ksii_core2_pre7[g]' is not a valid SBML 'SId'.
# 'M_ksii_core2_pre8[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre1[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre2[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre3[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre4[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre6[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre7[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre9[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre10[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre12[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre13[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre15[g]' is not a valid SBML 'SId'.
# 'M_ksi_pre16[g]' is not a valid SBML 'SId'.
# 'M_ak2g_hs[c]' is not a valid SBML 'SId'.
# 'M_cdpchol[c]' is not a valid SBML 'SId'.
# 'M_ak2gchol_hs[c]' is not a valid SBML 'SId'.
# 'M_cmp[c]' is not a valid SBML 'SId'.
# 'M_dak2gpe_hs[c]' is not a valid SBML 'SId'.
# 'M_cdpea[c]' is not a valid SBML 'SId'.
# 'M_ak2gp_hs[c]' is not a valid SBML 'SId'.
# 'M_akgp_hs[c]' is not a valid SBML 'SId'.
# 'M_Rtotal2[c]' is not a valid SBML 'SId'.
# 'M_agm[m]' is not a valid SBML 'SId'.
# 'M_ptrc[m]' is not a valid SBML 'SId'.
# 'M_urea[m]' is not a valid SBML 'SId'.
# 'M_Rtotal2coa[c]' is not a valid SBML 'SId'.
# 'M_alpa_hs[c]' is not a valid SBML 'SId'.
# 'M_pa_hs[c]' is not a valid SBML 'SId'.
# 'M_ala_L[m]' is not a valid SBML 'SId'.
# 'M_glx[m]' is not a valid SBML 'SId'.
# 'M_gly[m]' is not a valid SBML 'SId'.
# 'M_pyr[x]' is not a valid SBML 'SId'.
# 'M_ala_L[x]' is not a valid SBML 'SId'.
# 'M_glx[x]' is not a valid SBML 'SId'.
# 'M_gly[x]' is not a valid SBML 'SId'.
# 'M_ahandrostanglc[c]' is not a valid SBML 'SId'.
# 'M_ahandrostanglc[e]' is not a valid SBML 'SId'.
# 'M_ahandrostanglc[r]' is not a valid SBML 'SId'.
# 'M_ahcys[r]' is not a valid SBML 'SId'.
# 'M_n2m2nmn[l]' is not a valid SBML 'SId'.
# 'M_n2m2mn[l]' is not a valid SBML 'SId'.
# 'M_air[c]' is not a valid SBML 'SId'.
# 'M_5aizc[c]' is not a valid SBML 'SId'.
# 'M_succoa[m]' is not a valid SBML 'SId'.
# 'M_mal_L[c]' is not a valid SBML 'SId'.
# 'M_mal_L[m]' is not a valid SBML 'SId'.
# 'M_akg[e]' is not a valid SBML 'SId'.
# 'M_akg[x]' is not a valid SBML 'SId'.
# 'M_prgstrn[c]' is not a valid SBML 'SId'.
# 'M_aprgstrn[c]' is not a valid SBML 'SId'.
# 'M_xol7ah[c]' is not a valid SBML 'SId'.
# 'M_xol7ah2[c]' is not a valid SBML 'SId'.
# 'M_xoldioloneh[c]' is not a valid SBML 'SId'.
# 'M_xoltriol[c]' is not a valid SBML 'SId'.
# 'M_xol7aone[c]' is not a valid SBML 'SId'.
# 'M_xoldiolone[c]' is not a valid SBML 'SId'.
# 'M_ala_L[e]' is not a valid SBML 'SId'.
# 'M_ala_L[c]' is not a valid SBML 'SId'.
# 'M_asn_L[c]' is not a valid SBML 'SId'.
# 'M_asn_L[e]' is not a valid SBML 'SId'.
# 'M_cys_L[c]' is not a valid SBML 'SId'.
# 'M_cys_L[e]' is not a valid SBML 'SId'.
# 'M_ala_D[e]' is not a valid SBML 'SId'.
# 'M_ala_D[c]' is not a valid SBML 'SId'.
# 'M_gln_L[c]' is not a valid SBML 'SId'.
# 'M_gln_L[e]' is not a valid SBML 'SId'.
# 'M_gly[c]' is not a valid SBML 'SId'.
# 'M_gly[e]' is not a valid SBML 'SId'.
# 'M_ser_L[c]' is not a valid SBML 'SId'.
# 'M_ser_L[e]' is not a valid SBML 'SId'.
# 'M_ala_L[l]' is not a valid SBML 'SId'.
# 'M_thr_L[c]' is not a valid SBML 'SId'.
# 'M_thr_L[e]' is not a valid SBML 'SId'.
# 'M_12ppd_R[c]' is not a valid SBML 'SId'.
# 'M_lald_D[c]' is not a valid SBML 'SId'.
# 'M_12ppd_S[c]' is not a valid SBML 'SId'.
# 'M_lald_L[c]' is not a valid SBML 'SId'.
# 'M_etoh[c]' is not a valid SBML 'SId'.
# 'M_id3acald[c]' is not a valid SBML 'SId'.
# 'M_ind3ac[c]' is not a valid SBML 'SId'.
# 'M_id3acald[m]' is not a valid SBML 'SId'.
# 'M_ind3ac[m]' is not a valid SBML 'SId'.
# 'M_pristanal[c]' is not a valid SBML 'SId'.
# 'M_prist[c]' is not a valid SBML 'SId'.
# 'M_aldstrn[c]' is not a valid SBML 'SId'.
# 'M_aldstrn[e]' is not a valid SBML 'SId'.
# 'M_aldstrn[m]' is not a valid SBML 'SId'.
# 'M_dhap[c]' is not a valid SBML 'SId'.
# 'M_arachd[c]' is not a valid SBML 'SId'.
# 'M_12HPET[c]' is not a valid SBML 'SId'.
# 'M_15HPET[c]' is not a valid SBML 'SId'.
# 'M_5HPET[c]' is not a valid SBML 'SId'.
# 'M_leuktrA4[c]' is not a valid SBML 'SId'.
# 'M_dhcholestancoa[x]' is not a valid SBML 'SId'.
# 'M_h2o[r]' is not a valid SBML 'SId'.
# 'M_o2[r]' is not a valid SBML 'SId'.
# 'M_dhcholestancoa[r]' is not a valid SBML 'SId'.
# 'M_cholcoar[x]' is not a valid SBML 'SId'.
# 'M_cholcoar[r]' is not a valid SBML 'SId'.
# 'M_amuco[c]' is not a valid SBML 'SId'.
# 'M_amet[r]' is not a valid SBML 'SId'.
# 'M_amet[m]' is not a valid SBML 'SId'.
# 'M_ahcys[m]' is not a valid SBML 'SId'.
# 'M_imp[c]' is not a valid SBML 'SId'.
# 'M_cgly[e]' is not a valid SBML 'SId'.
# 'M_amp[x]' is not a valid SBML 'SId'.
# 'M_amp[r]' is not a valid SBML 'SId'.
# 'M_strch1[e]' is not a valid SBML 'SId'.
# 'M_glc_D[e]' is not a valid SBML 'SId'.
# 'M_strch2[e]' is not a valid SBML 'SId'.
# 'M_glygn2[e]' is not a valid SBML 'SId'.
# 'M_glygn4[e]' is not a valid SBML 'SId'.
# 'M_andrstrnglc[c]' is not a valid SBML 'SId'.
# 'M_andrstrnglc[e]' is not a valid SBML 'SId'.
# 'M_andrstrnglc[r]' is not a valid SBML 'SId'.
# 'M_andrstrn[e]' is not a valid SBML 'SId'.
# 'M_andrstrn[c]' is not a valid SBML 'SId'.
# 'M_andrstrn[r]' is not a valid SBML 'SId'.
# 'M_antipyrene[e]' is not a valid SBML 'SId'.
# 'M_antipyrene[c]' is not a valid SBML 'SId'.
# 'M_2aobut[m]' is not a valid SBML 'SId'.
# 'M_msa[m]' is not a valid SBML 'SId'.
# 'M_ala_B[m]' is not a valid SBML 'SId'.
# 'M_apnnox[e]' is not a valid SBML 'SId'.
# 'M_apnnox[c]' is not a valid SBML 'SId'.
# 'M_apoC[c]' is not a valid SBML 'SId'.
# 'M_lys_L[c]' is not a valid SBML 'SId'.
# 'M_apoC_Lys[c]' is not a valid SBML 'SId'.
# 'M_apoC[m]' is not a valid SBML 'SId'.
# 'M_lys_L[m]' is not a valid SBML 'SId'.
# 'M_apoC_Lys[m]' is not a valid SBML 'SId'.
# 'M_apoC_Lys_btn[c]' is not a valid SBML 'SId'.
# 'M_biocyt[c]' is not a valid SBML 'SId'.
# 'M_apoC_Lys_btn[m]' is not a valid SBML 'SId'.
# 'M_biocyt[m]' is not a valid SBML 'SId'.
# 'M_appnn[e]' is not a valid SBML 'SId'.
# 'M_appnn[c]' is not a valid SBML 'SId'.
# 'M_aprut[c]' is not a valid SBML 'SId'.
# 'M_n4abutn[c]' is not a valid SBML 'SId'.
# 'M_arab_L[e]' is not a valid SBML 'SId'.
# 'M_arab_L[c]' is not a valid SBML 'SId'.
# 'M_arachcoa[c]' is not a valid SBML 'SId'.
# 'M_arachcoa[x]' is not a valid SBML 'SId'.
# 'M_arachcrn[c]' is not a valid SBML 'SId'.
# 'M_arachcoa[m]' is not a valid SBML 'SId'.
# 'M_arachcrn[m]' is not a valid SBML 'SId'.
# 'M_arachdcoa[c]' is not a valid SBML 'SId'.
# 'M_arachdcoa[x]' is not a valid SBML 'SId'.
# 'M_arachd[e]' is not a valid SBML 'SId'.
# 'M_arachd[r]' is not a valid SBML 'SId'.
# 'M_arach[e]' is not a valid SBML 'SId'.
# 'M_arach[c]' is not a valid SBML 'SId'.
# 'M_arg_L[m]' is not a valid SBML 'SId'.
# 'M_lys_L[e]' is not a valid SBML 'SId'.
# 'M_arg_L[e]' is not a valid SBML 'SId'.
# 'M_arg_L[c]' is not a valid SBML 'SId'.
# 'M_orn[m]' is not a valid SBML 'SId'.
# 'M_argsuc[c]' is not a valid SBML 'SId'.
# 'M_citr_L[c]' is not a valid SBML 'SId'.
# 'M_sgalside_hs[l]' is not a valid SBML 'SId'.
# 'M_galside_hs[l]' is not a valid SBML 'SId'.
# 'M_so4[l]' is not a valid SBML 'SId'.
# 'M_Rtotal[c]' is not a valid SBML 'SId'.
# 'M_Rtotalcoa[c]' is not a valid SBML 'SId'.
# 'M_Rtotal3coa[c]' is not a valid SBML 'SId'.
# 'M_Rtotal3[c]' is not a valid SBML 'SId'.
# 'M_pmtcoa[c]' is not a valid SBML 'SId'.
# 'M_R1coa_hs[c]' is not a valid SBML 'SId'.
# 'M_hdcoa[c]' is not a valid SBML 'SId'.
# 'M_tdcoa[c]' is not a valid SBML 'SId'.
# 'M_lnlncacoa[c]' is not a valid SBML 'SId'.
# 'M_R2coa_hs[c]' is not a valid SBML 'SId'.
# 'M_lnlncgcoa[c]' is not a valid SBML 'SId'.
# 'M_strdnccoa[c]' is not a valid SBML 'SId'.
# 'M_dlnlcgcoa[c]' is not a valid SBML 'SId'.
# 'M_tmndnccoa[c]' is not a valid SBML 'SId'.
# 'M_lnlccoa[c]' is not a valid SBML 'SId'.
# 'M_clpndcoa[c]' is not a valid SBML 'SId'.
# 'M_dcsptn1coa[c]' is not a valid SBML 'SId'.
# 'M_c226coa[c]' is not a valid SBML 'SId'.
# 'M_stcoa[c]' is not a valid SBML 'SId'.
# 'M_R3coa_hs[c]' is not a valid SBML 'SId'.
# 'M_odecoa[c]' is not a valid SBML 'SId'.
# 'M_octd11ecoa[c]' is not a valid SBML 'SId'.
# 'M_lneldccoa[c]' is not a valid SBML 'SId'.
# 'M_R4coa_hs[c]' is not a valid SBML 'SId'.
# 'M_nrvnccoa[c]' is not a valid SBML 'SId'.
# 'M_od2coa[c]' is not a valid SBML 'SId'.
# 'M_ttccoa[c]' is not a valid SBML 'SId'.
# 'M_R5coa_hs[c]' is not a valid SBML 'SId'.
# 'M_hexccoa[c]' is not a valid SBML 'SId'.
# 'M_eicostetcoa[c]' is not a valid SBML 'SId'.
# 'M_tetpent6coa[c]' is not a valid SBML 'SId'.
# 'M_tetpent3coa[c]' is not a valid SBML 'SId'.
# 'M_tettet6coa[c]' is not a valid SBML 'SId'.
# 'M_tethex3coa[c]' is not a valid SBML 'SId'.
# 'M_hdd2coa[c]' is not a valid SBML 'SId'.
# 'M_R6coa_hs[c]' is not a valid SBML 'SId'.
# 'M_pmtcoa[m]' is not a valid SBML 'SId'.
# 'M_Rtotalcoa[m]' is not a valid SBML 'SId'.
# 'M_Rtotal2coa[m]' is not a valid SBML 'SId'.
# 'M_Rtotal3coa[m]' is not a valid SBML 'SId'.
# 'M_Rtotal[l]' is not a valid SBML 'SId'.
# 'M_crm_hs[l]' is not a valid SBML 'SId'.
# 'M_sphings[l]' is not a valid SBML 'SId'.
# 'M_ascb_L[c]' is not a valid SBML 'SId'.
# 'M_o2s[c]' is not a valid SBML 'SId'.
# 'M_dhdascb[c]' is not a valid SBML 'SId'.
# 'M_ascb_L[e]' is not a valid SBML 'SId'.
# 'M_nh4[m]' is not a valid SBML 'SId'.
# 'M_asn_L[m]' is not a valid SBML 'SId'.
# 'M_Asn_X_Ser_Thr[r]' is not a valid SBML 'SId'.
# 'M_Asn_X_Ser_Thr[l]' is not a valid SBML 'SId'.
# 'M_cbp[c]' is not a valid SBML 'SId'.
# 'M_cbasp[c]' is not a valid SBML 'SId'.
# 'M_asp_D[e]' is not a valid SBML 'SId'.
# 'M_asp_D[c]' is not a valid SBML 'SId'.
# 'M_k[c]' is not a valid SBML 'SId'.
# 'M_k[e]' is not a valid SBML 'SId'.
# 'M_asp_D[x]' is not a valid SBML 'SId'.
# 'M_Nacasp[m]' is not a valid SBML 'SId'.
# 'M_asp_L[e]' is not a valid SBML 'SId'.
# 'M_oaa[m]' is not a valid SBML 'SId'.
# 'M_atp[r]' is not a valid SBML 'SId'.
# 'M_adp[r]' is not a valid SBML 'SId'.
# 'M_atp[e]' is not a valid SBML 'SId'.
# 'M_pi[e]' is not a valid SBML 'SId'.
# 'M_amp[e]' is not a valid SBML 'SId'.
# 'M_adp[e]' is not a valid SBML 'SId'.
# 'M_atp[n]' is not a valid SBML 'SId'.
# 'M_atp[x]' is not a valid SBML 'SId'.
# 'M_gbside_hs[g]' is not a valid SBML 'SId'.
# 'M_ga2_hs[g]' is not a valid SBML 'SId'.
# 'M_ga1_hs[g]' is not a valid SBML 'SId'.
# 'M_gm2_hs[g]' is not a valid SBML 'SId'.
# 'M_gm1_hs[g]' is not a valid SBML 'SId'.
# 'M_gd2_hs[g]' is not a valid SBML 'SId'.
# 'M_gd1b_hs[g]' is not a valid SBML 'SId'.
# 'M_gt2_hs[g]' is not a valid SBML 'SId'.
# 'M_gt1c_hs[g]' is not a valid SBML 'SId'.
# 'M_galgbside_hs[g]' is not a valid SBML 'SId'.
# 'M_acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galacglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_gal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_acglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_acglc13galacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galacgalfuc12gal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galacgalfucgalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_acglcgalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galacglcgalacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galacglc13galacglcgal14acglcgalgluside_hs[g]' is not a valid SBML 'SId'.
# 'M_galthcrm_hs[g]' is not a valid SBML 'SId'.
# 'M_galgalthcrm_hs[g]' is not a valid SBML 'SId'.
# 'M_galgalgalthcrm_hs[g]' is not a valid SBML 'SId'.
# 'M_acglcgalgbside_hs[g]' is not a valid SBML 'SId'.
# 'M_galacglcgalgbside_hs[g]' is not a valid SBML 'SId'.
# 'M_h2o[g]' is not a valid SBML 'SId'.
# 'M_gm2a_hs[g]' is not a valid SBML 'SId'.
# 'M_gm1a_hs[g]' is not a valid SBML 'SId'.
# 'M_gluside_hs[g]' is not a valid SBML 'SId'.
# 'M_cholcoa[x]' is not a valid SBML 'SId'.
# 'M_gchola[x]' is not a valid SBML 'SId'.
# 'M_taur[x]' is not a valid SBML 'SId'.
# 'M_tchola[x]' is not a valid SBML 'SId'.
# 'M_dgcholcoa[x]' is not a valid SBML 'SId'.
# 'M_dgchol[x]' is not a valid SBML 'SId'.
# 'M_dcholcoa[x]' is not a valid SBML 'SId'.
# 'M_btn[c]' is not a valid SBML 'SId'.
# 'M_btamp[c]' is not a valid SBML 'SId'.
# 'M_btn[m]' is not a valid SBML 'SId'.
# 'M_btamp[m]' is not a valid SBML 'SId'.
# 'M_ala_B[c]' is not a valid SBML 'SId'.
# 'M_ala_B[e]' is not a valid SBML 'SId'.
# 'M_4tmeabutn[c]' is not a valid SBML 'SId'.
# 'M_succ[c]' is not a valid SBML 'SId'.
# 'M_caro[c]' is not a valid SBML 'SId'.
# 'M_retinal[c]' is not a valid SBML 'SId'.
# 'M_glc_D[c]' is not a valid SBML 'SId'.
# 'M_bhb[m]' is not a valid SBML 'SId'.
# 'M_chito2pdol_L[c]' is not a valid SBML 'SId'.
# 'M_gdpmann[c]' is not a valid SBML 'SId'.
# 'M_mpdol_L[c]' is not a valid SBML 'SId'.
# 'M_chito2pdol_U[c]' is not a valid SBML 'SId'.
# 'M_mpdol_U[c]' is not a valid SBML 'SId'.
# 'M_betald[m]' is not a valid SBML 'SId'.
# 'M_glyb[m]' is not a valid SBML 'SId'.
# 'M_bhb[e]' is not a valid SBML 'SId'.
# 'M_bhb[c]' is not a valid SBML 'SId'.
# 'M_hcys_L[c]' is not a valid SBML 'SId'.
# 'M_glyb[c]' is not a valid SBML 'SId'.
# 'M_dmgly[c]' is not a valid SBML 'SId'.
# 'M_met_L[c]' is not a valid SBML 'SId'.
# 'M_bildglcur[e]' is not a valid SBML 'SId'.
# 'M_bildglcur[c]' is not a valid SBML 'SId'.
# 'M_bildglcur[r]' is not a valid SBML 'SId'.
# 'M_bilglcur[e]' is not a valid SBML 'SId'.
# 'M_bilglcur[c]' is not a valid SBML 'SId'.
# 'M_bilglcur[r]' is not a valid SBML 'SId'.
# 'M_biliverd[c]' is not a valid SBML 'SId'.
# 'M_bilirub[c]' is not a valid SBML 'SId'.
# 'M_bilirub[e]' is not a valid SBML 'SId'.
# 'M_bilirub[r]' is not a valid SBML 'SId'.
# 'M_biocyt[n]' is not a valid SBML 'SId'.
# 'M_h[r]' is not a valid SBML 'SId'.
# 'M_dolmanp_L[r]' is not a valid SBML 'SId'.
# 'M_dolp_L[r]' is not a valid SBML 'SId'.
# 'M_dolmanp_U[r]' is not a valid SBML 'SId'.
# 'M_dolp_U[r]' is not a valid SBML 'SId'.
# 'M_h2o[n]' is not a valid SBML 'SId'.
# 'M_lys_L[n]' is not a valid SBML 'SId'.
# 'M_btn[n]' is not a valid SBML 'SId'.
# 'M_biocyt[e]' is not a valid SBML 'SId'.
# 'M_btn[e]' is not a valid SBML 'SId'.
# 'M_3uib[c]' is not a valid SBML 'SId'.
# 'M_3aib_D[c]' is not a valid SBML 'SId'.
# 'M_but[c]' is not a valid SBML 'SId'.
# 'M_but[m]' is not a valid SBML 'SId'.
# 'M_bz[e]' is not a valid SBML 'SId'.
# 'M_bz[c]' is not a valid SBML 'SId'.
# 'M_bz[r]' is not a valid SBML 'SId'.
# 'M_nadph[r]' is not a valid SBML 'SId'.
# 'M_nadp[r]' is not a valid SBML 'SId'.
# 'M_44mctr[r]' is not a valid SBML 'SId'.
# 'M_44mzym[r]' is not a valid SBML 'SId'.
# 'M_pmtcrn[c]' is not a valid SBML 'SId'.
# 'M_pmtcrn[m]' is not a valid SBML 'SId'.
# 'M_hdcecrn[c]' is not a valid SBML 'SId'.
# 'M_hdd2crn[c]' is not a valid SBML 'SId'.
# 'M_hdcoa[m]' is not a valid SBML 'SId'.
# 'M_hdcecrn[m]' is not a valid SBML 'SId'.
# 'M_hdd2coa[m]' is not a valid SBML 'SId'.
# 'M_hdd2crn[m]' is not a valid SBML 'SId'.
# 'M_stcrn[c]' is not a valid SBML 'SId'.
# 'M_stcoa[m]' is not a valid SBML 'SId'.
# 'M_stcrn[m]' is not a valid SBML 'SId'.
# 'M_odecrn[c]' is not a valid SBML 'SId'.
# 'M_odecoa[m]' is not a valid SBML 'SId'.
# 'M_odecrn[m]' is not a valid SBML 'SId'.
# 'M_arachdcrn[c]' is not a valid SBML 'SId'.
# 'M_arachdcoa[m]' is not a valid SBML 'SId'.
# 'M_arachdcrn[m]' is not a valid SBML 'SId'.
# 'M_c226coa[x]' is not a valid SBML 'SId'.
# 'M_c226crn[c]' is not a valid SBML 'SId'.
# 'M_c226coa[m]' is not a valid SBML 'SId'.
# 'M_c226crn[m]' is not a valid SBML 'SId'.
# 'M_co2[r]' is not a valid SBML 'SId'.
# 'M_4mzym_int1[r]' is not a valid SBML 'SId'.
# 'M_4mzym_int2[r]' is not a valid SBML 'SId'.
# 'M_nadh[r]' is not a valid SBML 'SId'.
# 'M_nad[r]' is not a valid SBML 'SId'.
# 'M_zym_int2[r]' is not a valid SBML 'SId'.
# 'M_zymst[r]' is not a valid SBML 'SId'.
# 'M_ca2[c]' is not a valid SBML 'SId'.
# 'M_ca2[e]' is not a valid SBML 'SId'.
# 'M_caro[e]' is not a valid SBML 'SId'.
# 'M_carveol[e]' is not a valid SBML 'SId'.
# 'M_carveol[c]' is not a valid SBML 'SId'.
# 'M_etoh[x]' is not a valid SBML 'SId'.
# 'M_h2o2[m]' is not a valid SBML 'SId'.
# 'M_nh4[r]' is not a valid SBML 'SId'.
# 'M_glc_D[r]' is not a valid SBML 'SId'.
# 'M_cbp[r]' is not a valid SBML 'SId'.
# 'M_g6p[r]' is not a valid SBML 'SId'.
# 'M_cbp[m]' is not a valid SBML 'SId'.
# 'M_pi[r]' is not a valid SBML 'SId'.
# 'M_ppi[r]' is not a valid SBML 'SId'.
# 'M_prostge1[c]' is not a valid SBML 'SId'.
# 'M_prostge2[c]' is not a valid SBML 'SId'.
# 'M_prostgf2[c]' is not a valid SBML 'SId'.
# 'M_cdpdag_hs[c]' is not a valid SBML 'SId'.
# 'M_inost[c]' is not a valid SBML 'SId'.
# 'M_pail_hs[c]' is not a valid SBML 'SId'.
# 'M_cdpdag_hs[m]' is not a valid SBML 'SId'.
# 'M_ctp[c]' is not a valid SBML 'SId'.
# 'M_pa_hs[m]' is not a valid SBML 'SId'.
# 'M_ctp[m]' is not a valid SBML 'SId'.
# 'M_dag_hs[c]' is not a valid SBML 'SId'.
# 'M_pchol_hs[c]' is not a valid SBML 'SId'.
# 'M_pe_hs[c]' is not a valid SBML 'SId'.
# 'M_crm_hs[c]' is not a valid SBML 'SId'.
# 'M_crmp_hs[c]' is not a valid SBML 'SId'.
# 'M_crm_hs[g]' is not a valid SBML 'SId'.
# 'M_crm_hs[r]' is not a valid SBML 'SId'.
# 'M_gluside_hs[c]' is not a valid SBML 'SId'.
# 'M_gluside_hs[r]' is not a valid SBML 'SId'.
# 'M_cgly[c]' is not a valid SBML 'SId'.
# 'M_chsterol[r]' is not a valid SBML 'SId'.
# 'M_xol25oh[r]' is not a valid SBML 'SId'.
# 'M_chol[c]' is not a valid SBML 'SId'.
# 'M_coa[n]' is not a valid SBML 'SId'.
# 'M_chol[n]' is not a valid SBML 'SId'.
# 'M_cholp[c]' is not a valid SBML 'SId'.
# 'M_chol[m]' is not a valid SBML 'SId'.
# 'M_cholate[e]' is not a valid SBML 'SId'.
# 'M_cholate[c]' is not a valid SBML 'SId'.
# 'M_cholp[g]' is not a valid SBML 'SId'.
# 'M_cholp[l]' is not a valid SBML 'SId'.
# 'M_chol[g]' is not a valid SBML 'SId'.
# 'M_chol[r]' is not a valid SBML 'SId'.
# 'M_chsterol[c]' is not a valid SBML 'SId'.
# 'M_chsterols[c]' is not a valid SBML 'SId'.
# 'M_chsterol[l]' is not a valid SBML 'SId'.
# 'M_chsterol[m]' is not a valid SBML 'SId'.
# 'M_chsterol[g]' is not a valid SBML 'SId'.
# 'M_chtn[c]' is not a valid SBML 'SId'.
# 'M_acgam[e]' is not a valid SBML 'SId'.
# 'M_chtn[e]' is not a valid SBML 'SId'.
# 'M_itaccoa[m]' is not a valid SBML 'SId'.
# 'M_citmcoa_L[m]' is not a valid SBML 'SId'.
# 'M_citr_L[m]' is not a valid SBML 'SId'.
# 'M_cit[e]' is not a valid SBML 'SId'.
# 'M_pep[m]' is not a valid SBML 'SId'.
# 'M_creat[m]' is not a valid SBML 'SId'.
# 'M_pcreat[m]' is not a valid SBML 'SId'.
# 'M_creat[c]' is not a valid SBML 'SId'.
# 'M_pcreat[c]' is not a valid SBML 'SId'.
# 'M_cl[e]' is not a valid SBML 'SId'.
# 'M_cl[c]' is not a valid SBML 'SId'.
# 'M_for[c]' is not a valid SBML 'SId'.
# 'M_for[e]' is not a valid SBML 'SId'.
# 'M_i[c]' is not a valid SBML 'SId'.
# 'M_i[e]' is not a valid SBML 'SId'.
# 'M_oxa[c]' is not a valid SBML 'SId'.
# 'M_oxa[e]' is not a valid SBML 'SId'.
# 'M_clpndcoa[x]' is not a valid SBML 'SId'.
# 'M_clpndcrn[c]' is not a valid SBML 'SId'.
# 'M_clpndcoa[m]' is not a valid SBML 'SId'.
# 'M_clpndcrn[m]' is not a valid SBML 'SId'.
# 'M_clpnd[e]' is not a valid SBML 'SId'.
# 'M_clpnd[c]' is not a valid SBML 'SId'.
# 'M_pglyc_hs[c]' is not a valid SBML 'SId'.
# 'M_clpn_hs[c]' is not a valid SBML 'SId'.
# 'M_cmp[g]' is not a valid SBML 'SId'.
# 'M_cmpacna[c]' is not a valid SBML 'SId'.
# 'M_cmpacna[g]' is not a valid SBML 'SId'.
# 'M_cmpacna[n]' is not a valid SBML 'SId'.
# 'M_ppi[n]' is not a valid SBML 'SId'.
# 'M_ctp[n]' is not a valid SBML 'SId'.
# 'M_co2[g]' is not a valid SBML 'SId'.
# 'M_co2[x]' is not a valid SBML 'SId'.
# 'M_coa[g]' is not a valid SBML 'SId'.
# 'M_coa[l]' is not a valid SBML 'SId'.
# 'M_coa[r]' is not a valid SBML 'SId'.
# 'M_coke[r]' is not a valid SBML 'SId'.
# 'M_egme[r]' is not a valid SBML 'SId'.
# 'M_2dpmhobq[m]' is not a valid SBML 'SId'.
# 'M_q10[m]' is not a valid SBML 'SId'.
# 'M_2dp6mobq[m]' is not a valid SBML 'SId'.
# 'M_2dp6mobq_me[m]' is not a valid SBML 'SId'.
# 'M_2dp6mep[m]' is not a valid SBML 'SId'.
# 'M_Tn_antigen[g]' is not a valid SBML 'SId'.
# 'M_core3[g]' is not a valid SBML 'SId'.
# 'M_core4[g]' is not a valid SBML 'SId'.
# 'M_core5[g]' is not a valid SBML 'SId'.
# 'M_core6[g]' is not a valid SBML 'SId'.
# 'M_core7[g]' is not a valid SBML 'SId'.
# 'M_core8[g]' is not a valid SBML 'SId'.
# 'M_co[c]' is not a valid SBML 'SId'.
# 'M_co[e]' is not a valid SBML 'SId'.
# 'M_T4hcinnm[m]' is not a valid SBML 'SId'.
# 'M_coumarin[e]' is not a valid SBML 'SId'.
# 'M_coumarin[c]' is not a valid SBML 'SId'.
# 'M_creat[e]' is not a valid SBML 'SId'.
# 'M_crmp_hs[e]' is not a valid SBML 'SId'.
# 'M_crn[x]' is not a valid SBML 'SId'.
# 'M_pcrn[x]' is not a valid SBML 'SId'.
# 'M_pcrn[c]' is not a valid SBML 'SId'.
# 'M_acrn[x]' is not a valid SBML 'SId'.
# 'M_crn[e]' is not a valid SBML 'SId'.
# 'M_dmnoncrn[x]' is not a valid SBML 'SId'.
# 'M_dmnoncrn[m]' is not a valid SBML 'SId'.
# 'M_crtn[c]' is not a valid SBML 'SId'.
# 'M_crtsl[e]' is not a valid SBML 'SId'.
# 'M_crtsl[c]' is not a valid SBML 'SId'.
# 'M_crtsl[m]' is not a valid SBML 'SId'.
# 'M_crtsl[r]' is not a valid SBML 'SId'.
# 'M_crtstrn[e]' is not a valid SBML 'SId'.
# 'M_crtstrn[c]' is not a valid SBML 'SId'.
# 'M_crtstrn[m]' is not a valid SBML 'SId'.
# 'M_crvnc[e]' is not a valid SBML 'SId'.
# 'M_crvnc[c]' is not a valid SBML 'SId'.
# 'M_cspg_a[l]' is not a valid SBML 'SId'.
# 'M_Ser_Gly_Ala_X_Gly[l]' is not a valid SBML 'SId'.
# 'M_cs_a[l]' is not a valid SBML 'SId'.
# 'M_cspg_b[l]' is not a valid SBML 'SId'.
# 'M_cs_b[l]' is not a valid SBML 'SId'.
# 'M_cspg_c[l]' is not a valid SBML 'SId'.
# 'M_cs_c[l]' is not a valid SBML 'SId'.
# 'M_cspg_d[l]' is not a valid SBML 'SId'.
# 'M_cs_d[l]' is not a valid SBML 'SId'.
# 'M_cspg_e[l]' is not a valid SBML 'SId'.
# 'M_cs_e[l]' is not a valid SBML 'SId'.
# 'M_pcrn[m]' is not a valid SBML 'SId'.
# 'M_dmnoncoa[x]' is not a valid SBML 'SId'.
# 'M_ppcoa[x]' is not a valid SBML 'SId'.
# 'M_acrn[r]' is not a valid SBML 'SId'.
# 'M_crn[r]' is not a valid SBML 'SId'.
# 'M_csn[e]' is not a valid SBML 'SId'.
# 'M_csn[c]' is not a valid SBML 'SId'.
# 'M_cspg_a[g]' is not a valid SBML 'SId'.
# 'M_cspg_a[e]' is not a valid SBML 'SId'.
# 'M_cspg_b[g]' is not a valid SBML 'SId'.
# 'M_cspg_b[e]' is not a valid SBML 'SId'.
# 'M_cspg_c[g]' is not a valid SBML 'SId'.
# 'M_cspg_c[e]' is not a valid SBML 'SId'.
# 'M_cspg_d[g]' is not a valid SBML 'SId'.
# 'M_cspg_d[e]' is not a valid SBML 'SId'.
# 'M_cspg_e[g]' is not a valid SBML 'SId'.
# 'M_cspg_e[e]' is not a valid SBML 'SId'.
# 'M_cyan[e]' is not a valid SBML 'SId'.
# 'M_cyan[c]' is not a valid SBML 'SId'.
# 'M_cyan[m]' is not a valid SBML 'SId'.
# 'M_focytC[m]' is not a valid SBML 'SId'.
# 'M_ficytC[m]' is not a valid SBML 'SId'.
# 'M_q10h2[m]' is not a valid SBML 'SId'.
# 'M_Lcystin[c]' is not a valid SBML 'SId'.
# 'M_gthrd[c]' is not a valid SBML 'SId'.
# 'M_gthox[c]' is not a valid SBML 'SId'.
# 'M_mercppyr[c]' is not a valid SBML 'SId'.
# 'M_cys_L[m]' is not a valid SBML 'SId'.
# 'M_glu_L[e]' is not a valid SBML 'SId'.
# 'M_Lcystin[e]' is not a valid SBML 'SId'.
# 'M_cytd[c]' is not a valid SBML 'SId'.
# 'M_uri[c]' is not a valid SBML 'SId'.
# 'M_cmp[m]' is not a valid SBML 'SId'.
# 'M_cytd[m]' is not a valid SBML 'SId'.
# 'M_nh4[n]' is not a valid SBML 'SId'.
# 'M_h[n]' is not a valid SBML 'SId'.
# 'M_cytd[n]' is not a valid SBML 'SId'.
# 'M_uri[n]' is not a valid SBML 'SId'.
# 'M_cytd[e]' is not a valid SBML 'SId'.
# 'M_cytd[l]' is not a valid SBML 'SId'.
# 'M_cdp[c]' is not a valid SBML 'SId'.
# 'M_dgtp[c]' is not a valid SBML 'SId'.
# 'M_dgdp[c]' is not a valid SBML 'SId'.
# 'M_cmp[n]' is not a valid SBML 'SId'.
# 'M_cdp[n]' is not a valid SBML 'SId'.
# 'M_dgtp[n]' is not a valid SBML 'SId'.
# 'M_dgdp[n]' is not a valid SBML 'SId'.
# 'M_dcmp[c]' is not a valid SBML 'SId'.
# 'M_dcdp[c]' is not a valid SBML 'SId'.
# 'M_dcmp[n]' is not a valid SBML 'SId'.
# 'M_dcdp[n]' is not a valid SBML 'SId'.
# 'M_dctp[c]' is not a valid SBML 'SId'.
# 'M_dctp[n]' is not a valid SBML 'SId'.
# 'M_datp[n]' is not a valid SBML 'SId'.
# 'M_dadp[n]' is not a valid SBML 'SId'.
# 'M_utp[c]' is not a valid SBML 'SId'.
# 'M_udp[n]' is not a valid SBML 'SId'.
# 'M_utp[n]' is not a valid SBML 'SId'.
# 'M_cdp[m]' is not a valid SBML 'SId'.
# 'M_adp[n]' is not a valid SBML 'SId'.
# 'M_gtp[n]' is not a valid SBML 'SId'.
# 'M_gdp[n]' is not a valid SBML 'SId'.
# 'M_3aib_D[e]' is not a valid SBML 'SId'.
# 'M_3aib_D[m]' is not a valid SBML 'SId'.
# 'M_dad_2[c]' is not a valid SBML 'SId'.
# 'M_din[c]' is not a valid SBML 'SId'.
# 'M_dad_2[e]' is not a valid SBML 'SId'.
# 'M_din[e]' is not a valid SBML 'SId'.
# 'M_pa_hs[n]' is not a valid SBML 'SId'.
# 'M_dag_hs[n]' is not a valid SBML 'SId'.
# 'M_dag_hs[e]' is not a valid SBML 'SId'.
# 'M_nh4[x]' is not a valid SBML 'SId'.
# 'M_ala_D[x]' is not a valid SBML 'SId'.
# 'M_arg_D[x]' is not a valid SBML 'SId'.
# 'M_5g2oxpt[x]' is not a valid SBML 'SId'.
# 'M_23doguln[c]' is not a valid SBML 'SId'.
# 'M_oaa[x]' is not a valid SBML 'SId'.
# 'M_dd2coa[m]' is not a valid SBML 'SId'.
# 'M_dd3coa[m]' is not a valid SBML 'SId'.
# 'M_dcmp[m]' is not a valid SBML 'SId'.
# 'M_dcyt[m]' is not a valid SBML 'SId'.
# 'M_dcyt[n]' is not a valid SBML 'SId'.
# 'M_dcsptn1coa[x]' is not a valid SBML 'SId'.
# 'M_dcsptn1crn[c]' is not a valid SBML 'SId'.
# 'M_dcsptn1coa[m]' is not a valid SBML 'SId'.
# 'M_dcsptn1crn[m]' is not a valid SBML 'SId'.
# 'M_dcsptn1[e]' is not a valid SBML 'SId'.
# 'M_dcsptn1[c]' is not a valid SBML 'SId'.
# 'M_L_dpchrm[c]' is not a valid SBML 'SId'.
# 'M_56dihindlcrbxlt[c]' is not a valid SBML 'SId'.
# 'M_dcyt[c]' is not a valid SBML 'SId'.
# 'M_duri[c]' is not a valid SBML 'SId'.
# 'M_duri[n]' is not a valid SBML 'SId'.
# 'M_dcyt[e]' is not a valid SBML 'SId'.
# 'M_4h2oglt[m]' is not a valid SBML 'SId'.
# 'M_debrisoquine[e]' is not a valid SBML 'SId'.
# 'M_debrisoquine[c]' is not a valid SBML 'SId'.
# 'M_decdp[c]' is not a valid SBML 'SId'.
# 'M_decdp[m]' is not a valid SBML 'SId'.
# 'M_dedoldp_L[c]' is not a valid SBML 'SId'.
# 'M_dedolp_L[c]' is not a valid SBML 'SId'.
# 'M_dedol_L[c]' is not a valid SBML 'SId'.
# 'M_dolichol_L[c]' is not a valid SBML 'SId'.
# 'M_dolichol_U[c]' is not a valid SBML 'SId'.
# 'M_tag_hs[c]' is not a valid SBML 'SId'.
# 'M_dgchol[e]' is not a valid SBML 'SId'.
# 'M_dgchol[c]' is not a valid SBML 'SId'.
# 'M_datp[m]' is not a valid SBML 'SId'.
# 'M_dadp[m]' is not a valid SBML 'SId'.
# 'M_dgdp[m]' is not a valid SBML 'SId'.
# 'M_dgmp[m]' is not a valid SBML 'SId'.
# 'M_dgsn[m]' is not a valid SBML 'SId'.
# 'M_dgsn[e]' is not a valid SBML 'SId'.
# 'M_dgsn[c]' is not a valid SBML 'SId'.
# 'M_3dhguln[c]' is not a valid SBML 'SId'.
# 'M_dhdascb[e]' is not a valid SBML 'SId'.
# 'M_dhap[x]' is not a valid SBML 'SId'.
# 'M_dhcholestanate[m]' is not a valid SBML 'SId'.
# 'M_dhcholestanate[x]' is not a valid SBML 'SId'.
# 'M_fad[r]' is not a valid SBML 'SId'.
# 'M_fadh2[r]' is not a valid SBML 'SId'.
# 'M_zymstnl[r]' is not a valid SBML 'SId'.
# 'M_chlstol[r]' is not a valid SBML 'SId'.
# 'M_lthstrl[r]' is not a valid SBML 'SId'.
# 'M_dsmsterol[r]' is not a valid SBML 'SId'.
# 'M_ddsmsterol[r]' is not a valid SBML 'SId'.
# 'M_dhcrm_hs[c]' is not a valid SBML 'SId'.
# 'M_fad[c]' is not a valid SBML 'SId'.
# 'M_fadh2[c]' is not a valid SBML 'SId'.
# 'M_3dpdhb_me[m]' is not a valid SBML 'SId'.
# 'M_dheas[e]' is not a valid SBML 'SId'.
# 'M_dheas[c]' is not a valid SBML 'SId'.
# 'M_dheas[r]' is not a valid SBML 'SId'.
# 'M_dhea[c]' is not a valid SBML 'SId'.
# 'M_dhea[r]' is not a valid SBML 'SId'.
# 'M_dhf[c]' is not a valid SBML 'SId'.
# 'M_dhf[l]' is not a valid SBML 'SId'.
# 'M_dhf[m]' is not a valid SBML 'SId'.
# 'M_dhor_S[c]' is not a valid SBML 'SId'.
# 'M_orot[c]' is not a valid SBML 'SId'.
# 'M_56dura[c]' is not a valid SBML 'SId'.
# 'M_cala[c]' is not a valid SBML 'SId'.
# 'M_56dthm[c]' is not a valid SBML 'SId'.
# 'M_dhbpt[c]' is not a valid SBML 'SId'.
# 'M_thbpt[c]' is not a valid SBML 'SId'.
# 'M_mlthf[c]' is not a valid SBML 'SId'.
# 'M_didp[c]' is not a valid SBML 'SId'.
# 'M_didp[n]' is not a valid SBML 'SId'.
# 'M_digalsgalside_hs[c]' is not a valid SBML 'SId'.
# 'M_digalsgalside_hs[g]' is not a valid SBML 'SId'.
# 'M_digalside_hs[c]' is not a valid SBML 'SId'.
# 'M_digalside_hs[g]' is not a valid SBML 'SId'.
# 'M_digalside_hs[l]' is not a valid SBML 'SId'.
# 'M_ditp[c]' is not a valid SBML 'SId'.
# 'M_ditp[n]' is not a valid SBML 'SId'.
# 'M_dkmpp[c]' is not a valid SBML 'SId'.
# 'M_2kmb[c]' is not a valid SBML 'SId'.
# 'M_lac_D[e]' is not a valid SBML 'SId'.
# 'M_lac_D[c]' is not a valid SBML 'SId'.
# 'M_lac_D[m]' is not a valid SBML 'SId'.
# 'M_dlnlcgcrn[c]' is not a valid SBML 'SId'.
# 'M_dlnlcgcoa[m]' is not a valid SBML 'SId'.
# 'M_dlnlcgcrn[m]' is not a valid SBML 'SId'.
# 'M_dlnlcg[e]' is not a valid SBML 'SId'.
# 'M_dlnlcg[c]' is not a valid SBML 'SId'.
# 'M_dgtp[m]' is not a valid SBML 'SId'.
# 'M_dsT_antigen[g]' is not a valid SBML 'SId'.
# 'M_dttp[m]' is not a valid SBML 'SId'.
# 'M_dttp[n]' is not a valid SBML 'SId'.
# 'M_ethamp[r]' is not a valid SBML 'SId'.
# 'M_kdn[c]' is not a valid SBML 'SId'.
# 'M_n5m2masn[g]' is not a valid SBML 'SId'.
# 'M_Ser_Thr[l]' is not a valid SBML 'SId'.
# 'M_sprm[c]' is not a valid SBML 'SId'.
# 'M_sTn_antigen[g]' is not a valid SBML 'SId'.
# 'M_yvite[c]' is not a valid SBML 'SId'.
# 'M_dmantipyrine[e]' is not a valid SBML 'SId'.
# 'M_dmantipyrine[c]' is not a valid SBML 'SId'.
# 'M_ppi[x]' is not a valid SBML 'SId'.
# ...
# 'R_EX_HC02020[e]' is not a valid SBML 'SId'.
# 'R_EX_prgnlones[e]' is not a valid SBML 'SId'.
# 'R_EX_CE1352[e]' is not a valid SBML 'SId'.
# 'R_EX_xol24oh[e]' is not a valid SBML 'SId'.
# 'R_EX_xol27oh[e]' is not a valid SBML 'SId'.
# 'R_EX_xol25oh[e]' is not a valid SBML 'SId'.
# 'R_EX_dsmsterol[e]' is not a valid SBML 'SId'.
# 'R_EX_chsterols[e]' is not a valid SBML 'SId'.
# 'R_EX_3ityr_L[e]' is not a valid SBML 'SId'.
# 'R_EX_35diotyr[e]' is not a valid SBML 'SId'.
# 'R_EX_13_cis_retn[e]' is not a valid SBML 'SId'.
# 'R_EX_CE1617[e]' is not a valid SBML 'SId'.
# 'R_EX_HC00460[e]' is not a valid SBML 'SId'.
# 'R_EX_34dhoxmand[e]' is not a valid SBML 'SId'.
# 'R_EX_fna5moxam[e]' is not a valid SBML 'SId'.
# 'R_EX_CE5643[e]' is not a valid SBML 'SId'.
# 'R_EX_CE7090[e]' is not a valid SBML 'SId'.
# 'R_EX_CE7085[e]' is not a valid SBML 'SId'.
# 'R_EX_CE7096[e]' is not a valid SBML 'SId'.
# 'R_EX_CE4877[e]' is not a valid SBML 'SId'.
# 'R_EX_CE1447[e]' is not a valid SBML 'SId'.
# 'R_EX_CE2006[e]' is not a valid SBML 'SId'.
# 'R_EX_CE1401[e]' is not a valid SBML 'SId'.
# 'R_EX_glucys[e]' is not a valid SBML 'SId'.
# 'R_EX_n8aspmd[e]' is not a valid SBML 'SId'.
# 'R_EX_CE6205[e]' is not a valid SBML 'SId'.
# 'R_EX_melatn[e]' is not a valid SBML 'SId'.
# 'R_EX_6hoxmelatn[e]' is not a valid SBML 'SId'.
# 'R_EX_trypta[e]' is not a valid SBML 'SId'.
# 'R_EX_C10164[e]' is not a valid SBML 'SId'.
# 'R_EX_CE4890[e]' is not a valid SBML 'SId'.
# 'R_EX_C09642[e]' is not a valid SBML 'SId'.
# 'R_EX_C05769[e]' is not a valid SBML 'SId'.
# 'R_EX_C05767[e]' is not a valid SBML 'SId'.
# 'R_EX_C05770[e]' is not a valid SBML 'SId'.
# 'R_EX_mhista[e]' is not a valid SBML 'SId'.
# 'R_EX_ppbng[e]' is not a valid SBML 'SId'.
# 'R_EX_13dampp[e]' is not a valid SBML 'SId'.
# 'R_EX_mma[e]' is not a valid SBML 'SId'.
# 'R_EX_12ppd_R[e]' is not a valid SBML 'SId'.
# 'R_EX_ametam[e]' is not a valid SBML 'SId'.
# 'R_EX_xylu_L[e]' is not a valid SBML 'SId'.
# 'R_EX_xylu_D[e]' is not a valid SBML 'SId'.
# 'R_EX_CE0737[e]' is not a valid SBML 'SId'.
# 'R_EX_sphings[e]' is not a valid SBML 'SId'.
# 'R_EX_hdd2crn[e]' is not a valid SBML 'SId'.
# 'R_EX_im4ac[e]' is not a valid SBML 'SId'.
# 'R_EX_CE1918[e]' is not a valid SBML 'SId'.
# 'R_EX_mlthf[e]' is not a valid SBML 'SId'.
# 'R_EX_ppp9[e]' is not a valid SBML 'SId'.
# 'R_EX_aact[e]' is not a valid SBML 'SId'.
# 'R_EX_CE2705[e]' is not a valid SBML 'SId'.
# 'R_EX_sphgn[e]' is not a valid SBML 'SId'.
# 'R_EX_selmeth[e]' is not a valid SBML 'SId'.
# 'R_EX_N1aspmd[e]' is not a valid SBML 'SId'.
# 'R_EX_1a25dhvitd3[e]' is not a valid SBML 'SId'.
# 'R_EX_prist[e]' is not a valid SBML 'SId'.
# 'R_EX_CE2049[e]' is not a valid SBML 'SId'.
# 'R_EX_CE2047[e]' is not a valid SBML 'SId'.
# 'R_EX_fdp[e]' is not a valid SBML 'SId'.
# 'R_EX_coke[e]' is not a valid SBML 'SId'.
# 'R_EX_5a2opntn[e]' is not a valid SBML 'SId'.
# 'R_EX_arg_D[e]' is not a valid SBML 'SId'.
# 'R_EX_vldl_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_idl_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_ldl_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_hdl_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_HC00005[e]' is not a valid SBML 'SId'.
# 'R_EX_HC00006[e]' is not a valid SBML 'SId'.
# 'R_EX_HC00007[e]' is not a valid SBML 'SId'.
# 'R_EX_HC00008[e]' is not a valid SBML 'SId'.
# 'R_EX_HC00009[e]' is not a valid SBML 'SId'.
# 'R_EX_dopa4sf[e]' is not a valid SBML 'SId'.
# 'R_EX_dopa4glcur[e]' is not a valid SBML 'SId'.
# 'R_EX_dopa3glcur[e]' is not a valid SBML 'SId'.
# 'R_EX_4glu56dihdind[e]' is not a valid SBML 'SId'.
# 'R_EX_5cysdopa[e]' is not a valid SBML 'SId'.
# 'R_EX_CE5025[e]' is not a valid SBML 'SId'.
# 'R_EX_CE2172[e]' is not a valid SBML 'SId'.
# 'R_EX_CE5629[e]' is not a valid SBML 'SId'.
# 'R_EX_gd3_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_gluside_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_gm3_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_cmpacna[e]' is not a valid SBML 'SId'.
# 'R_EX_gd2_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_gd1a_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_34dhpe[c]' is not a valid SBML 'SId'.
# 'R_EX_pail_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_CE1243[e]' is not a valid SBML 'SId'.
# 'R_EX_CE5026[e]' is not a valid SBML 'SId'.
# 'R_EX_5cysgly34dhphe[e]' is not a valid SBML 'SId'.
# 'R_EX_CE1261[e]' is not a valid SBML 'SId'.
# 'R_EX_galgluside_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_ga1_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_gm1_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_gm2_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_gm1b_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_gd1b_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_gt1b_hs[e]' is not a valid SBML 'SId'.
# 'R_EX_M00932[e]' is not a valid SBML 'SId'.
# 'R_EX_M02957[e]' is not a valid SBML 'SId'.
# 'R_EX_M01570[e]' is not a valid SBML 'SId'.
# 'R_EX_M03147[e]' is not a valid SBML 'SId'.
# 'R_EX_M02048[e]' is not a valid SBML 'SId'.
# 'R_EX_M02353[e]' is not a valid SBML 'SId'.
# 'R_EX_M01569[e]' is not a valid SBML 'SId'.
# 'R_EX_M03146[e]' is not a valid SBML 'SId'.
# 'R_EX_M02047[e]' is not a valid SBML 'SId'.
# 'R_EX_M02352[e]' is not a valid SBML 'SId'.
# 'R_EX_apoC_Lys[e]' is not a valid SBML 'SId'.
# 'R_EX_pre_prot[e]' is not a valid SBML 'SId'.
# 'R_EX_M03161[e]' is not a valid SBML 'SId'.
# 'R_EX_nadh[e]' is not a valid SBML 'SId'.
# 'R_EX_glc_D[e]' is not a valid SBML 'SId'.
# 'R_EX_sbt_D[e]' is not a valid SBML 'SId'.
# 'R_EX_3dhcdchol[e]' is not a valid SBML 'SId'.
# 'R_EX_3dhchol[e]' is not a valid SBML 'SId'.
# 'R_EX_3dhdchol[e]' is not a valid SBML 'SId'.
# 'R_EX_3dhlchol[e]' is not a valid SBML 'SId'.
# 'R_EX_ca24g[e]' is not a valid SBML 'SId'.
# 'R_EX_ca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_cdca24g[e]' is not a valid SBML 'SId'.
# 'R_EX_cdca3g[e]' is not a valid SBML 'SId'.
# 'R_EX_dca24g[e]' is not a valid SBML 'SId'.
# 'R_EX_dca3g[e]' is not a valid SBML 'SId'.
# 'R_EX_dca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_gca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_gcdca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_gdca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_gudca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_hca24g[e]' is not a valid SBML 'SId'.
# 'R_EX_hca6g[e]' is not a valid SBML 'SId'.
# 'R_EX_hdca24g[e]' is not a valid SBML 'SId'.
# 'R_EX_hdca6g[e]' is not a valid SBML 'SId'.
# 'R_EX_hyochol[e]' is not a valid SBML 'SId'.
# 'R_EX_lca24g[e]' is not a valid SBML 'SId'.
# 'R_EX_lca3g[e]' is not a valid SBML 'SId'.
# 'R_EX_lca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_tca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_tcdca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_tdca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_thyochol[e]' is not a valid SBML 'SId'.
# 'R_EX_tudca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_udca3s[e]' is not a valid SBML 'SId'.
# 'R_EX_12htacr[e]' is not a valid SBML 'SId'.
# 'R_EX_1331tacr[e]' is not a valid SBML 'SId'.
# 'R_EX_13dmt[e]' is not a valid SBML 'SId'.
# 'R_EX_14hmdz[e]' is not a valid SBML 'SId'.
# 'R_EX_1513tacr[e]' is not a valid SBML 'SId'.
# 'R_EX_1531tacr[e]' is not a valid SBML 'SId'.
# 'R_EX_15dmt[e]' is not a valid SBML 'SId'.
# 'R_EX_1hibup_S[e]' is not a valid SBML 'SId'.
# 'R_EX_1hibupglu_S[e]' is not a valid SBML 'SId'.
# 'R_EX_1hmdgluc[e]' is not a valid SBML 'SId'.
# 'R_EX_1ohmdz[e]' is not a valid SBML 'SId'.
# 'R_EX_2hatvacid[e]' is not a valid SBML 'SId'.
# 'R_EX_2hatvacidgluc[e]' is not a valid SBML 'SId'.
# 'R_EX_2hatvlac[e]' is not a valid SBML 'SId'.
# 'R_EX_2hatvlacgluc[e]' is not a valid SBML 'SId'.
# 'R_EX_2hibup_R[e]' is not a valid SBML 'SId'.
# 'R_EX_2hibup_S[e]' is not a valid SBML 'SId'.
# 'R_EX_2hibupglu_S[e]' is not a valid SBML 'SId'.
# 'R_EX_31dmt[e]' is not a valid SBML 'SId'.
# 'R_EX_35dhpvs[e]' is not a valid SBML 'SId'.
# 'R_EX_35dsmv[e]' is not a valid SBML 'SId'.
# 'R_EX_3hibup_R[e]' is not a valid SBML 'SId'.
# 'R_EX_3hibup_S[e]' is not a valid SBML 'SId'.
# 'R_EX_3hibupglu_S[e]' is not a valid SBML 'SId'.
# 'R_EX_3hlvstacid[e]' is not a valid SBML 'SId'.
# 'R_EX_3hpvs[e]' is not a valid SBML 'SId'.
# 'R_EX_3hpvstet[e]' is not a valid SBML 'SId'.
# 'R_EX_3hsmvacid[e]' is not a valid SBML 'SId'.
# 'R_EX_3ispvs[e]' is not a valid SBML 'SId'.
# 'R_EX_3ohacmp[e]' is not a valid SBML 'SId'.
# 'R_EX_4bhglz[e]' is not a valid SBML 'SId'.
# 'R_EX_4hatvacid[e]' is not a valid SBML 'SId'.
# 'R_EX_4hatvlac[e]' is not a valid SBML 'SId'.
# 'R_EX_4hmdgluc[e]' is not a valid SBML 'SId'.
# 'R_EX_4ohmdz[e]' is not a valid SBML 'SId'.
# 'R_EX_56dhpvs[e]' is not a valid SBML 'SId'.
# 'R_EX_56eppvs[e]' is not a valid SBML 'SId'.
# 'R_EX_5ohfvs[e]' is not a valid SBML 'SId'.
# 'R_EX_5ohfvsglu[e]' is not a valid SBML 'SId'.
# 'R_EX_6ahglz[e]' is not a valid SBML 'SId'.
# 'R_EX_6bhglz[e]' is not a valid SBML 'SId'.
# 'R_EX_6bhglzglc[e]' is not a valid SBML 'SId'.
# 'R_EX_6csmvacid[e]' is not a valid SBML 'SId'.
# 'R_EX_6epvs[e]' is not a valid SBML 'SId'.
# 'R_EX_6hlvst[e]' is not a valid SBML 'SId'.
# 'R_EX_6hmsmvacid[e]' is not a valid SBML 'SId'.
# 'R_EX_6hsmvacid[e]' is not a valid SBML 'SId'.
# 'R_EX_6melvacid[e]' is not a valid SBML 'SId'.
# 'R_EX_6melvst[e]' is not a valid SBML 'SId'.
# 'R_EX_6ohfvs[e]' is not a valid SBML 'SId'.
# 'R_EX_6ohfvsglu[e]' is not a valid SBML 'SId'.
# 'R_EX_7ahglz[e]' is not a valid SBML 'SId'.
# 'R_EX_7bhglz[e]' is not a valid SBML 'SId'.
# 'R_EX_7bhglzglc[e]' is not a valid SBML 'SId'.
# 'R_EX_7hpvs[e]' is not a valid SBML 'SId'.
# 'R_EX_acmp[e]' is not a valid SBML 'SId'.
# 'R_EX_acmpglu[e]' is not a valid SBML 'SId'.
# 'R_EX_acmpglut[e]' is not a valid SBML 'SId'.
# 'R_EX_allop[e]' is not a valid SBML 'SId'.
# 'R_EX_am19cs[e]' is not a valid SBML 'SId'.
# 'R_EX_am1a4ncs[e]' is not a valid SBML 'SId'.
# 'R_EX_am1accs[e]' is not a valid SBML 'SId'.
# 'R_EX_am1acs[e]' is not a valid SBML 'SId'.
# 'R_EX_am1alcs[e]' is not a valid SBML 'SId'.
# 'R_EX_am1c4n9cs[e]' is not a valid SBML 'SId'.
# 'R_EX_am1c9cs[e]' is not a valid SBML 'SId'.
# 'R_EX_am1ccs[e]' is not a valid SBML 'SId'.
# 'R_EX_am1cglc[e]' is not a valid SBML 'SId'.
# 'R_EX_am1csa[e]' is not a valid SBML 'SId'.
# 'R_EX_am4n9cs[e]' is not a valid SBML 'SId'.
# 'R_EX_am4ncs[e]' is not a valid SBML 'SId'.
# 'R_EX_am9csa[e]' is not a valid SBML 'SId'.
# 'R_EX_atvacid[e]' is not a valid SBML 'SId'.
# 'R_EX_atvlac[e]' is not a valid SBML 'SId'.
# 'R_EX_caribup_R[e]' is not a valid SBML 'SId'.
# 'R_EX_caribup_s[e]' is not a valid SBML 'SId'.
# 'R_EX_caribupglu_S[e]' is not a valid SBML 'SId'.
# 'R_EX_crglz[e]' is not a valid SBML 'SId'.
# 'R_EX_crvs[e]' is not a valid SBML 'SId'.
# 'R_EX_crvsm1[e]' is not a valid SBML 'SId'.
# 'R_EX_crvsm23[e]' is not a valid SBML 'SId'.
# 'R_EX_crvsm24[e]' is not a valid SBML 'SId'.
# 'R_EX_csa[e]' is not a valid SBML 'SId'.
# 'R_EX_csasulp[e]' is not a valid SBML 'SId'.
# 'R_EX_cysacmp[e]' is not a valid SBML 'SId'.
# 'R_EX_deoxfvs[e]' is not a valid SBML 'SId'.
# 'R_EX_desfvs[e]' is not a valid SBML 'SId'.
# 'R_EX_dhglz[e]' is not a valid SBML 'SId'.
# 'R_EX_dspvs[e]' is not a valid SBML 'SId'.
# 'R_EX_epoxtac[e]' is not a valid SBML 'SId'.
# 'R_EX_fvs[e]' is not a valid SBML 'SId'.
# 'R_EX_fvstet[e]' is not a valid SBML 'SId'.
# 'R_EX_fvstetglu[e]' is not a valid SBML 'SId'.
# 'R_EX_glc3meacp[e]' is not a valid SBML 'SId'.
# 'R_EX_glz[e]' is not a valid SBML 'SId'.
# 'R_EX_gtacmp[e]' is not a valid SBML 'SId'.
# 'R_EX_ibup_R[e]' is not a valid SBML 'SId'.
# 'R_EX_ibup_S[e]' is not a valid SBML 'SId'.
# 'R_EX_ibupgluc[e]' is not a valid SBML 'SId'.
# 'R_EX_isolvstacid[e]' is not a valid SBML 'SId'.
# 'R_EX_lst4exp[e]' is not a valid SBML 'SId'.
# 'R_EX_lstn[e]' is not a valid SBML 'SId'.
# 'R_EX_lstn1gluc[e]' is not a valid SBML 'SId'.
# 'R_EX_lstnm1[e]' is not a valid SBML 'SId'.
# 'R_EX_lstnm2[e]' is not a valid SBML 'SId'.
# 'R_EX_lstnm4[e]' is not a valid SBML 'SId'.
# 'R_EX_lstnm5[e]' is not a valid SBML 'SId'.
# 'R_EX_lstnm7[e]' is not a valid SBML 'SId'.
# 'R_EX_lvst[e]' is not a valid SBML 'SId'.
# 'R_EX_mdz[e]' is not a valid SBML 'SId'.
# 'R_EX_mdzglc[e]' is not a valid SBML 'SId'.
# 'R_EX_meracmp[e]' is not a valid SBML 'SId'.
# 'R_EX_mhglz[e]' is not a valid SBML 'SId'.
# 'R_EX_ndersv[e]' is not a valid SBML 'SId'.
# 'R_EX_nfd[e]' is not a valid SBML 'SId'.
# 'R_EX_nfdac[e]' is not a valid SBML 'SId'.
# 'R_EX_nfdlac[e]' is not a valid SBML 'SId'.
# 'R_EX_nfdnpy[e]' is not a valid SBML 'SId'.
# 'R_EX_nfdoh[e]' is not a valid SBML 'SId'.
# 'R_EX_oxyp[e]' is not a valid SBML 'SId'.
# 'R_EX_oxyp1rb[e]' is not a valid SBML 'SId'.
# 'R_EX_oxyp7rb[e]' is not a valid SBML 'SId'.
# 'R_EX_profvs[e]' is not a valid SBML 'SId'.
# 'R_EX_ptvst[e]' is not a valid SBML 'SId'.
# 'R_EX_ptvstlac[e]' is not a valid SBML 'SId'.
# 'R_EX_ptvstm3[e]' is not a valid SBML 'SId'.
# 'R_EX_pvs[e]' is not a valid SBML 'SId'.
# 'R_EX_pvsgluc[e]' is not a valid SBML 'SId'.
# 'R_EX_rsv[e]' is not a valid SBML 'SId'.
# 'R_EX_rsvlac[e]' is not a valid SBML 'SId'.
# 'R_EX_s3meacmp[e]' is not a valid SBML 'SId'.
# 'R_EX_smv[e]' is not a valid SBML 'SId'.
# 'R_EX_smvacid[e]' is not a valid SBML 'SId'.
# 'R_EX_stacmp[ev]' is not a valid SBML 'SId'.
# 'R_EX_sulpacmp[e]' is not a valid SBML 'SId'.
# 'R_EX_tacr[e]' is not a valid SBML 'SId'.
# 'R_EX_tauribup_S[e]' is not a valid SBML 'SId'.
# 'R_EX_thrfvs[e]' is not a valid SBML 'SId'.
# 'R_EX_tlacfvs[e]' is not a valid SBML 'SId'.
# 'R_EX_tmd[e]' is not a valid SBML 'SId'.
# 'R_EX_tmdm1[e]' is not a valid SBML 'SId'.
# 'R_EX_tmdm3[e]' is not a valid SBML 'SId'.
# 'R_EX_tmdm5[e]' is not a valid SBML 'SId'.
# 'R_EX_tripvs[e]' is not a valid SBML 'SId'.
# 'R_EX_tsacmgluc[e]' is not a valid SBML 'SId'.
# 'R_EX_tsacmsul[e]' is not a valid SBML 'SId'.
# 'R_EX_lvstacid[e]' is not a valid SBML 'SId'.
# 'R_EX_ptvstm13[e]' is not a valid SBML 'SId'.
# 'R_EX_caproic[e]' is not a valid SBML 'SId'.
# 'R_EX_1a25dhvitd2[e]' is not a valid SBML 'SId'.
# 'R_EX_C13856[e]' is not a valid SBML 'SId'.
# 'R_EX_M02956[e]' is not a valid SBML 'SId'.
# 'R_EX_M00234[e]' is not a valid SBML 'SId'.
# 'R_EX_M01807[e]' is not a valid SBML 'SId'.
# 'R_EX_M00503[e]' is not a valid SBML 'SId'.
# 'R_EX_M00241[e]' is not a valid SBML 'SId'.
# 'R_EX_M01820[e]' is not a valid SBML 'SId'.
# 'R_EX_M00510[e]' is not a valid SBML 'SId'.
# 'R_EX_M01819[e]' is not a valid SBML 'SId'.
# 'R_EX_M00003[e]' is not a valid SBML 'SId'.
# 'R_EX_M00008[e]' is not a valid SBML 'SId'.
# 'R_EX_M00010[e]' is not a valid SBML 'SId'.
# 'R_EX_M00017[e]' is not a valid SBML 'SId'.
# 'R_EX_M00019[e]' is not a valid SBML 'SId'.
# 'R_EX_M00021[e]' is not a valid SBML 'SId'.
# 'R_EX_M00115[e]' is not a valid SBML 'SId'.
# 'R_EX_M00117[e]' is not a valid SBML 'SId'.
# 'R_EX_M00260[e]' is not a valid SBML 'SId'.
# 'R_EX_M00265[e]' is not a valid SBML 'SId'.
# 'R_EX_M00315[e]' is not a valid SBML 'SId'.
# 'R_EX_M00341[e]' is not a valid SBML 'SId'.
# 'R_EX_M01197[e]' is not a valid SBML 'SId'.
# 'R_EX_M01207[e]' is not a valid SBML 'SId'.
# 'R_EX_M01235[e]' is not a valid SBML 'SId'.
# 'R_EX_M01238[e]' is not a valid SBML 'SId'.
# 'R_EX_M01582[e]' is not a valid SBML 'SId'.
# 'R_EX_M02053[e]' is not a valid SBML 'SId'.
# 'R_EX_M02457[e]' is not a valid SBML 'SId'.
# 'R_EX_M02613[e]' is not a valid SBML 'SId'.
# 'R_EX_M02745[e]' is not a valid SBML 'SId'.
# 'R_EX_M03045[e]' is not a valid SBML 'SId'.
# 'R_EX_M03051[e]' is not a valid SBML 'SId'.
# 'R_EX_M03153[e]' is not a valid SBML 'SId'.
# 'R_EX_M02560[e]' is not a valid SBML 'SId'.
# 'R_EX_M02561[e]' is not a valid SBML 'SId'.
# 'R_EX_C01601[e]' is not a valid SBML 'SId'.
# 'R_EX_M02909[e]' is not a valid SBML 'SId'.
# 'R_EX_M02108[e]' is not a valid SBML 'SId'.
# 'R_EX_M03117[e]' is not a valid SBML 'SId'.
# 'R_EX_M03134[e]' is not a valid SBML 'SId'.
# 'R_EX_HC02080[e]' is not a valid SBML 'SId'.
# 'R_EX_M01111[e]' is not a valid SBML 'SId'.
# 'R_EX_h2co3[e]' is not a valid SBML 'SId'.
# 'R_EX_M01872[e]' is not a valid SBML 'SId'.
# 'R_EX_M01870[e]' is not a valid SBML 'SId'.
# 'R_EX_ditp[e]' is not a valid SBML 'SId'.
# 'R_EX_hnifedipine[e]' is not a valid SBML 'SId'.
# 'R_EX_M02446[e]' is not a valid SBML 'SId'.
# 'R_EX_M02447[e]' is not a valid SBML 'SId'.
# 'R_EX_M02449[e]' is not a valid SBML 'SId'.
# 'R_EX_M02451[e]' is not a valid SBML 'SId'.
# 'R_EX_itacon[e]' is not a valid SBML 'SId'.
# 'R_EX_adpman[e]' is not a valid SBML 'SId'.
# 'R_EX_rbl_D[e]' is not a valid SBML 'SId'.
# 'R_EX_M01966[e]' is not a valid SBML 'SId'.
# 'R_EX_M02155[e]' is not a valid SBML 'SId'.
# 'R_EX_M01989[e]' is not a valid SBML 'SId'.
# 'R_EX_M02837[e]' is not a valid SBML 'SId'.
# 'R_EX_M01881[e]' is not a valid SBML 'SId'.
# 'R_EX_M03131[e]' is not a valid SBML 'SId'.
# 'R_EX_n5m2masn[e]' is not a valid SBML 'SId'.
# 'R_EX_hretn[e]' is not a valid SBML 'SId'.
# 'R_EX_kdn[e]' is not a valid SBML 'SId'.
# 'R_EX_dolichol_L[e]' is not a valid SBML 'SId'.
# <Model Recon3D at 0x1f5d4df9a48>

# %%
#load the reconstruction results as a dictionary
fastcore_res_dict = pd.read_csv('data/r3d_compact_ccle_bc_fastcore.csv', index_col=[0, 1]).T.to_dict()

#get only first sample
sample = list(fastcore_res_dict.keys())[0]
fastcore_res_dict = {sample: fastcore_res_dict[sample]}
fastcore_res_dict
# Out:
# {('fastcore', 'ACH-001396'): {'10FTHF5GLUtl': False,
#   '10FTHF5GLUtm': False,
#   '10FTHF6GLUtl': False,
#   '10FTHF6GLUtm': False,
#   '10FTHF7GLUtl': False,
#   '10FTHF7GLUtm': False,
#   '10FTHFtl': False,
#   '10FTHFtm': False,
#   '11DOCRTSLtm': False,
#   '11DOCRTSLtr': False,
#   '11DOCRTSTRNtm': False,
#   '11DOCRTSTRNtr': False,
#   '13DAMPPOX': False,
#   '1MNCAMti': False,
#   '1PPDCRp': False,
#   '24_25DHVITD2t': False,
#   '24_25DHVITD2tm': False,
#   '24_25DHVITD3t': False,
#   '24_25DHVITD3tm': False,
#   '24_25VITD2Hm': False,
#   '24_25VITD3Hm': False,
#   '24NPHte': False,
#   '25HVITD2t': False,
#   '25HVITD2tin': False,
#   '25HVITD2tin_m': False,
#   '25HVITD2tm': False,
#   '25HVITD3t': False,
#   '25HVITD3tin_m': False,
#   '25HVITD3tm': False,
#   '25VITD2Hm': False,
#   '25VITD3Hm': False,
#   '2AMACHYD': False,
#   '2AMACSULT': False,
#   '2AMADPTm': False,
#   '2DR1PP': False,
#   '2HBO': False,
#   '2HBt2': False,
#   '2HCO3_NAt': False,
#   '2MCITt': False,
#   '2OXOADOXm': False,
#   '2OXOADPTm': False,
#   '34DHOXPEGOX': False,
#   '34DHOXPEGt': False,
#   '34DHPHAMT': False,
#   '34DHPHEt': False,
#   '34DHPLACOX': False,
#   '34DHPLACOX_NADP_': False,
#   '34DHXMANDACOX': False,
#   '34DHXMANDACOX_NADP_': False,
#   '34HPLFM': False,
#   '34HPPOR': False,
#   '35CGMPtn': False,
#   '3AIBTm': False,
#   '3AIBtmi': False,
#   '3DPHBH1': False,
#   '3DPHBH2': False,
#   '3DSPHR': False,
#   '3HAO': False,
#   '3HBCDm': False,
#   '3HBCOAHLm': False,
#   '3HKYNAKGAT': False,
#   '3HLYTCL': False,
#   '3HXKYNDCL': False,
#   '3HXKYNOXDA': False,
#   '3M4HDXPAC': False,
#   '3MLDAt': False,
#   '3MOBt2im': False,
#   '3MOPt2im': False,
#   '3MOX4HOXPGALDOX': False,
#   '3MOX4HOXPGALDOX_NADP_': False,
#   '3MOXTYROX': False,
#   '3SALAASPm': False,
#   '3SALACBOXL': False,
#   '3SALAOX': False,
#   '3SALATAi': False,
#   '3SALATAim': False,
#   '3SPYRSP': False,
#   '3SPYRSPm': False,
#   '41R1H2MAE12BOOX': False,
#   '41R2A1H12BOOX': False,
#   '42A12BOOX': False,
#   '4ABUTtm': False,
#   '4HBZCOAFm': False,
#   '4HBZFm': False,
#   '4HDEBRISOQUINEte': False,
#   '4HGLSDm': False,
#   '4HOXPACDOX_NADP_': False,
#   '4MOPt2im': False,
#   '4MPTNLte': False,
#   '4MPTNLtm': False,
#   '4MTOLBUTAMIDEte': False,
#   '4NPHSFte': False,
#   '4NPHSULT': False,
#   '4NPHte': False,
#   '4PYRDX': False,
#   '5ADTSTSTERONEGLCte': False,
#   '5ADTSTSTERONEGLCtr': False,
#   '5ADTSTSTERONESte': False,
#   '5ADTSTSTERONESULT': False,
#   '5ADTSTSTERONEte': False,
#   '5ADTSTSTERONEtr': False,
#   '5AOPtm': False,
#   '5DHFtl': False,
#   '5FTHFt2': False,
#   '5HLTDL': False,
#   '5HOMEPRAZOLEte': False,
#   '5HOXINDACTO2OX': False,
#   '5HOXINOXDA': False,
#   '5HTRPDOX': False,
#   '5HTRPVESSEC': False,
#   '5HXKYNDCL': False,
#   '5HXKYNOXDA': False,
#   '5MTHFt': False,
#   '5MTHFt2': False,
#   '5THFtl': False,
#   '5THFtm': False,
#   '6DHFtl': False,
#   '6DHFtm': False,
#   '6HTSTSTERONEte': False,
#   '6HTSTSTERONEtr': False,
#   '6THFtl': False,
#   '6THFtm': False,
#   '7DHCHSTEROLtr': False,
#   '7DHFtl': False,
#   '7DHFtm': False,
#   '7THFtl': False,
#   '7THFtm': False,
#   'A_MANASEly': False,
#   'A4GALTc': False,
#   'A4GALTg': False,
#   'A4GNT1g': False,
#   'A4GNT2g': False,
#   'AACTOOR': False,
#   'AACTtm': False,
#   'AASAD3m': False,
#   'AATAi': False,
#   'ABO1g': False,
#   'ABO2g': False,
#   'ABO3g': False,
#   'ABO4g': False,
#   'ABO5g': False,
#   'ABO6g': False,
#   'ABO7g': False,
#   'ABO8g': False,
#   'ABO9g': False,
#   'ABTArm': False,
#   'ABTD': False,
#   'ABTti': False,
#   'ABUTt4_2_r': False,
#   'ACACT10m': False,
#   'ACACT1rm': False,
#   'ACACT1x': False,
#   'ACACt2m': False,
#   'ACACT4p': False,
#   'ACACT5p': False,
#   'ACACT6p': False,
#   'ACACT7p': False,
#   'ACACT8p': False,
#   'ACACT9p': False,
#   'ACACtx': False,
#   'ACALDtm': False,
#   'ACALDtr': False,
#   'ACALDtx': False,
#   'ACCOACm': False,
#   'ACCOAgt': False,
#   'ACCOALm': False,
#   'ACCOAtn': False,
#   'ACCOAtr': False,
#   'ACETONEt2': False,
#   'ACETONEt2m': False,
#   'ACGAGBSIDEtg': False,
#   'ACGAGBSIDEtl': False,
#   'ACGALFUCGALACGALFUC12GAL14ACGLCGALGLUSIDEte': False,
#   'ACGALFUCGALACGALFUC12GAL14ACGLCGALGLUSIDEtg': False,
#   'ACGALFUCGALACGALFUCGALACGLCGAL14ACGLCGALGLUSIDEte': False,
#   'ACGALFUCGALACGALFUCGALACGLCGAL14ACGLCGALGLUSIDEtg': False,
#   'ACGALK': False,
#   'ACGALK2': False,
#   'ACGALtlg': False,
#   'ACGALtly': False,
#   'ACGAM6PSi': False,
#   'ACGAMK': False,
#   'ACGAMPM': False,
#   'ACGAMtly': False,
#   'ACGBGBSIDEtg': False,
#   'ACGBGBSIDEtl': False,
#   'ACGSm': False,
#   'ACHEe': False,
#   'ACHtn': False,
#   'ACHVESSEC': False,
#   'ACITL': False,
#   'ACN13ACNGALGBSIDEte': False,
#   'ACN13ACNGALGBSIDEtg': False,
#   'ACN23ACNGALGBSIDEte': False,
#   'ACN23ACNGALGBSIDEtg': False,
#   'ACNACNGAL14ACGLCGALGLUSIDEte': False,
#   'ACNACNGAL14ACGLCGALGLUSIDEtg': False,
#   'ACNACNGALGBSIDEte': False,
#   'ACNACNGALGBSIDEtg': False,
#   'ACNAM9PL': False,
#   'ACNAM9PL2': False,
#   'ACNAMlt': False,
#   'ACNAMPH': False,
#   'ACNAMtn': False,
#   'ACNGALACGLCGAL14ACGLCGALGLUSIDEte': False,
#   'ACNGALACGLCGAL14ACGLCGALGLUSIDEtg': False,
#   'ACNMLr': False,
#   'ACOAD10m': False,
#   'ACOAD1fm': False,
#   'ACOAD8m': False,
#   'ACOAD9m': False,
#   'ACOAHi': False,
#   'ACOAO7p': False,
#   'ACODA': False,
#   'ACONTm': False,
#   'ACOX22x': False,
#   'ACOX2x': False,
#   'ACP1_FMN_': False,
#   'ACRNtm': False,
#   'ACS2': False,
#   'ACSm': False,
#   'ACSRTNMT': False,
#   'ACt2m': False,
#   'ACt2r': False,
#   'ACtg': False,
#   'ACTLMO': False,
#   'ACTNMO': False,
#   'ADA': False,
#   'ADAe': False,
#   'ADCim': False,
#   'ADEt': False,
#   'ADHAPtx': False,
#   'ADK1m': False,
#   'ADK3': False,
#   'ADK3m': False,
#   'ADKd': False,
#   'ADMDC': False,
#   'ADNCYC': False,
#   'ADNK1m': False,
#   'ADNt': False,
#   'ADNt4': False,
#   'ADNtl': False,
#   'ADNtm': False,
#   'ADPMAN': False,
#   'ADPRIBt': False,
#   'ADPtx': False,
#   'ADRNCOAtx': False,
#   'ADRNCPT1': False,
#   'ADRNCPT2': False,
#   'ADRNCRNt': False,
#   'ADRNLPVESSEC': False,
#   'ADRNt': False,
#   'ADSK': False,
#   'ADSL1': False,
#   'ADSL2': False,
#   'AFLATOXINte': False,
#   'AG13T10g': False,
#   'AG13T11g': False,
#   'AG13T12g': False,
#   'AG13T13g': False,
#   'AG13T14g': False,
#   'AG13T15g': False,
#   'AG13T16g': False,
#   'AG13T17g': False,
#   'AG13T18g': False,
#   'AG13T1g': False,
#   'AG13T2g': False,
#   'AG13T3g': False,
#   'AG13T4g': False,
#   'AG13T5g': False,
#   'AG13T6g': False,
#   'AG13T7g': False,
#   'AG13T8g': False,
#   'AG13T9g': False,
#   'AGLPC': False,
#   'AGLPH': False,
#   'AGLPT': False,
#   'AGMTm': False,
#   'AGPAT1': False,
#   'AGTim': False,
#   'AGTix': False,
#   'AHANDROSTANGLCte': False,
#   'AHANDROSTANGLCtr': False,
#   'AHCYStr': False,
#   'AHEXASE2ly': False,
#   'AHEXASEly': False,
#   'AIRCr': False,
#   'AKGDm': False,
#   'AKGMALtm': False,
#   'AKGt4_3': False,
#   'AKGtp': False,
#   'AKR1C1': False,
#   'AKR1C41': False,
#   'AKR1C42': False,
#   'AKR1D': False,
#   'AKR1D2': False,
#   'ALAASNNaEx': False,
#   'ALACYSNaEx': False,
#   'ALADGLNexR': False,
#   'ALADGLYexR': False,
#   'ALAGLNexR': False,
#   'ALAGLNNaEx': False,
#   'ALAGLYexR': False,
#   'ALASERNaEx': False,
#   'ALASm': False,
#   'ALAt2rL': False,
#   'ALAt4': False,
#   'ALATA_L': False,
#   'ALATHRNaEx': False,
#   'ALAtN1': False,
#   'ALCD21_D': False,
#   'ALCD21_L': False,
#   'ALCD22_D': False,
#   'ALCD22_L': False,
#   'ALCD2if': False,
#   'ALCD2yf': False,
#   'ALDD20x': False,
#   'ALDD20xm': False,
#   'ALDD21': False,
#   'ALDD2xm': False,
#   'ALDD2y': False,
#   'ALDSTRNte': False,
#   'ALDSTRNtm': False,
#   'ALOX12': False,
#   'ALOX15': False,
#   'ALOX5': False,
#   'ALOX52': False,
#   'ALR2': False,
#   'ALR3': False,
#   'AMACR2p': False,
#   'AMACRp': False,
#   'AMCOXO': False,
#   'AMETr': False,
#   'AMETt2m': False,
#   'AMPDA': False,
#   'AMPTASECGe': False,
#   'AMPtp': False,
#   'AMY1e': False,
#   'AMY2e': False,
#   'ANDRSTRNGLCte': False,
#   'ANDRSTRNGLCtr': False,
#   'ANDRSTRNte': False,
#   'ANDRSTRNtr': False,
#   'ANTIPYRENEte': False,
#   'AOBUTDsm': False,
#   'APAT2rm': False,
#   'APNNOXte': False,
#   'APOCF': False,
#   'APOCFm': False,
#   'APOC_LYS_BTNP': False,
#   'APOC_LYS_BTNPm': False,
#   'APPNNte': False,
#   'APRTO2': False,
#   'ARAB_Lt': False,
#   'ARABR': False,
#   'ARACHCOAtx': False,
#   'ARACHCPT1': False,
#   'ARACHCPT2': False,
#   'ARACHCRNt': False,
#   'ARACHDCOAtx': False,
#   'ARACHDt2': False,
#   'ARACHDtr': False,
#   'ARACHt': False,
#   'ARGDCm': False,
#   'ARGLYSex': False,
#   'ARGNm': False,
#   'ARGSS': False,
#   'ARGt4': False,
#   'ARGtm': False,
#   'ARSA': False,
#   'ARTCOAL1': False,
#   'ARTCOAL2': False,
#   'ARTCOAL3': False,
#   'R_group_phosphotase_1': False,
#   'R_group_phosphotase_2': False,
#   'R_group_phosphotase_3': False,
#   'ARTFR11': False,
#   'ARTFR12': False,
#   'ARTFR13': False,
#   'ARTFR202': False,
#   'ARTFR203': False,
#   'ARTFR204': False,
#   'ARTFR205': False,
#   'ARTFR206': False,
#   'ARTFR207': False,
#   'ARTFR208': False,
#   'ARTFR209': False,
#   'ARTFR210': False,
#   'ARTFR211': False,
#   'ARTFR212': False,
#   'ARTFR213': False,
#   'ARTFR31': False,
#   'ARTFR32': False,
#   'ARTFR33': False,
#   'ARTFR34': False,
#   'ARTFR41': False,
#   'ARTFR42': False,
#   'ARTFR43': False,
#   'ARTFR44': False,
#   'ARTFR45': False,
#   'ARTFR46': False,
#   'ARTFR51': False,
#   'ARTFR52': False,
#   'ARTFR53': False,
#   'ARTFR54': False,
#   'ARTFR55': False,
#   'ARTFR56': False,
#   'ARTFR57': False,
#   'ARTFR61': False,
#   'ARTPLM1': False,
#   'ARTPLM1m': False,
#   'ARTPLM2': False,
#   'ARTPLM2m': False,
#   'ARTPLM3': False,
#   'ARTPLM3m': False,
#   'ASAH1': False,
#   'ASCBOX': False,
#   'ASCBt': False,
#   'ASCBt4': False,
#   'ASNALANaEx': False,
#   'ASNCYSNaEx': False,
#   'ASNGLNNaEx': False,
#   'ASNNm': False,
#   'ASNS1': False,
#   'ASNSERNaEx': False,
#   'ASNt4': False,
#   'ASNTHRNaEx': False,
#   'ASNtm': False,
#   'ASNtN1': False,
#   'Asn_X_Ser_Thrtr': False,
#   'ASPCTr': False,
#   'ASPDt6': False,
#   'ASPDxt': False,
#   'ASPGLUm': False,
#   'ASPNATm': False,
#   'ASPt6': False,
#   'ASPTAm': False,
#   'ATP1ter': False,
#   'ATP2ter': False,
#   'ATPasel': False,
#   'ATPH1e': False,
#   'ATPH2e': False,
#   'ATPtm': False,
#   'ATPtn': False,
#   'ATPtx': False,
#   'B_MANNASEly': False,
#   'B3GALT3g': False,
#   'B3GALT41g': False,
#   'B3GALT42g': False,
#   'B3GALT43g': False,
#   'B3GALT44g': False,
#   'B3GALT5g': False,
#   'B3GALTg': False,
#   'B3GNT11g': False,
#   'B3GNT12g': False,
#   'B3GNT310g': False,
#   'B3GNT311g': False,
#   'B3GNT312g': False,
#   'B3GNT313g': False,
#   'B3GNT314g': False,
#   'B3GNT315g': False,
#   'B3GNT31g': False,
#   'B3GNT32g': False,
#   'B3GNT33g': False,
#   'B3GNT34g': False,
#   'B3GNT35g': False,
#   'B3GNT36g': False,
#   'B3GNT37g': False,
#   'B3GNT39g': False,
#   'B3GNT51g': False,
#   'BAAT1x': False,
#   'BAAT2x': False,
#   'BAAT3x': False,
#   'BAAT4x': False,
#   'BACCL': False,
#   'BACCLm': False,
#   'BALAtmr': False,
#   'BALAVECSEC': False,
#   'BAMPPALDOX': False,
#   'BBHOX': False,
#   'BCDO': False,
#   'BDHm': False,
#   'BDMT_L': False,
#   'BDMT_U': False,
#   'BETALDHxm': False,
#   'BHBt': False,
#   'BHBtm': False,
#   'BHMT': False,
#   'BILDGLCURt': False,
#   'BILDGLCURte': False,
#   'BILDGLCURtr': False,
#   'BILGLCURt': False,
#   'BILGLCURte': False,
#   'BILGLCURtr': False,
#   'BILIRED': False,
#   'BILIRUBt2': False,
#   'BILIRUBtr': False,
#   'BIOCYTtn': False,
#   'BPNT2': False,
#   'BTND1': False,
#   'BTND1n': False,
#   'BTNDe': False,
#   'BTNDm': False,
#   'BTNPL': False,
#   'BTNPLm': False,
#   'BTNt2': False,
#   'BTNt3i': False,
#   'BTNt4i': False,
#   'BTNtn': False,
#   'BUP2': False,
#   'BUTt2m': False,
#   'BZt': False,
#   'BZtr': False,
#   'C14STRr': False,
#   'C160CPT1': False,
#   'C160CPT2': False,
#   'C160CRNt': False,
#   'C161CPT1': False,
#   'C161CPT12': False,
#   'C161CPT2': False,
#   'C161CPT22': False,
#   'C161CRN2t': False,
#   'C161CRNt': False,
#   'C180CPT1': False,
#   'C180CPT2': False,
#   'C180CRNt': False,
#   'C181CPT1': False,
#   'C181CPT2': False,
#   'C181CRNt': False,
#   'C204CPT1': False,
#   'C204CPT2': False,
#   'C204CRNt': False,
#   'C226COAtx': False,
#   'C226CPT1': False,
#   'C226CPT2': False,
#   'C226CRNt': False,
#   'C3STDH1Pr': False,
#   'C3STDH1r': False,
#   'C3STKR2r': False,
#   'C4STMO1r': False,
#   'C4STMO2Pr': False,
#   'C4STMO2r': False,
#   'CAATPS': False,
#   'CAROtr': False,
#   'CARVEOLte': False,
#   'CAT2p': False,
#   'CAt7r': False,
#   'CATm': False,
#   'CATp': False,
#   'CBPPer': False,
#   'CBPSam': False,
#   'CBPter': False,
#   'CBR2': False,
#   'CDIPTr': False,
#   'CDPDAGtm': False,
#   'CDS': False,
#   'CDSm': False,
#   'CEPTC': False,
#   'CEPTE': False,
#   'CERK': False,
#   'CERT1gt': False,
#   'CERT1rt': False,
#   'CERT2gt': False,
#   'CERT2rt': False,
#   'CGLYt3_2_': False,
#   'CH25H': False,
#   'CHAT': False,
#   'CHATn': False,
#   'CHLP': False,
#   'CHLPCTD': False,
#   'CHLtm': False,
#   'CHOLATEt': False,
#   'CHOLATEt2': False,
#   'CHOLATEt3': False,
#   'CHOLD2m': False,
#   'CHOLK': False,
#   'CHOLPtg': False,
#   'CHOLPtl': False,
#   'CHOLt4': False,
#   'CHOLtg': False,
#   'CHOLtn': False,
#   'CHOLtr': False,
#   'CHOLtu': False,
#   'CHSTEROLSULT': False,
#   'CHSTEROLt1': False,
#   'CHSTEROLt2': False,
#   'CHSTEROLt3': False,
#   'CHSTEROLtg': False,
#   'CHTNASE': False,
#   'CHTNASEe': False,
#   'CITMCOAHm': False,
#   'CITMCOALm': False,
#   'CITRtm': False,
#   'CITt4_2': False,
#   'CITtam': False,
#   'CITtbm': False,
#   'CK': False,
#   'CKc': False,
#   'CLFORtex': False,
#   'CLHCO3tex2': False,
#   'CLI2tex': False,
#   'CLOHtex2': False,
#   'CLOXAtex2': False,
#   'CLPNDCOAtx': False,
#   'CLPNDCPT1': False,
#   'CLPNDCPT2': False,
#   'CLPNDCRNt': False,
#   'CLPNDt': False,
#   'CLS_hs': False,
#   'CMPACNAtg': False,
#   'CMPACNAtn': False,
#   'CMPSAS': False,
#   'CMPSASn': False,
#   'CO2ter': False,
#   'CO2tg': False,
#   'CO2tm': False,
#   'CO2tp': False,
#   'COAtg': False,
#   'COAtl': False,
#   'COAtm': False,
#   'COAtn': False,
#   'COAtp': False,
#   'COAtr': False,
#   'COKECBESr': False,
#   'COQ3m': False,
#   'COQ5m': False,
#   'COQ6m': False,
#   'COQ7m': False,
#   'CORE2GTg': False,
#   'CORE3GTg': False,
#   'CORE4GTg': False,
#   'CORE5GTg': False,
#   'CORE6GTg': False,
#   'CORE7GTg': False,
#   'CORE8GTg': False,
#   'COt': False,
#   'COUCOAFm': False,
#   'COUMARINte': False,
#   'CREATt4_2_r': False,
#   'CREATtmdiffir': False,
#   'CRMPte': False,
#   'CRNCAR3tp': False,
#   'CRNCARtp': False,
#   'CRNt': False,
#   'CRNtHa': False,
#   'CRNtim': False,
#   'CRNtuNa': False,
#   'CRNtx': False,
#   'CRTNsyn': False,
#   'CRTSLt': False,
#   'CRTSLtm': False,
#   'CRTSLtr': False,
#   'CRTSTRNt': False,
#   'CRTSTRNtm': False,
#   'CRVNCtr': False,
#   'CSAPASEly': False,
#   'CSBPASEly': False,
#   'CSCPASEly': False,
#   'CSDPASEly': False,
#   'CSEPASEly': False,
#   'CSm': False,
#   'CSNAT2m': False,
#   'CSNAT2x': False,
#   'CSNAT3x': False,
#   'CSNATer': False,
#   'CSNATm': False,
#   'CSNATp': False,
#   'CSNATr': False,
#   'CSNt': False,
#   'CSPG_At': False,
#   'CSPG_Atly': False,
#   'CSPG_Bt': False,
#   'CSPG_Btly': False,
#   'CSPG_Ct': False,
#   'CSPG_Ctly': False,
#   'CSPG_Dt': False,
#   'CSPG_Dtly': False,
#   'CSPG_Et': False,
#   'CSPG_Etly': False,
#   'CTPtn': False,
#   'CYANt': False,
#   'CYANtm': False,
#   'CYSALANaEx': False,
#   'CYSASNNaEx': False,
#   'CYSGLNNaEx': False,
#   'CYSGLTH': False,
#   'CYSGLUexR': False,
#   'CYSGLYexR': False,
#   'CYSO': False,
#   'CYSSERNaEx': False,
#   'CYSt4': False,
#   'CYSTA': False,
#   'CYStec': False,
#   'CYSTGLUex': False,
#   'CYSTHRNaEx': False,
#   'CYSTSERex': False,
#   'CYTD': False,
#   'CYTDK1': False,
#   'CYTDK2m': False,
#   'CYTDn': False,
#   'CYTDt': False,
#   'CYTDt4': False,
#   'CYTDtl': False,
#   'CYTDtm': False,
#   'CYTDtn': False,
#   'CYTK10': False,
#   'CYTK10n': False,
#   'CYTK11': False,
#   'CYTK11n': False,
#   'CYTK12': False,
#   'CYTK12n': False,
#   'CYTK13': False,
#   'CYTK13n': False,
#   'CYTK14': False,
#   'CYTK14n': False,
#   'CYTK1m': False,
#   'CYTK1n': False,
#   'CYTK2n': False,
#   'CYTK3': False,
#   'CYTK3n': False,
#   'CYTK4': False,
#   'CYTK4n': False,
#   'CYTK5': False,
#   'CYTK5n': False,
#   'CYTK6': False,
#   'CYTK6n': False,
#   'CYTK7': False,
#   'CYTK7n': False,
#   'CYTK8': False,
#   'CYTK8n': False,
#   'CYTK9': False,
#   'CYTK9n': False,
#   'D_3AIBt': False,
#   'D3AIBTm': False,
#   'DADA': False,
#   'DADAe': False,
#   'DADNK': False,
#   'DADNt4': False,
#   'DAGK_hs': False,
#   'DAGKn_hs': False,
#   'DAGt': False,
#   'DALAOXx': False,
#   'DALAt2r': False,
#   'DALAxt': False,
#   'DARGOp': False,
#   'DASCBH': False,
#   'DASCBR': False,
#   'DASPO1p': False,
#   'DATPtn': False,
#   'DCIm': False,
#   'DCK1m': False,
#   'DCK1n': False,
#   'DCK2n': False,
#   'DCSPTN1COAtx': False,
#   'DCSPTN1CPT1': False,
#   'DCSPTN1CPT2': False,
#   'DCSPTN1CRNt': False,
#   'DCSPTN1t': False,
#   'DCT': False,
#   'DCTPtn': False,
#   'DCYTD': False,
#   'DCYTDn': False,
#   'DCYTt': False,
#   'DDPGAm': False,
#   'DEBRISOQUINEt': False,
#   'DECDPtm': False,
#   'DEDOLP1_L': False,
#   'DEDOLP2_L': False,
#   'DEDOLR_L': False,
#   'DESAT16_2': False,
#   'DESAT18_10': False,
#   'DESAT18_3': False,
#   'DESAT18_4': False,
#   'DESAT18_5': False,
#   'DESAT18_6': False,
#   'DESAT18_7': False,
#   'DESAT18_8': False,
#   'DESAT18_9': False,
#   'DESAT20_1': False,
#   'DESAT20_2': False,
#   'DESAT22_1p': False,
#   'DESAT22_2p': False,
#   'DESAT24_1': False,
#   'DGAT': False,
#   'DGCHOLte': False,
#   'DGCHOLtx': False,
#   'DGK2m': False,
#   'DGNSKm': False,
#   'DGSNt': False,
#   'DGSNtm': False,
#   'DGTPtn': False,
#   'DGULND': False,
#   'DHAAt1r': False,
#   'DHAPA': False,
#   'DHCHOLESTANATEtm': False,
#   'DHCR241r': False,
#   'DHCR242r': False,
#   'DHCR243r': False,
#   'DHCR71r': False,
#   'DHCR72r': False,
#   'DHCRD1': False,
#   'DHCRD2': False,
#   'DHDPBMTm': False,
#   'DHEASt': False,
#   'DHEAStr': False,
#   'DHEASULT': False,
#   'DHEAtr': False,
#   'DHFtl': False,
#   'DHFtm': False,
#   'DHORD9': False,
#   'DHPM1': False,
#   'DHPM2': False,
#   'DHPR2': False,
#   'DIDPtn': False,
#   'DIGALSGALSIDEtg': False,
#   'DIGALSIDEtg': False,
#   'DIGALSIDEtl': False,
#   'DINt': False,
#   'DITPtn': False,
#   'DKMPPD': False,
#   'D_LACt2': False,
#   'D_LACtm': False,
#   'DLNLCGCPT1': False,
#   'DLNLCGCPT2': False,
#   'DLNLCGCRNt': False,
#   'DLNLCGt': False,
#   'DMANTIPYRINEte': False,
#   'DMATTx': False,
#   'DMGDHm': False,
#   'DMGtm': False,
#   'DMHPTCRNCPT2': False,
#   'DMHPTCRNt': False,
#   'DMHPTCRNte': False,
#   'DMNONCOACRNCPT1': False,
#   'DMNONCRNCPT2': False,
#   'DMNONCRNt': False,
#   'DNADtn': False,
#   'DNDPt10m': False,
#   'DNDPt11m': False,
#   'DNDPt12m': False,
#   'DNDPt13m': False,
#   'DNDPt14m': False,
#   'DNDPt15m': False,
#   'DNDPt16m': False,
#   'DNDPt17m': False,
#   'DNDPt18m': False,
#   'DNDPt19m': False,
#   'DNDPt1m': False,
#   'DNDPt20m': False,
#   'DNDPt21m': False,
#   'DNDPt22m': False,
#   'DNDPt23m': False,
#   'DNDPt24m': False,
#   'DNDPt25m': False,
#   'DNDPt26m': False,
#   'DNDPt27m': False,
#   'DNDPt28m': False,
#   'DNDPt29m': False,
#   'DNDPt2m': False,
#   'DNDPt30m': False,
#   'DNDPt31m': False,
#   'DNDPt32m': False,
#   'DNDPt33m': False,
#   'DNDPt34m': False,
#   'DNDPt35m': False,
#   'DNDPt36m': False,
#   'DNDPt37m': False,
#   'DNDPt38m': False,
#   'DNDPt39m': False,
#   'DNDPt3m': False,
#   'DNDPt40m': False,
#   'DNDPt41m': False,
#   'DNDPt42m': False,
#   'DNDPt43m': False,
#   'DNDPt44m': False,
#   'DNDPt45m': False,
#   'DNDPt46m': False,
#   'DNDPt47m': False,
#   'DNDPt48m': False,
#   'DNDPt49m': False,
#   'DNDPt4m': False,
#   'DNDPt50m': False,
#   'DNDPt57m': False,
#   'DNDPt58m': False,
#   'DNDPt59m': False,
#   'DNDPt5m': False,
#   'DNDPt60m': False,
#   'DNDPt61m': False,
#   'DNDPt62m': False,
#   'DNDPt63m': False,
#   'DNDPt6m': False,
#   'DNDPt7m': False,
#   'DNDPt8m': False,
#   'DNDPt9m': False,
#   'DOGULNO1': False,
#   'DOLASNT_Ler': False,
#   'DOLASNT_Uer': False,
#   'DOLDPP_Ler': False,
#   'DOLDPP_Uer': False,
#   'DOLGLCP_Lter': False,
#   'DOLGLCP_Uter': False,
#   'DOLGPP_Ler': False,
#   'DOLGPP_Uer': False,
#   'DOLICHOL_Lter': False,
#   'DOLICHOL_Uter': False,
#   'DOLK_L': False,
#   'DOLK_U': False,
#   'DOLMANP_Lter': False,
#   'DOLMANP_Uter': False,
#   'DOLP_Lter': False,
#   'DOLP_Uter': False,
#   'DOLPGT1_Ler': False,
#   'DOLPGT1_Uer': False,
#   'DOLPGT2_Ler': False,
#   'DOLPGT2_Uer': False,
#   'DOLPGT3_Ler': False,
#   'DOLPGT3_Uer': False,
#   'DOLPH_Ler': False,
#   'DOLPH_Uer': False,
#   'DOLPMT_L': False,
#   'DOLPMT_U': False,
#   'DOLPMT1_Ler': False,
#   'DOLPMT1_Uer': False,
#   'DOLPMT2_Ler': False,
#   'DOLPMT2_Uer': False,
#   'DOLPMT3_Ler': False,
#   'DOLPMT3_Uer': False,
#   'DOLPMT4_Ler': False,
#   'DOLPMT4_Uer': False,
#   'DOPABMO': False,
#   'DOPACHRMISO': False,
#   'DOPAMT': False,
#   'DOPAQNISO1': False,
#   'DOPASFt': False,
#   'DOPASULT': False,
#   'DOPAt4_2_r': False,
#   'DOPAtu': False,
#   'DOPAVESSEC': False,
#   'DORNOp': False,
#   'DPCOAtl': False,
#   'DPGase': False,
#   'DPGM': False,
#   'DPHMBDCm': False,
#   'DPMVDx': False,
#   'DPPS': False,
#   'DRIBt': False,
#   'DRPA': False,
#   'DSAT': False,
#   'DTDPtn': False,
#   'DTTPtn': False,
#   'DUDPtn': False,
#   'DUMPtn': False,
#   'DURAD': False,
#   'DURAD2': False,
#   'DURIK1': False,
#   'DURIK1m': False,
#   'DURIt': False,
#   'DURItn': False,
#   'DUTPDPm': False,
#   'DUTPDPn': False,
#   'EAFLATOXINte': False,
#   'EBASTINEOHte': False,
#   'EBASTINEOHtr': False,
#   'EBASTINEte': False,
#   'EBASTINEtr': False,
#   'EBP1r': False,
#   'EBP2r': False,
#   'ECOAH12m': False,
#   'ECOAH1m': False,
#   'ECOAH1x': False,
#   'ECOAH9m': False,
#   'EHGLAT2m': False,
#   'EHGLATm': False,
#   'EICOSTETCPT1': False,
#   'EICOSTETCPT2': False,
#   'EICOSTETCRNt': False,
#   'EICOSTETt': False,
#   'ELAIDCPT1': False,
#   'ELAIDCPT2': False,
#   'ELAIDCRNt': False,
#   'ELAIDt': False,
#   'ENGASE2ly': False,
#   'ENGASE3ly': False,
#   'ENGASEly': False,
#   'ESTRADIOLGLCt': False,
#   'ESTRADIOLGLCt2': False,
#   'ESTRADIOLGLCtr': False,
#   'ESTRADIOLt': False,
#   'ESTRADIOLtr': False,
#   'ESTRIOLGLCte': False,
#   'ESTRIOLGLCtr': False,
#   'ESTRIOLtr': False,
#   'ESTRONEGLCt': False,
#   'ESTRONEGLCtr': False,
#   'ESTRONESt': False,
#   'ESTRONESt2': False,
#   'ESTRONEtr': False,
#   'ESTSULT': False,
#   'ETF': False,
#   'ETFQO': False,
#   ...}}

# %%
# parse tasks from a previously existing JSON
# the supplied file contains tasks adapted from the publication of Richelle et. al, 2019
TASKS_PATH = 'data/nl2019_tasks_r3d_compact.json'
task_list = [t for t in JSONTaskIO().read_task(TASKS_PATH) if len((set(t.inflow_dict) |
             set(t.outflow_dict)) - set([m.id for m in task_model.metabolites])) == 0]
task_list
# Out:
# C:\Users\biosy\Documents\troppo\src\troppo\tasks\task_io.py:113: UserWarning: Key should_fail has no value. Setting default value = False
#   warnings.warn(str_msg)
# C:\Users\biosy\Documents\troppo\src\troppo\tasks\task_io.py:113: UserWarning: Key reaction_dict has no value. Setting default value = {}
#   warnings.warn(str_msg)
# C:\Users\biosy\Documents\troppo\src\troppo\tasks\task_io.py:113: UserWarning: Key flux_constraints has no value. Setting default value = {}
#   warnings.warn(str_msg)
# C:\Users\biosy\Documents\troppo\src\troppo\tasks\task_io.py:113: UserWarning: Key mandatory_activity has no value. Setting default value = []
#   warnings.warn(str_msg)
# [Task '1' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Oxidative phosphorylation via NADH-coenzyme Q oxidoreductase (COMPLEX I),
#  Task '2' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Oxidative phosphorylation via succinate-coenzyme Q oxidoreductase (COMPLEX II),
#  Task '3' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Krebs cycle - oxidative decarboxylation of pyruvate,
#  Task '4' expecting success:inflow_dict: 6 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 8 -- Krebs cycle - NADH generation,
#  Task '5' expecting success:inflow_dict: 5 ; outflow_dict: 3 ; annotations: 4 -- ATP regeneration from glucose (normoxic conditions) - glycolysis + krebs cycle,
#  Task '6' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 10 -- ATP generation from glucose (hypoxic conditions) - glycolysis,
#  Task '7' expecting failure:inflow_dict: 11 ; outflow_dict: 1 ; annotations: 4 -- ATP generation from ions,
#  Task '8' expecting success:inflow_dict: 1 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Reactive oxygen species detoxification (H2O2 to H2O),
#  Task '9' expecting success:inflow_dict: 3 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Presence of the thioredoxin system through the thioredoxin reductase activity,
#  Task '10' expecting success:inflow_dict: 8 ; outflow_dict: 10 ; annotations: 4 ; mandatory_activity: 15 -- Inosine monophosphate synthesis (IMP),
#  Task '11' expecting success:inflow_dict: 9 ; outflow_dict: 10 ; annotations: 4 ; mandatory_activity: 15 -- Cytidine triphosphate synthesis (CTP),
#  Task '12' expecting success:inflow_dict: 9 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 20 -- Guanosine triphosphate synthesis (GTP),
#  Task '13' expecting success:inflow_dict: 8 ; outflow_dict: 10 ; annotations: 4 ; mandatory_activity: 15 -- Uridine triphosphate synthesis (UTP),
#  Task '14' expecting success:inflow_dict: 9 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 22 -- Deoxyadenosine triphosphate synthesis (dATP),
#  Task '15' expecting success:inflow_dict: 10 ; outflow_dict: 12 ; annotations: 4 ; mandatory_activity: 17 -- Deoxycytidine triphosphate synthesis (dCTP),
#  Task '16' expecting success:inflow_dict: 10 ; outflow_dict: 13 ; annotations: 4 ; mandatory_activity: 21 -- Deoxyguanosine triphosphate synthesis (dGTP),
#  Task '17' expecting success:inflow_dict: 9 ; outflow_dict: 12 ; annotations: 4 ; mandatory_activity: 17 -- Deoxyuridine triphosphate synthesis (dUTP),
#  Task '18' expecting success:inflow_dict: 10 ; outflow_dict: 13 ; annotations: 4 ; mandatory_activity: 23 -- Deoxythymidine triphosphate synthesis (dTTP),
#  Task '19' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- AMP salvage from adenine,
#  Task '20' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- IMP salvage from hypoxanthine,
#  Task '21' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- GMP salvage from guanine,
#  Task '22' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 2 -- 3'-Phospho-5'-adenylyl sulfate synthesis,
#  Task '23' expecting success:inflow_dict: 6 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 6 -- Degradation of adenine to urate,
#  Task '24' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 2 -- Degradation of guanine to urate,
#  Task '25' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 4 -- Degradation of cytosine,
#  Task '26' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 3 -- Degradation of uracil,
#  Task '27' expecting success:inflow_dict: 10 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 15 -- Gluconeogenesis from pyruvate,
#  Task '28' expecting success:inflow_dict: 11 ; outflow_dict: 12 ; annotations: 4 ; mandatory_activity: 14 -- Gluconeogenesis from Lactate,
#  Task '29' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 6 -- Gluconeogenesis from Glycerol,
#  Task '30' expecting success:inflow_dict: 11 ; outflow_dict: 12 ; annotations: 4 -- Gluconeogenesis from Alanine,
#  Task '31' expecting success:inflow_dict: 6 ; outflow_dict: 7 ; annotations: 4 ; mandatory_activity: 7 -- Gluconeogenesis from Glutamine,
#  Task '32' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Ethanol to acetaldehyde,
#  Task '33' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 11 -- Glucose to lactate conversion,
#  Task '34' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Malate to pyruvate conversion,
#  Task '35' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Synthesis of fructose-6-phosphate from erythrose-4-phosphate (HMP shunt),
#  Task '36' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 5 -- Synthesis of ribose-5-phosphate,
#  Task '37' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 4 -- Synthesis of lactose,
#  Task '38' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 3 -- Glycogen biosynthesis,
#  Task '39' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 3 -- Glycogen degradation,
#  Task '40' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 3 -- Fructose degradation (to glucose-3-phosphate),
#  Task '41' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 1 -- Fructose to glucose conversion (via fructose-6-phosphate),
#  Task '42' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 2 -- UDP-glucose synthesis,
#  Task '43' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 2 -- UDP-galactose synthesis,
#  Task '44' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 4 -- UDP-glucuronate synthesis,
#  Task '45' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 2 -- GDP-L-fucose synthesis,
#  Task '46' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 2 -- Mannose degradation (to fructose-6-phosphate),
#  Task '47' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 3 -- GDP-mannose synthesis,
#  Task '48' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 7 -- UDP-N-acetyl D-galactosamine synthesis,
#  Task '49' expecting success:inflow_dict: 8 ; outflow_dict: 8 ; annotations: 4 ; mandatory_activity: 11 -- CMP-N-acetylneuraminate synthesis,
#  Task '50' expecting success:inflow_dict: 6 ; outflow_dict: 7 ; annotations: 4 ; mandatory_activity: 8 -- N-Acetylglucosamine synthesis,
#  Task '51' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 4 -- Glucuronate synthesis (via inositol),
#  Task '52' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 4 -- Glucuronate synthesis (via udp-glucose),
#  Task '53' expecting success:inflow_dict: 6 ; outflow_dict: 7 ; annotations: 4 ; mandatory_activity: 2 -- Synthesis of acetone,
#  Task '54' expecting success:inflow_dict: 6 ; outflow_dict: 7 ; annotations: 4 ; mandatory_activity: 2 -- (R)-3-Hydroxybutanoate synthesis,
#  Task '55' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 3 -- Synthesis of inositol,
#  Task '56' expecting success:inflow_dict: 5 ; outflow_dict: 7 ; annotations: 4 ; mandatory_activity: 8 -- Inositol as input for glucuronate-xylulose pathway,
#  Task '57' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Synthesis of phosphatidylinositol from inositol,
#  Task '58' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Conversion of 1-phosphatidyl-1D-myo-inositol 4,5-bisphosphate to 1D-myo-inositol 1,4,5-trisphosphate,
#  Task '59' expecting success:inflow_dict: 2 ; outflow_dict: 1 ; annotations: 4 ; mandatory_activity: 3 -- Starch degradation,
#  Task '60' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 3 -- Link between glyoxylate metabolism and pentose phosphate pathway (Xylulose to glycolate),
#  Task '61' expecting success:inflow_dict: 2 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 1 -- Synthesis of methylglyoxal,
#  Task '62' expecting success:inflow_dict: 9 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 19 -- Alanine synthesis,
#  Task '63' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Alanine degradation,
#  Task '64' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 2 -- Synthesis of alanine from glutamine,
#  Task '65' expecting success:inflow_dict: 10 ; outflow_dict: 15 ; annotations: 4 ; mandatory_activity: 7 -- Arginine synthesis,
#  Task '66' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 1 -- Arginine degradation,
#  Task '67' expecting success:inflow_dict: 7 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 8 -- Synthesis of arginine from glutamine,
#  Task '68' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 1 -- Synthesis of nitric oxide from arginine,
#  Task '69' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 2 -- Synthesis of aspartate from glutamine,
#  Task '70' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 2 -- Synthesis of creatine from arginine,
#  Task '71' expecting success:inflow_dict: 9 ; outflow_dict: 9 ; annotations: 4 ; mandatory_activity: 1 -- Asparagine synthesis,
#  Task '72' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 1 -- Asparagine degradation,
#  Task '73' expecting success:inflow_dict: 9 ; outflow_dict: 12 ; annotations: 4 ; mandatory_activity: 14 -- Aspartate synthesis,
#  Task '74' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Aspartate degradation,
#  Task '75' expecting success:inflow_dict: 3 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 2 -- Conversion of aspartate to arginine,
#  Task '76' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Conversion of aspartate to beta-alanine,
#  Task '77' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 1 -- Conversion of asparate to asparagine,
#  Task '78' expecting success:inflow_dict: 8 ; outflow_dict: 10 ; annotations: 4 ; mandatory_activity: 9 -- beta-Alanine synthesis,
#  Task '79' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- beta-Alanine degradation,
#  Task '80' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Conversion of carnosine to beta-alanine,
#  Task '81' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Beta-alanine to 3-oxopropanoate,
#  Task '82' expecting failure:inflow_dict: 6 ; outflow_dict: 6 ; annotations: 4 -- Cysteine synthesis,
#  Task '83' expecting success:inflow_dict: 5 ; outflow_dict: 9 ; annotations: 4 ; mandatory_activity: 2 -- Cysteine synthesis (need serine and methionine),
#  Task '84' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 -- Cysteine degradation,
#  Task '85' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Synthesis of cysteine from cystine,
#  Task '86' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 3 -- Synthesis of taurine from cysteine,
#  Task '87' expecting success:inflow_dict: 10 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 15 -- Glutamate synthesis,
#  Task '88' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Glutamate degradation,
#  Task '89' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 1 -- Conversion of glutamate to glutamine,
#  Task '90' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 4 -- Conversion of glutamate to proline,
#  Task '91' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 2 -- Conversion of GABA into succinate,
#  Task '92' expecting success:inflow_dict: 11 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 16 -- Glutamine synthesis,
#  Task '93' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Glutamine degradation,
#  Task '94' expecting success:inflow_dict: 6 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 8 -- Glutaminolysis (glutamine to lactate),
#  Task '95' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 2 -- Glutathionate synthesis,
#  Task '96' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 1 -- Glycine synthesis,
#  Task '97' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Glycine degradation,
#  Task '98' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 3 -- Conversion of glycine to pyruvate,
#  Task '99' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Histidine synthesis,
#  Task '100' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Histidine degradation,
#  Task '101' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 4 -- Conversion of histidine to glutamate,
#  Task '102' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Conversion of histidine to histamine,
#  Task '103' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Homocysteine synthesis,
#  Task '104' expecting success:inflow_dict: 4 ; outflow_dict: 7 ; annotations: 4 ; mandatory_activity: 4 -- Homocysteine synthesis (need methionine),
#  Task '105' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 9 -- Homocysteine degradation,
#  Task '106' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Isoleucine synthesis,
#  Task '107' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Isoleucine degradation,
#  Task '108' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Leucine synthesis,
#  Task '109' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Leucine degradation,
#  Task '110' expecting success:inflow_dict: 8 ; outflow_dict: 9 ; annotations: 4 ; mandatory_activity: 6 -- Conversion of leucine to acetyl-coA,
#  Task '111' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Lysine synthesis,
#  Task '112' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Lysine degradation,
#  Task '113' expecting success:inflow_dict: 4 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Conversion of lysine to L-Saccharopine,
#  Task '114' expecting success:inflow_dict: 6 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 6 -- Conversion of lysine to L-2-Aminoadipate,
#  Task '115' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Methionine synthesis,
#  Task '116' expecting success:inflow_dict: 11 ; outflow_dict: 15 ; annotations: 4 ; mandatory_activity: 15 -- Methionine degradation,
#  Task '117' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- S-adenosyl-L-methionine synthesis,
#  Task '118' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Ornithine degradation,
#  Task '119' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 3 -- Synthesis of ornithine from glutamine,
#  Task '120' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 4 -- Synthesis of spermidine from ornithine,
#  Task '121' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 10 -- Serine synthesis,
#  Task '122' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Serine degradation,
#  Task '123' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Phenylalanine synthesis,
#  Task '124' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 2 -- Phenylalanine degradation,
#  Task '125' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 2 -- Phenylalanine to phenylacetaldehyde,
#  Task '126' expecting success:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 ; mandatory_activity: 5 -- Phenylalanine to phenylacetyl-L-glutaminate,
#  Task '127' expecting success:inflow_dict: 3 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Phenylalanine to tyrosine,
#  Task '128' expecting success:inflow_dict: 8 ; outflow_dict: 9 ; annotations: 4 -- Proline synthesis,
#  Task '129' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Proline degradation,
#  Task '130' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 5 -- Synthesis of proline from glutamine,
#  Task '131' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Threonine synthesis,
#  Task '132' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Threonine degradation,
#  Task '133' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Tryptophan synthesis,
#  Task '134' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Tryptophan degradation,
#  Task '135' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 3 -- Synthesis of anthranilate from tryptophan,
#  Task '136' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 4 -- Synthesis of kynate from tryptophan,
#  Task '137' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Synthesis of L-kynurenine from tryptophan,
#  Task '138' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 2 -- Synthesis of N-formylanthranilate from tryptophan,
#  Task '139' expecting success:inflow_dict: 3 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 5 -- Synthesis of quinolinate from tryptophan,
#  Task '140' expecting success:inflow_dict: 4 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 2 -- Synthesis of serotonin from tryptophan,
#  Task '141' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Tyrosine synthesis,
#  Task '142' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 ; mandatory_activity: 3 -- Tyrosine synthesis (need phenylalanine),
#  Task '143' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Tyrosine degradation,
#  Task '144' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 4 -- Tyrosine to adrenaline,
#  Task '145' expecting success:inflow_dict: 3 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 2 -- Tyrosine to dopamine,
#  Task '146' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 5 -- Tyrosine to acetoacetate and fumarate,
#  Task '147' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Valine synthesis,
#  Task '148' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Valine degradation,
#  Task '149' expecting success:inflow_dict: 6 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 8 -- Valine to succinyl-coA,
#  Task '150' expecting success:inflow_dict: 7 ; outflow_dict: 7 ; annotations: 4 ; mandatory_activity: 13 -- Hydroxymethylglutaryl-CoA synthesis,
#  Task '151' expecting success:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 ; mandatory_activity: 20 -- Cholesterol synthesis,
#  Task '152' expecting success:inflow_dict: 6 ; outflow_dict: 7 ; annotations: 4 ; mandatory_activity: 13 -- Acetoacetate synthesis,
#  Task '153' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Mevalonate synthesis,
#  Task '154' expecting success:inflow_dict: 2 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 7 -- Farnesyl-pyrophosphate synthesis,
#  Task '155' expecting success:inflow_dict: 3 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 1 -- Glycerol-3-phosphate synthesis,
#  Task '156' expecting success:inflow_dict: 13 ; outflow_dict: 10 ; annotations: 4 ; mandatory_activity: 23 -- Phosphatidyl-choline synthesis,
#  Task '157' expecting success:inflow_dict: 14 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 23 -- Phosphatidyl-ethanolamine synthesis,
#  Task '158' expecting success:inflow_dict: 13 ; outflow_dict: 10 ; annotations: 4 ; mandatory_activity: 24 -- Phosphatidyl-serine synthesis,
#  Task '159' expecting success:inflow_dict: 13 ; outflow_dict: 12 ; annotations: 4 ; mandatory_activity: 22 -- Phosphatidyl-inositol synthesis,
#  Task '160' expecting success:inflow_dict: 12 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 1 -- Cardiolipin synthesis,
#  Task '161' expecting success:inflow_dict: 10 ; outflow_dict: 12 ; annotations: 4 ; mandatory_activity: 1 -- Triacylglycerol synthesis,
#  Task '162' expecting success:inflow_dict: 15 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 1 -- Sphingomyelin synthesis,
#  Task '163' expecting success:inflow_dict: 14 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 4 -- Ceramide synthesis,
#  Task '164' expecting success:inflow_dict: 5 ; outflow_dict: 8 ; annotations: 4 ; mandatory_activity: 2 -- Palmitate synthesis,
#  Task '165' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 3 -- Palmitate degradation,
#  Task '166' expecting success:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 ; mandatory_activity: 5 -- Palmitolate synthesis,
#  Task '167' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 4 -- Palmitolate degradation,
#  Task '168' expecting success:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 ; mandatory_activity: 3 -- cis-vaccenic acid synthesis,
#  Task '169' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 3 -- cis-vaccenic acid degradation,
#  Task '170' expecting success:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 ; mandatory_activity: 3 -- Elaidate synthesis,
#  Task '171' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 3 -- Elaidate degradation,
#  Task '172' expecting failure:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 -- Linolenate synthesis,
#  Task '173' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 2 -- Linolenate degradation,
#  Task '174' expecting failure:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 -- Linoleate synthesis,
#  Task '175' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 1 -- Linoleate degradation,
#  Task '176' expecting success:inflow_dict: 4 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 3 -- gamma-Linolenate synthesis,
#  Task '177' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 1 -- gamma-Linolenate degradation,
#  Task '178' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 6 -- Arachidonate synthesis,
#  Task '179' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 1 -- Arachidonate degradation,
#  Task '180' expecting success:inflow_dict: 6 ; outflow_dict: 9 ; annotations: 4 ; mandatory_activity: 12 -- Synthesis of malonyl-coa,
#  Task '181' expecting success:inflow_dict: 10 ; outflow_dict: 9 ; annotations: 4 ; mandatory_activity: 14 -- Synthesis of palmitoyl-CoA,
#  Task '182' expecting success:inflow_dict: 14 ; outflow_dict: 12 ; annotations: 4 ; mandatory_activity: 11 -- Taurochenodeoxycholate synthesis,
#  Task '183' expecting success:inflow_dict: 17 ; outflow_dict: 14 ; annotations: 4 ; mandatory_activity: 15 -- Glycochenodeoxycholate synthesis,
#  Task '184' expecting success:inflow_dict: 17 ; outflow_dict: 14 ; annotations: 4 ; mandatory_activity: 13 -- tauro-cholate synthesis,
#  Task '185' expecting success:inflow_dict: 16 ; outflow_dict: 13 ; annotations: 4 ; mandatory_activity: 13 -- glyco-cholate synthesis,
#  Task '186' expecting success:inflow_dict: 4 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 2 -- Synthesis of thromboxane from arachidonate,
#  Task '187' expecting success:inflow_dict: 12 ; outflow_dict: 12 ; annotations: 4 ; mandatory_activity: 2 -- Synthesis of galactosyl glucosyl ceramide (link with ganglioside metabolism),
#  Task '188' expecting success:inflow_dict: 11 ; outflow_dict: 10 ; annotations: 4 ; mandatory_activity: 1 -- Synthesis of glucocerebroside,
#  Task '189' expecting success:inflow_dict: 13 ; outflow_dict: 12 ; annotations: 4 ; mandatory_activity: 2 -- Synthesis of globoside (link with globoside metabolism),
#  Task '190' expecting success:inflow_dict: 4 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 2 -- NAD synthesis from nicotinamide,
#  Task '191' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 2 -- FAD synthesis,
#  Task '192' expecting success:inflow_dict: 3 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 5 -- Synthesis of coenzyme A,
#  Task '193' expecting success:inflow_dict: 9 ; outflow_dict: 11 ; annotations: 4 ; mandatory_activity: 14 -- Synthesis of ubiquinone from tyrosine,
#  Task '194' expecting success:inflow_dict: 3 ; outflow_dict: 2 ; annotations: 4 ; mandatory_activity: 2 -- Tetrahydrofolate synthesis,
#  Task '195' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Pyridoxal-phosphate synthesis,
#  Task '196' expecting success:inflow_dict: 5 ; outflow_dict: 8 ; annotations: 4 ; mandatory_activity: 2 -- Synthesis of bilirubin,
#  Task '197' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 8 -- Heme synthesis,
#  Task '200' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 5 -- Degradation of n2m2nmasn,
#  Task '201' expecting success:inflow_dict: 4 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 8 -- Biosynthesis of m4mpdol_U,
#  Task '202' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 8 -- Biosynthesis of g3m8masn,
#  Task '203' expecting success:inflow_dict: 2 ; outflow_dict: 6 ; annotations: 4 ; mandatory_activity: 8 -- Degradation of s2l2fn2m2masn,
#  Task '204' expecting success:inflow_dict: 4 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 3 -- Biosynthesis of core2 (beta-D-Galactosyl-1,3-(N-acetyl-beta-D-glucosaminyl-1,6)-N-acetyl-D-galactosaminyl-R),
#  Task '205' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 3 -- Biosynthesis of core4 (N-Acetyl-beta-D-glucosaminyl-1,6-(N-acetyl-beta-D-glucosaminyl-1,3)-N-acetyl-D-galactosaminyl-R),
#  Task '206' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 ; mandatory_activity: 1 -- Biosynthesis of Tn_antigen (Glycoprotein N-acetyl-D-galactosamine),
#  Task '207' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 11 -- Keratan sulfate biosynthesis from O-glycan (core 2-linked),
#  Task '208' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 11 -- Keratan sulfate biosynthesis from O-glycan (core 4-linked),
#  Task '209' expecting success:inflow_dict: 2 ; outflow_dict: 8 ; annotations: 4 ; mandatory_activity: 31 -- Keratan sulfate degradation,
#  Task '210' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 ; mandatory_activity: 37 -- Keratan sulfate biosynthesis from N-glycan]

# %%
for task in task_list:
    task.inflow_dict = {k: v if k not in task.outflow_dict.keys() else [-1000, 1000] for k, v in
                        task.inflow_dict.items()}
    task.outflow_dict = {k: v for k, v in task.outflow_dict.items()
                         if k not in task.inflow_dict.items()}
for task in task_list:
    task.mandatory_activity = []

task_list
# Out:
# [Task '1' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Oxidative phosphorylation via NADH-coenzyme Q oxidoreductase (COMPLEX I),
#  Task '2' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 -- Oxidative phosphorylation via succinate-coenzyme Q oxidoreductase (COMPLEX II),
#  Task '3' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Krebs cycle - oxidative decarboxylation of pyruvate,
#  Task '4' expecting success:inflow_dict: 6 ; outflow_dict: 6 ; annotations: 4 -- Krebs cycle - NADH generation,
#  Task '5' expecting success:inflow_dict: 5 ; outflow_dict: 3 ; annotations: 4 -- ATP regeneration from glucose (normoxic conditions) - glycolysis + krebs cycle,
#  Task '6' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 -- ATP generation from glucose (hypoxic conditions) - glycolysis,
#  Task '7' expecting failure:inflow_dict: 11 ; outflow_dict: 1 ; annotations: 4 -- ATP generation from ions,
#  Task '8' expecting success:inflow_dict: 1 ; outflow_dict: 2 ; annotations: 4 -- Reactive oxygen species detoxification (H2O2 to H2O),
#  Task '9' expecting success:inflow_dict: 3 ; outflow_dict: 2 ; annotations: 4 -- Presence of the thioredoxin system through the thioredoxin reductase activity,
#  Task '10' expecting success:inflow_dict: 8 ; outflow_dict: 10 ; annotations: 4 -- Inosine monophosphate synthesis (IMP),
#  Task '11' expecting success:inflow_dict: 9 ; outflow_dict: 10 ; annotations: 4 -- Cytidine triphosphate synthesis (CTP),
#  Task '12' expecting success:inflow_dict: 9 ; outflow_dict: 11 ; annotations: 4 -- Guanosine triphosphate synthesis (GTP),
#  Task '13' expecting success:inflow_dict: 8 ; outflow_dict: 10 ; annotations: 4 -- Uridine triphosphate synthesis (UTP),
#  Task '14' expecting success:inflow_dict: 9 ; outflow_dict: 11 ; annotations: 4 -- Deoxyadenosine triphosphate synthesis (dATP),
#  Task '15' expecting success:inflow_dict: 10 ; outflow_dict: 12 ; annotations: 4 -- Deoxycytidine triphosphate synthesis (dCTP),
#  Task '16' expecting success:inflow_dict: 10 ; outflow_dict: 13 ; annotations: 4 -- Deoxyguanosine triphosphate synthesis (dGTP),
#  Task '17' expecting success:inflow_dict: 9 ; outflow_dict: 12 ; annotations: 4 -- Deoxyuridine triphosphate synthesis (dUTP),
#  Task '18' expecting success:inflow_dict: 10 ; outflow_dict: 13 ; annotations: 4 -- Deoxythymidine triphosphate synthesis (dTTP),
#  Task '19' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 -- AMP salvage from adenine,
#  Task '20' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 -- IMP salvage from hypoxanthine,
#  Task '21' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 -- GMP salvage from guanine,
#  Task '22' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 -- 3'-Phospho-5'-adenylyl sulfate synthesis,
#  Task '23' expecting success:inflow_dict: 6 ; outflow_dict: 5 ; annotations: 4 -- Degradation of adenine to urate,
#  Task '24' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 -- Degradation of guanine to urate,
#  Task '25' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 -- Degradation of cytosine,
#  Task '26' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 -- Degradation of uracil,
#  Task '27' expecting success:inflow_dict: 10 ; outflow_dict: 11 ; annotations: 4 -- Gluconeogenesis from pyruvate,
#  Task '28' expecting success:inflow_dict: 11 ; outflow_dict: 12 ; annotations: 4 -- Gluconeogenesis from Lactate,
#  Task '29' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Gluconeogenesis from Glycerol,
#  Task '30' expecting success:inflow_dict: 11 ; outflow_dict: 12 ; annotations: 4 -- Gluconeogenesis from Alanine,
#  Task '31' expecting success:inflow_dict: 6 ; outflow_dict: 7 ; annotations: 4 -- Gluconeogenesis from Glutamine,
#  Task '32' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Ethanol to acetaldehyde,
#  Task '33' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Glucose to lactate conversion,
#  Task '34' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Malate to pyruvate conversion,
#  Task '35' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 -- Synthesis of fructose-6-phosphate from erythrose-4-phosphate (HMP shunt),
#  Task '36' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 -- Synthesis of ribose-5-phosphate,
#  Task '37' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Synthesis of lactose,
#  Task '38' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Glycogen biosynthesis,
#  Task '39' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Glycogen degradation,
#  Task '40' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Fructose degradation (to glucose-3-phosphate),
#  Task '41' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 -- Fructose to glucose conversion (via fructose-6-phosphate),
#  Task '42' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- UDP-glucose synthesis,
#  Task '43' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- UDP-galactose synthesis,
#  Task '44' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 -- UDP-glucuronate synthesis,
#  Task '45' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- GDP-L-fucose synthesis,
#  Task '46' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Mannose degradation (to fructose-6-phosphate),
#  Task '47' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- GDP-mannose synthesis,
#  Task '48' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- UDP-N-acetyl D-galactosamine synthesis,
#  Task '49' expecting success:inflow_dict: 8 ; outflow_dict: 8 ; annotations: 4 -- CMP-N-acetylneuraminate synthesis,
#  Task '50' expecting success:inflow_dict: 6 ; outflow_dict: 7 ; annotations: 4 -- N-Acetylglucosamine synthesis,
#  Task '51' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 -- Glucuronate synthesis (via inositol),
#  Task '52' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Glucuronate synthesis (via udp-glucose),
#  Task '53' expecting success:inflow_dict: 6 ; outflow_dict: 7 ; annotations: 4 -- Synthesis of acetone,
#  Task '54' expecting success:inflow_dict: 6 ; outflow_dict: 7 ; annotations: 4 -- (R)-3-Hydroxybutanoate synthesis,
#  Task '55' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 -- Synthesis of inositol,
#  Task '56' expecting success:inflow_dict: 5 ; outflow_dict: 7 ; annotations: 4 -- Inositol as input for glucuronate-xylulose pathway,
#  Task '57' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Synthesis of phosphatidylinositol from inositol,
#  Task '58' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Conversion of 1-phosphatidyl-1D-myo-inositol 4,5-bisphosphate to 1D-myo-inositol 1,4,5-trisphosphate,
#  Task '59' expecting success:inflow_dict: 2 ; outflow_dict: 1 ; annotations: 4 -- Starch degradation,
#  Task '60' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 -- Link between glyoxylate metabolism and pentose phosphate pathway (Xylulose to glycolate),
#  Task '61' expecting success:inflow_dict: 2 ; outflow_dict: 4 ; annotations: 4 -- Synthesis of methylglyoxal,
#  Task '62' expecting success:inflow_dict: 9 ; outflow_dict: 11 ; annotations: 4 -- Alanine synthesis,
#  Task '63' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Alanine degradation,
#  Task '64' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Synthesis of alanine from glutamine,
#  Task '65' expecting success:inflow_dict: 10 ; outflow_dict: 15 ; annotations: 4 -- Arginine synthesis,
#  Task '66' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Arginine degradation,
#  Task '67' expecting success:inflow_dict: 7 ; outflow_dict: 11 ; annotations: 4 -- Synthesis of arginine from glutamine,
#  Task '68' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 -- Synthesis of nitric oxide from arginine,
#  Task '69' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Synthesis of aspartate from glutamine,
#  Task '70' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 -- Synthesis of creatine from arginine,
#  Task '71' expecting success:inflow_dict: 9 ; outflow_dict: 9 ; annotations: 4 -- Asparagine synthesis,
#  Task '72' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Asparagine degradation,
#  Task '73' expecting success:inflow_dict: 9 ; outflow_dict: 12 ; annotations: 4 -- Aspartate synthesis,
#  Task '74' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Aspartate degradation,
#  Task '75' expecting success:inflow_dict: 3 ; outflow_dict: 5 ; annotations: 4 -- Conversion of aspartate to arginine,
#  Task '76' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 -- Conversion of aspartate to beta-alanine,
#  Task '77' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 -- Conversion of asparate to asparagine,
#  Task '78' expecting success:inflow_dict: 8 ; outflow_dict: 10 ; annotations: 4 -- beta-Alanine synthesis,
#  Task '79' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- beta-Alanine degradation,
#  Task '80' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 -- Conversion of carnosine to beta-alanine,
#  Task '81' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 -- Beta-alanine to 3-oxopropanoate,
#  Task '82' expecting failure:inflow_dict: 6 ; outflow_dict: 6 ; annotations: 4 -- Cysteine synthesis,
#  Task '83' expecting success:inflow_dict: 5 ; outflow_dict: 9 ; annotations: 4 -- Cysteine synthesis (need serine and methionine),
#  Task '84' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 -- Cysteine degradation,
#  Task '85' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 -- Synthesis of cysteine from cystine,
#  Task '86' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Synthesis of taurine from cysteine,
#  Task '87' expecting success:inflow_dict: 10 ; outflow_dict: 11 ; annotations: 4 -- Glutamate synthesis,
#  Task '88' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Glutamate degradation,
#  Task '89' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 -- Conversion of glutamate to glutamine,
#  Task '90' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 -- Conversion of glutamate to proline,
#  Task '91' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 -- Conversion of GABA into succinate,
#  Task '92' expecting success:inflow_dict: 11 ; outflow_dict: 11 ; annotations: 4 -- Glutamine synthesis,
#  Task '93' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Glutamine degradation,
#  Task '94' expecting success:inflow_dict: 6 ; outflow_dict: 6 ; annotations: 4 -- Glutaminolysis (glutamine to lactate),
#  Task '95' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 -- Glutathionate synthesis,
#  Task '96' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Glycine synthesis,
#  Task '97' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Glycine degradation,
#  Task '98' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Conversion of glycine to pyruvate,
#  Task '99' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Histidine synthesis,
#  Task '100' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Histidine degradation,
#  Task '101' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Conversion of histidine to glutamate,
#  Task '102' expecting success:inflow_dict: 2 ; outflow_dict: 2 ; annotations: 4 -- Conversion of histidine to histamine,
#  Task '103' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Homocysteine synthesis,
#  Task '104' expecting success:inflow_dict: 4 ; outflow_dict: 7 ; annotations: 4 -- Homocysteine synthesis (need methionine),
#  Task '105' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 -- Homocysteine degradation,
#  Task '106' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Isoleucine synthesis,
#  Task '107' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Isoleucine degradation,
#  Task '108' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Leucine synthesis,
#  Task '109' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Leucine degradation,
#  Task '110' expecting success:inflow_dict: 8 ; outflow_dict: 9 ; annotations: 4 -- Conversion of leucine to acetyl-coA,
#  Task '111' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Lysine synthesis,
#  Task '112' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Lysine degradation,
#  Task '113' expecting success:inflow_dict: 4 ; outflow_dict: 3 ; annotations: 4 -- Conversion of lysine to L-Saccharopine,
#  Task '114' expecting success:inflow_dict: 6 ; outflow_dict: 6 ; annotations: 4 -- Conversion of lysine to L-2-Aminoadipate,
#  Task '115' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Methionine synthesis,
#  Task '116' expecting success:inflow_dict: 11 ; outflow_dict: 15 ; annotations: 4 -- Methionine degradation,
#  Task '117' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- S-adenosyl-L-methionine synthesis,
#  Task '118' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Ornithine degradation,
#  Task '119' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Synthesis of ornithine from glutamine,
#  Task '120' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 -- Synthesis of spermidine from ornithine,
#  Task '121' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 -- Serine synthesis,
#  Task '122' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Serine degradation,
#  Task '123' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Phenylalanine synthesis,
#  Task '124' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Phenylalanine degradation,
#  Task '125' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 -- Phenylalanine to phenylacetaldehyde,
#  Task '126' expecting success:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 -- Phenylalanine to phenylacetyl-L-glutaminate,
#  Task '127' expecting success:inflow_dict: 3 ; outflow_dict: 2 ; annotations: 4 -- Phenylalanine to tyrosine,
#  Task '128' expecting success:inflow_dict: 8 ; outflow_dict: 9 ; annotations: 4 -- Proline synthesis,
#  Task '129' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Proline degradation,
#  Task '130' expecting success:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Synthesis of proline from glutamine,
#  Task '131' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Threonine synthesis,
#  Task '132' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Threonine degradation,
#  Task '133' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Tryptophan synthesis,
#  Task '134' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Tryptophan degradation,
#  Task '135' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 -- Synthesis of anthranilate from tryptophan,
#  Task '136' expecting success:inflow_dict: 3 ; outflow_dict: 4 ; annotations: 4 -- Synthesis of kynate from tryptophan,
#  Task '137' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Synthesis of L-kynurenine from tryptophan,
#  Task '138' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Synthesis of N-formylanthranilate from tryptophan,
#  Task '139' expecting success:inflow_dict: 3 ; outflow_dict: 5 ; annotations: 4 -- Synthesis of quinolinate from tryptophan,
#  Task '140' expecting success:inflow_dict: 4 ; outflow_dict: 3 ; annotations: 4 -- Synthesis of serotonin from tryptophan,
#  Task '141' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Tyrosine synthesis,
#  Task '142' expecting success:inflow_dict: 4 ; outflow_dict: 4 ; annotations: 4 -- Tyrosine synthesis (need phenylalanine),
#  Task '143' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Tyrosine degradation,
#  Task '144' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 -- Tyrosine to adrenaline,
#  Task '145' expecting success:inflow_dict: 3 ; outflow_dict: 2 ; annotations: 4 -- Tyrosine to dopamine,
#  Task '146' expecting success:inflow_dict: 4 ; outflow_dict: 5 ; annotations: 4 -- Tyrosine to acetoacetate and fumarate,
#  Task '147' expecting failure:inflow_dict: 5 ; outflow_dict: 6 ; annotations: 4 -- Valine synthesis,
#  Task '148' expecting success:inflow_dict: 5 ; outflow_dict: 4 ; annotations: 4 -- Valine degradation,
#  Task '149' expecting success:inflow_dict: 6 ; outflow_dict: 6 ; annotations: 4 -- Valine to succinyl-coA,
#  Task '150' expecting success:inflow_dict: 7 ; outflow_dict: 7 ; annotations: 4 -- Hydroxymethylglutaryl-CoA synthesis,
#  Task '151' expecting success:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 -- Cholesterol synthesis,
#  Task '152' expecting success:inflow_dict: 6 ; outflow_dict: 7 ; annotations: 4 -- Acetoacetate synthesis,
#  Task '153' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Mevalonate synthesis,
#  Task '154' expecting success:inflow_dict: 2 ; outflow_dict: 6 ; annotations: 4 -- Farnesyl-pyrophosphate synthesis,
#  Task '155' expecting success:inflow_dict: 3 ; outflow_dict: 2 ; annotations: 4 -- Glycerol-3-phosphate synthesis,
#  Task '156' expecting success:inflow_dict: 13 ; outflow_dict: 10 ; annotations: 4 -- Phosphatidyl-choline synthesis,
#  Task '157' expecting success:inflow_dict: 14 ; outflow_dict: 11 ; annotations: 4 -- Phosphatidyl-ethanolamine synthesis,
#  Task '158' expecting success:inflow_dict: 13 ; outflow_dict: 10 ; annotations: 4 -- Phosphatidyl-serine synthesis,
#  Task '159' expecting success:inflow_dict: 13 ; outflow_dict: 12 ; annotations: 4 -- Phosphatidyl-inositol synthesis,
#  Task '160' expecting success:inflow_dict: 12 ; outflow_dict: 11 ; annotations: 4 -- Cardiolipin synthesis,
#  Task '161' expecting success:inflow_dict: 10 ; outflow_dict: 12 ; annotations: 4 -- Triacylglycerol synthesis,
#  Task '162' expecting success:inflow_dict: 15 ; outflow_dict: 11 ; annotations: 4 -- Sphingomyelin synthesis,
#  Task '163' expecting success:inflow_dict: 14 ; outflow_dict: 11 ; annotations: 4 -- Ceramide synthesis,
#  Task '164' expecting success:inflow_dict: 5 ; outflow_dict: 8 ; annotations: 4 -- Palmitate synthesis,
#  Task '165' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 -- Palmitate degradation,
#  Task '166' expecting success:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 -- Palmitolate synthesis,
#  Task '167' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 -- Palmitolate degradation,
#  Task '168' expecting success:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 -- cis-vaccenic acid synthesis,
#  Task '169' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 -- cis-vaccenic acid degradation,
#  Task '170' expecting success:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 -- Elaidate synthesis,
#  Task '171' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 -- Elaidate degradation,
#  Task '172' expecting failure:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 -- Linolenate synthesis,
#  Task '173' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 -- Linolenate degradation,
#  Task '174' expecting failure:inflow_dict: 6 ; outflow_dict: 8 ; annotations: 4 -- Linoleate synthesis,
#  Task '175' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 -- Linoleate degradation,
#  Task '176' expecting success:inflow_dict: 4 ; outflow_dict: 3 ; annotations: 4 -- gamma-Linolenate synthesis,
#  Task '177' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 -- gamma-Linolenate degradation,
#  Task '178' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 -- Arachidonate synthesis,
#  Task '179' expecting success:inflow_dict: 7 ; outflow_dict: 6 ; annotations: 4 -- Arachidonate degradation,
#  Task '180' expecting success:inflow_dict: 6 ; outflow_dict: 9 ; annotations: 4 -- Synthesis of malonyl-coa,
#  Task '181' expecting success:inflow_dict: 10 ; outflow_dict: 9 ; annotations: 4 -- Synthesis of palmitoyl-CoA,
#  Task '182' expecting success:inflow_dict: 14 ; outflow_dict: 12 ; annotations: 4 -- Taurochenodeoxycholate synthesis,
#  Task '183' expecting success:inflow_dict: 17 ; outflow_dict: 14 ; annotations: 4 -- Glycochenodeoxycholate synthesis,
#  Task '184' expecting success:inflow_dict: 17 ; outflow_dict: 14 ; annotations: 4 -- tauro-cholate synthesis,
#  Task '185' expecting success:inflow_dict: 16 ; outflow_dict: 13 ; annotations: 4 -- glyco-cholate synthesis,
#  Task '186' expecting success:inflow_dict: 4 ; outflow_dict: 3 ; annotations: 4 -- Synthesis of thromboxane from arachidonate,
#  Task '187' expecting success:inflow_dict: 12 ; outflow_dict: 12 ; annotations: 4 -- Synthesis of galactosyl glucosyl ceramide (link with ganglioside metabolism),
#  Task '188' expecting success:inflow_dict: 11 ; outflow_dict: 10 ; annotations: 4 -- Synthesis of glucocerebroside,
#  Task '189' expecting success:inflow_dict: 13 ; outflow_dict: 12 ; annotations: 4 -- Synthesis of globoside (link with globoside metabolism),
#  Task '190' expecting success:inflow_dict: 4 ; outflow_dict: 2 ; annotations: 4 -- NAD synthesis from nicotinamide,
#  Task '191' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- FAD synthesis,
#  Task '192' expecting success:inflow_dict: 3 ; outflow_dict: 6 ; annotations: 4 -- Synthesis of coenzyme A,
#  Task '193' expecting success:inflow_dict: 9 ; outflow_dict: 11 ; annotations: 4 -- Synthesis of ubiquinone from tyrosine,
#  Task '194' expecting success:inflow_dict: 3 ; outflow_dict: 2 ; annotations: 4 -- Tetrahydrofolate synthesis,
#  Task '195' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Pyridoxal-phosphate synthesis,
#  Task '196' expecting success:inflow_dict: 5 ; outflow_dict: 8 ; annotations: 4 -- Synthesis of bilirubin,
#  Task '197' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 -- Heme synthesis,
#  Task '200' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Degradation of n2m2nmasn,
#  Task '201' expecting success:inflow_dict: 4 ; outflow_dict: 6 ; annotations: 4 -- Biosynthesis of m4mpdol_U,
#  Task '202' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 -- Biosynthesis of g3m8masn,
#  Task '203' expecting success:inflow_dict: 2 ; outflow_dict: 6 ; annotations: 4 -- Degradation of s2l2fn2m2masn,
#  Task '204' expecting success:inflow_dict: 4 ; outflow_dict: 3 ; annotations: 4 -- Biosynthesis of core2 (beta-D-Galactosyl-1,3-(N-acetyl-beta-D-glucosaminyl-1,6)-N-acetyl-D-galactosaminyl-R),
#  Task '205' expecting success:inflow_dict: 3 ; outflow_dict: 3 ; annotations: 4 -- Biosynthesis of core4 (N-Acetyl-beta-D-glucosaminyl-1,6-(N-acetyl-beta-D-glucosaminyl-1,3)-N-acetyl-D-galactosaminyl-R),
#  Task '206' expecting success:inflow_dict: 2 ; outflow_dict: 3 ; annotations: 4 -- Biosynthesis of Tn_antigen (Glycoprotein N-acetyl-D-galactosamine),
#  Task '207' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 -- Keratan sulfate biosynthesis from O-glycan (core 2-linked),
#  Task '208' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 -- Keratan sulfate biosynthesis from O-glycan (core 4-linked),
#  Task '209' expecting success:inflow_dict: 2 ; outflow_dict: 8 ; annotations: 4 -- Keratan sulfate degradation,
#  Task '210' expecting success:inflow_dict: 5 ; outflow_dict: 5 ; annotations: 4 -- Keratan sulfate biosynthesis from N-glycan]

# %%
 # tasks should be evaluated without open boundary reactions. We can easily close them on
# the COBRA model
for k in task_model.boundary:
    k.knock_out()

# get the names of all reactions in the model - this will be useful further on
all_reactions = set([r.id for r in task_model.reactions])

all_reactions
# Out:
# {'r1908',
#  'GMPtn',
#  'DOPAVESSEC',
#  'r1624',
#  'OMHDOCOSACTD',
#  'LDH_L',
#  'EX_3bcrn[e]',
#  'ACLEUtm',
#  'DESAT20_1',
#  'HMR_2644',
#  'r1571',
#  'DGTPtn',
#  '25HVITD2t',
#  'SRTNtu',
#  'r1593',
#  'DOPA4GLCURt',
#  'HC00900t1',
#  'RE2427M',
#  'AG13T17g',
#  'HMR_2193',
#  'HMR_3341',
#  'r2195',
#  'EX_ind3ac[e]',
#  'RE1827C',
#  'r0587',
#  'HMR_9642',
#  'HMR_2348',
#  'GLCAASE1ly',
#  '3TETD7ECOACRNtr',
#  'HMR_0271',
#  'HMR_9669',
#  'HMR_1739',
#  'TETDECA511ACc',
#  'CSBPASEly',
#  'HMR_6619',
#  'RE3334X',
#  'DTMPK',
#  'RE3004M',
#  'HMR_0894',
#  'HMR_0256',
#  'HMR_2793',
#  'RE2997X',
#  '3AIB_Dtm',
#  'EX_gumgchol[e]',
#  'MMALtm',
#  'HMR_1761',
#  'r1454',
#  'DASPO1p',
#  'TETDEC2CRNe',
#  'r2237',
#  'FUT95g',
#  'HMR_2650',
#  'ACMPGLUthc',
#  'HMR_4783',
#  'GLCAE1g',
#  'CE6031t',
#  'HMR_1968',
#  'HMR_2917',
#  'HMR_0428',
#  'r1608',
#  'DHEAtr',
#  'C142ACBP',
#  'EX_ethamp[e]',
#  'ARACHCPT2',
#  'RE3243C',
#  'r2312',
#  'HMR_0496',
#  '7HPVStev',
#  'r1612',
#  '4HMDZGLUChr',
#  'ADAe',
#  'TIGCRNe',
#  'HMR_1764',
#  'ESTRSABCtc',
#  'PELINETH',
#  'GDPFUCtg',
#  'HMR_3668',
#  'HMR_3059',
#  'EX_thrglntyr[e]',
#  'r1662',
#  'RE0958C',
#  'CE6247t',
#  'EX_CE1617[e]',
#  'HMR_3427',
#  'RE2318R',
#  'r0885',
#  'C6DCCACT',
#  '25HVITD3c',
#  'PAFS',
#  'EX_hestratriol[e]',
#  'HMR_0491',
#  'PS_HSter',
#  'EX_pheglnphe[e]',
#  'EX_HC01361[e]',
#  'r1547',
#  'ICDCHOLt2',
#  'BGLYtm',
#  'EX_tdchola[e]',
#  'r1692',
#  'GLCt2_2',
#  'C16DCtr',
#  'EX_HC02214[e]',
#  'r0639',
#  'UGT1A1r',
#  'HMR_8578',
#  'LSTO1r',
#  'HMR_6717',
#  'r2071',
#  'SERPHELYSt',
#  'THRSERARGr',
#  'HMR_6813',
#  'EX_thyox_L[e]',
#  'LCADim',
#  'CYTK13n',
#  'TETPENT6COAtx',
#  'RE1527X',
#  'OCDCAFATPc',
#  'r0357',
#  'EX_12htacr[e]',
#  'FUT98g',
#  'HS3ly',
#  'TETHEX3t',
#  'r0557',
#  'HCO3_CLt',
#  'r1779',
#  'FUCASEly',
#  'ADNCYC',
#  'RE3159X',
#  'LCAT56e',
#  'HMR_5154',
#  'HMR_1095',
#  'r1920',
#  'EX_alalysthr[e]',
#  'GHMT2r',
#  'r1531',
#  'P5CRm',
#  'r0242',
#  'GLNPROGLUt',
#  'HMR_3706',
#  'TCHOLAtx',
#  'ETHP',
#  'r2085',
#  'DMGtm',
#  'SMVLAChep',
#  'HMR_9608',
#  'HMR_0200',
#  'EX_5adtststerones[e]',
#  'EX_gq1b_hs[e]',
#  'PELINL_HSt1e',
#  'HMR_1539',
#  'EX_gluthrlys[e]',
#  'TXB2c',
#  'EX_pheleuasp[e]',
#  'TRPATB0tc',
#  'r2057',
#  'MM8Ber',
#  'RE3012R',
#  'EX_M02447[e]',
#  'LEUKABCtc',
#  'MI34PP',
#  'r1521',
#  'HMR_9738',
#  'CHTNASE',
#  'EX_3dhchol[e]',
#  'HMR_1681',
#  'r1591',
#  'FACOAL1831',
#  'MDZGLCtev',
#  'EX_gsn[e]',
#  'r1642',
#  'r1827',
#  'EBP1r',
#  'ESTRONESt',
#  'r1150',
#  'r1976',
#  'RE0575C',
#  'PIK5',
#  'SAMHISTAe',
#  'HMR_5248',
#  'PCREATtmdiffir',
#  'PCHOLN201_HSt1e',
#  'C4tmc',
#  'RE3391M',
#  'EX_c10crn[e]',
#  'r0641',
#  'r1169',
#  'HMR_2067',
#  '5OHFVShc',
#  'FAOXTC122m',
#  'FUCGALGBSIDEtg',
#  'LCAT17e',
#  'HMR_3223',
#  'INSt5le',
#  'r1784',
#  'NADK',
#  'r0911',
#  'MCOATA',
#  'HMR_3179',
#  'MTHFDm',
#  'r1049',
#  'EX_C02356[e]',
#  'GALTg',
#  'PEDH15_HSPLA2',
#  'EX_CE2026[e]',
#  'LCADi',
#  'FAOXC61m',
#  'HMR_3183',
#  'QUILSYN',
#  '56DURAtd',
#  'HISPROLYSr',
#  'HMR_0844',
#  'HMR_1478',
#  'HMR_1558',
#  '3HDECECRNtr',
#  'HMR_0614',
#  'HMR_9626',
#  'FUT910g',
#  'HMR_1532',
#  'S6TASE12ly',
#  'r2494',
#  'HMR_3703',
#  'r2323',
#  'CHSTEROLt',
#  'XANtx',
#  'HMR_0350',
#  'HMGCOASim',
#  '4NPHSFte',
#  'GALSIDEter',
#  'FVSteb',
#  'EX_pmtcrn[e]',
#  'LPIPECOLt',
#  'RADH4',
#  'CRTSLtm',
#  'HMR_1766',
#  'GALGLUSIDEtl2',
#  'r2114',
#  'SPHMYLN18120_hs_ATPt',
#  '10FTHF5GLUtl',
#  'RE3389M',
#  'SMS6',
#  'r2226',
#  'NADtm',
#  'GLUDxm',
#  'RE2999M',
#  'AG13T15g',
#  'RE3174R',
#  'r1983',
#  'DOCOHEXETHc',
#  'EX_steeth[e]',
#  'r2169',
#  'LCAT52e',
#  'VALARGGLYr',
#  'r2139',
#  'r2281',
#  'ME2',
#  'HMR_2988',
#  'r2168',
#  'AM1ALCSteb',
#  'RE2914M',
#  'SERDGLNexR',
#  'NACHEX13ly',
#  'EX_tetdeca511ac[e]',
#  'MALTTTRt',
#  'HMR_5387',
#  'GALTt',
#  'r2087',
#  'AMPtp',
#  'RE1587R',
#  'EX_HC02191[e]',
#  'C05463t2',
#  'HMR_3191',
#  '24_25DHVITD2t',
#  'CRTSLtr',
#  'LST4EXPthc',
#  '1531TALThr',
#  'r2079',
#  'SMS14',
#  'CYTK5n',
#  'r2420',
#  'EX_tiggly[e]',
#  'r0432',
#  'C8DCc',
#  'NABTNO',
#  'HMR_2967',
#  'RETI2',
#  'LEUKTRB4WOHtr',
#  'HMR_1085',
#  'P45027A16m',
#  'ONPTHLte',
#  'r1078',
#  'PCHLN225_HSt1e',
#  'EBP2r',
#  'FADtx',
#  'EX_tchola[e]',
#  'ELAIDCRNt',
#  'HMR_0817',
#  '2HATVLACGLUChr',
#  'r0672',
#  'DNDPt18m',
#  'GP1CALPHAtg',
#  'C4CRNtr',
#  'NACASPAH',
#  'SPHMYLN_HsSECt',
#  'HMR_1135',
#  'PGK',
#  'HMR_1976',
#  'RE1806R',
#  'HMR_2904',
#  'r1752',
#  'AG13T13g',
#  'r2052',
#  'EX_gcdca3s[e]',
#  'ARTFR45',
#  'EX_ileasp[e]',
#  'AGPAT1',
#  'SUCCt2m',
#  'HMR_2263',
#  'EX_trpthrtyr[e]',
#  'RE2989X',
#  'RETH2',
#  'HMR_3225',
#  'HMR_3522',
#  'HMR_0663',
#  'B3GNT32g',
#  'r0604',
#  'DNDPt24m',
#  'FAOXC201C181x',
#  'PCHOLPALME-HSt1e',
#  'EX_10fthf[e]',
#  'EX_asn_L[e]',
#  'FUCACGALFUCGALACGLCGALGLUSIDEtg',
#  '3TTETDDCOACRNtr',
#  'NACHEXA18ly',
#  'VALPHELAT2tc',
#  'TRPMETVALr',
#  'HMR_3680',
#  'HMR_9753',
#  'RE1933C',
#  'GLUMETt',
#  'C51CPT1',
#  'IBUP_SCYP3hep',
#  'FAOXC180',
#  'HMR_3662',
#  'r0122',
#  'EX_crvsm1[e]',
#  'PSYTCHe',
#  'r2060',
#  'FAOXC1811601m',
#  'SERLYSHISt',
#  'r2310',
#  'LEUPROARGt',
#  'r0673',
#  'r1598',
#  'HMR_3626',
#  'EX_cdpea[e]',
#  'FAOXTC162TC142m',
#  'RE1233C',
#  'r2084',
#  'GCC2am',
#  'BUTt2r',
#  'EX_CE1918[e]',
#  'r2267',
#  'LCAT25e',
#  'HMR_2240',
#  'IZPN',
#  'GQ1BALPHAtg',
#  'HEXCt',
#  'EX_hdcecrn[e]',
#  'r1303',
#  'HMR_2736',
#  'r1857',
#  'HMR_3321',
#  'HMR_2769',
#  'EX_am4n9cs[e]',
#  'EX_cysglnmet[e]',
#  'PE161_HSt1e',
#  '2HIBUP_Rthv',
#  'ALLOP2tu',
#  'EX_ileasnhis[e]',
#  'GLU5SAtmc',
#  'RE0344C',
#  'r1163',
#  'HMR_3331',
#  'HMR_3095',
#  'CLPNDCRNt',
#  'EX_isolvstacid[e]',
#  '3HPVSTEThc',
#  'EX_cysaspphe[e]',
#  'HMR_7277',
#  'HMR_1958',
#  'HMR_9776',
#  'EX_trpleuval[e]',
#  'UMPK2n',
#  'r1830',
#  'HMR_0287',
#  'EX_dhf[e]',
#  'IPDPtx',
#  'HMR_2621',
#  'C8CRNe',
#  'HMR_3722',
#  'SMS',
#  'EX_sphmyln181221_hs[e]',
#  'RE3272N',
#  'r1986',
#  'HMR_0527',
#  'PEOLE_HSABCt',
#  'LCAT8e',
#  'HMR_2540',
#  'RE1635X',
#  'GLAl',
#  '7BHGLZGLChr',
#  'HMR_1033',
#  'AMPDA',
#  'O16G2e',
#  'HMR_2585',
#  'HMR_0433',
#  'EX_hisglugln[e]',
#  'EX_hdca[e]',
#  'HMR_3332',
#  'EX_bhb[e]',
#  'BGLUTDECHOe',
#  'r2490',
#  'EX_hishislys[e]',
#  'LCA3GSc',
#  'LALDO2x',
#  'HMR_9646',
#  '5MTHFt2',
#  'EX_pchol2linl_hs[e]',
#  'CE0328te',
#  'RETH2e',
#  'B3GNT314g',
#  'r1995',
#  'r0409',
#  'PCHOLPg_hs',
#  'HMR_0963',
#  'NTD12',
#  'EX_c4crn[e]',
#  'EX_4abut[e]',
#  '1HIBUPGLUC_Sthv',
#  'CYSGLUTRPt',
#  'HMR_0520',
#  'r2513',
#  'PNTEH',
#  'RE2888C',
#  'RE2993X',
#  'UDPGLCter',
#  'GALGLUSIDEtg',
#  'r1562',
#  'EX_stcrn[e]',
#  'ASPHISPROt',
#  '3OHSEBACtxc',
#  '6HLVSTitr',
#  'GLCNACT4g',
#  'FACOAL206',
#  'EX_tauribup_S[e]',
#  'CE7082UPKt',
#  'PROD2',
#  'XOLEST181_HSte',
#  'EX_HC01446[e]',
#  'EX_melatn[e]',
#  'r1954',
#  'RE3151C',
#  '1HMDGLUCitr',
#  'RETFA',
#  'PHYCBOXL',
#  'NADPtru',
#  'GT1Ate',
#  'PI3P3Pn',
#  'EX_c4dc[e]',
#  'r1797',
#  'HMR_2896',
#  'ACMPtu',
#  'r1585',
#  'r2104',
#  'HMR_9617',
#  'C181CPT2',
#  'AND19ONEc',
#  'PA_HStm',
#  'HMR_2790',
#  'r1184',
#  'LCAT4e',
#  'PTDCAt',
#  'C06315t',
#  '3OHSEBACx',
#  'URAt',
#  'RE3009C',
#  'HMR_5136',
#  '24_25VITD2Hm',
#  'NACHEX27ly',
#  'r1686',
#  'NTD2m',
#  'MVLACte',
#  'RE1691M',
#  'HMR_0189',
#  'EX_6bhglz[e]',
#  'ACOX22x',
#  'MDZtd',
#  'HMR_1928',
#  'HMR_3663',
#  'THP2Ctp',
#  'NACHEXA5ly',
#  'THMTP',
#  'r1423',
#  'CORE5GTg',
#  'r2095',
#  'r2425',
#  'r1730',
#  'DNDPt43m',
#  'HMR_2849',
#  'IBUP_Stdu',
#  'SPHMYLN180241_hs_ATPt',
#  'r1638',
#  'FAOXC121C10x',
#  'HMR_9771',
#  'RE1631C',
#  'ADRNCRNt',
#  'EX_HC01944[e]',
#  'LPS4e',
#  'RAI3',
#  'r1156',
#  'PE15_HSABCt',
#  '3DHLCAt2',
#  'FAOXC16080x',
#  'FAOXC6C4m',
#  'NACHEXA4ly',
#  'FACOAL140i',
#  'CSNAT2x',
#  'r0287',
#  'EX_profvs[e]',
#  'HMR_0526',
#  'HMR_6408',
#  'r2376',
#  'EX_acgalfucgalacgalfuc12gal14acglcgalgluside_hs[e]',
#  'METS',
#  'PHELYSALAr',
#  'HMR_6986',
#  'SLDt',
#  'EX_andrstrn[e]',
#  'MM7Ag',
#  'r1913',
#  'EX_hislysval[e]',
#  'EX_3mtp[e]',
#  'PCHOLN204_HSt1e',
#  'CDCA24Gtr',
#  'DCHOLESTANCOAc',
#  'CE0737te',
#  'IDHPOXOX4',
#  'FPGS3m',
#  'r0553',
#  'HMR_6620',
#  'EX_M03161[e]',
#  'H2O2t',
#  'P45027A11m',
#  'HMR_5152',
#  'EX_protrpthr[e]',
#  'AHCYStr',
#  'EX_hnifedipine[e]',
#  'EX_tststerone[e]',
#  'EX_7thf[e]',
#  'MLTG1ly',
#  'ALAR',
#  'r0934',
#  'EX_asphispro[e]',
#  '3HPVSCOAitm',
#  'HMR_2651',
#  'ACLYSHYc',
#  'HMR_0394',
#  'r0365',
#  'HDCA24GSr',
#  'FAOXC2252053x',
#  'EX_homoval[e]',
#  'CRNtuNa',
#  'RE2799C',
#  'HMR_8570',
#  'r0732',
#  'PROVALGLNr',
#  'TRPPROLEUr',
#  '4HBZtm',
#  'EX_fad[e]',
#  '3ANTHRNtr',
#  'BILDGLCURte',
#  'PIPLC',
#  'RE2386C',
#  'EX_HC02217[e]',
#  'ASNMETPROr',
#  '56EPPVStev',
#  'HMR_0553',
#  'r1813',
#  'RE3136C',
#  'FAOXC15NADPx',
#  'NACHEX11ly',
#  'C6DCtr',
#  'P45019A1r',
#  'HMR_2633',
#  'r1359',
#  'r1744',
#  'CRGLZtev',
#  'GALt2_2',
#  'HMR_3117',
#  'EX_dcmp[e]',
#  'r0986',
#  'RE1925C',
#  'HMR_2016',
#  'HMR_1215',
#  'HMR_5146',
#  'EX_ttdca[e]',
#  'HC00004t1r',
#  'SPMD3n',
#  'AG13T18g',
#  'EX_M01582[e]',
#  'GASNASEly',
#  'DOPAtu',
#  'r2172',
#  'FDPte',
#  'r0389',
#  'GLACter',
#  'EX_selmeth[e]',
#  'HMR_5134',
#  'PCHOLN2254_HSPLA2',
#  'BTNDe',
#  'RE2991X',
#  'EX_CE5786[e]',
#  'NACCYSte',
#  'r1765',
#  'GDPtg',
#  'H2O2tp',
#  'C05770te',
#  'HMR_3689',
#  'CYOOm3i',
#  'HMR_2794',
#  'THRILEARGr',
#  'HMR_6728',
#  'GMAND',
#  'HMR_0703',
#  'FAOXC5C5OHm',
#  'RE3562R',
#  'AM1CSAhr',
#  'EX_smv[e]',
#  'B3GNT315g',
#  'CITt4_2',
#  'HMR_2246',
#  'HMR_3544',
#  'HMR_7743',
#  'r2497',
#  'RE2319X',
#  'HMR_3220',
#  'EX_ade[e]',
#  'r0466',
#  'ARGNm',
#  'EX_nac[e]',
#  'CORE8GTg',
#  'HMR_2269',
#  'NACHEXA3ly',
#  'HMR_6558',
#  'HMR_0382',
#  'SMS11',
#  'TMNDNCCRNt',
#  'LEUKTRC4t',
#  'NTD1m',
#  'r0475',
#  'MI145PP',
#  'HMR_2978',
#  'HISPROLYSt',
#  'UGLCNACtg',
#  'DODECANACt',
#  'HMR_0197',
#  'HMR_0438',
#  'HC00460te',
#  'RDH2',
#  'FAOXC2252053m',
#  'GGH_10FTHF5GLUl',
#  'SPMS',
#  'EX_dhcholestanate[e]',
#  'HMR_3655',
#  'CSAitr',
#  'ACNMLr',
#  'EX_asplyshis[e]',
#  'HMR_0321',
#  'RE3476C',
#  'ANDRSTRNGLCtr',
#  'ARACHDt2',
#  'FOLOATPtc',
#  'TXA2te',
#  'EX_gudac[e]',
#  'CYSSERMETt',
#  'HMR_0807',
#  'ORNLEUrBATtc',
#  'HMR_2080',
#  'r2216',
#  'EX_4hbz[e]',
#  'CE7172ATP',
#  'LANOSTte',
#  'EX_n8aspmd[e]',
#  'HMR_2906',
#  'PROGLULYSr',
#  'r1583',
#  'AHCYStd',
#  'DOLMANP_Lter',
#  'EX_galside_hs[e]',
#  'r2127',
#  'HPDCACRNCPT2',
#  'FAOXC14DCC12DCx',
#  'RSVtev',
#  'HMR_3724',
#  'GLYOp',
#  'OXAHCOtex',
#  'RE3003M',
#  'EX_5aop[e]',
#  'TMDOATPtsc',
#  '12DHCHOLabc',
#  'HMR_9627',
#  'r2029',
#  'TMDM1OATt',
#  'r0618',
#  'SPHMYLN1824_hs_SECt',
#  'LNLCCPT1',
#  'FMNALKPle',
#  'L_LACt4r',
#  'ARGPROMETr',
#  '3HLYTCL',
#  'r2388',
#  'EX_leuasnasp[e]',
#  'DTDPtn',
#  'D_LACt2',
#  'HYOCHOLabc',
#  'ALDD2y',
#  'XANDp',
#  'FPGS6m',
#  'r2485',
#  'GLYGLYPEPT1tc',
#  'RE1526M',
#  'r1926',
#  'EX_3ohsebac[e]',
#  'RE2921M',
#  'EX_M03147[e]',
#  'RE1523X',
#  'DOLPMT2_Ler',
#  'r2250',
#  'HMR_0841',
#  'RE2649M',
#  'RE0549C',
#  'HMR_0325',
#  'EX_M01881[e]',
#  'FAOXC81C61x',
#  'DEDOLP2_L',
#  'CREATt4_2_r',
#  'UGT1A10r',
#  'THMATPe',
#  'RE3251M',
#  'HMR_2873',
#  'VLCS2r',
#  'NH4tp',
#  'HMR_3692',
#  'r1881',
#  'SPTix',
#  'SMVtu',
#  'EX_cmpacna[e]',
#  'TRPARGALAt',
#  'FRDPtcr',
#  'HMR_9640',
#  'FAOXC161C141x',
#  'LEUTRPt',
#  'PGDI',
#  'GGNG',
#  'HMR_1331',
#  'TRPVALASPr',
#  'ABTArm',
#  'RE3239C',
#  'HMR_2363',
#  'HMR_3714',
#  'FUCGALFUCGALACGLCGALGLUSIDEte',
#  'RE1901R',
#  'HMR_4964',
#  'S2L2N2M2MASNtly',
#  'CE1554t',
#  'RE1582R',
#  'HISTAVESSEC',
#  'PEAMNO',
#  'PTRCAT1',
#  'HMR_3681',
#  'DESAT18_4',
#  'TYROXDAc',
#  'r1649',
#  'RE3437C',
#  'EX_sucaceto[e]',
#  'r0130',
#  'VALLEUPHEr',
#  'EX_3ohglutac[e]',
#  'r1514',
#  'HMR_2287',
#  'EX_ethmalac[e]',
#  'HMR_2237',
#  'NACHEX3ly',
#  'steroids',
#  'RE2638C',
#  '3HCINNMsec',
#  'PROHISt',
#  'PCHOLN19_HSPLA2',
#  'A4GALTc',
#  'EX_xylu_D[e]',
#  'r2520',
#  'EX_3octdeccrn[e]',
#  'RE3236R',
#  'NORANMT',
#  'r2398',
#  'HMR_8572',
#  'RE3225R',
#  'HMR_9790',
#  'SR5ARr',
#  'EX_am1a4ncs[e]',
#  'DGK2m',
#  'HMR_2666',
#  'FACOAL161',
#  'AM1CCSteb',
#  'PI34P5Kn',
#  'HMR_3684',
#  'TMNDNCCOAtx',
#  'ARGLYSASPt',
#  'r1568',
#  'LSTNitr',
#  'ACGAM6PSi',
#  'r1661',
#  'RE1807M',
#  'RE3237C',
#  'PROLYSPROt',
#  'r0645',
#  'r0391',
#  'HMR_0194',
#  'HMR_8576',
#  'SMS1S2',
#  'NTD7',
#  'HMR_7757',
#  'RE3162R',
#  'RE1234C',
#  'RE3488C',
#  'r2270',
#  'RE3036C',
#  'S6T6g',
#  'HMR_5165',
#  '35DSMVhep',
#  'PROFVStev',
#  'r0924',
#  'THRASNTYRt',
#  'RE3166R',
#  'METHISLYSt',
#  'SERHL',
#  'r0319',
#  'SERATB0tc',
#  'LCAT34e',
#  'ADPACtd',
#  'EX_C05767[e]',
#  'SRTNACT',
#  'r1984',
#  'EX_gchola[e]',
#  'FUT12g',
#  'HMR_9797',
#  'EX_dheas[e]',
#  'DNDPt13m',
#  'TETPENT6CPT1',
#  'GLNtN1',
#  'ADRNCPT1',
#  'EX_CE2915[e]',
#  'LCAT44e',
#  'ACTHRte',
#  'HEXCCPT1',
#  'r0510',
#  'HMR_7279',
#  'EPOXTACteb',
#  'NEU21',
#  'HMR_3424',
#  'HMR_1962',
#  'GALASE8ly',
#  'NAHCO3_HCLt',
#  'r0940',
#  'S2TASE3ly',
#  'S6TASE8ly',
#  'HMR_3643',
#  'ARGARGLYSt',
#  'RE3165R',
#  'HMR_2700',
#  'EX_HC00955[e]',
#  'C10OHc',
#  '3UIBtd',
#  'EX_hdd2crn[e]',
#  'EX_xoltri24[e]',
#  'LTC4Sr',
#  'EX_HC01444[e]',
#  'THRHISHISt',
#  'NNATr',
#  'SPHMYLN181201_hs_ATPt',
#  'CYOOm2i',
#  'EX_proargasp[e]',
#  'r1018',
#  'HMR_1242',
#  'HMR_2827',
#  'TETDECE1CRNe',
#  'CHSTEROLSULT',
#  'GASNASE2ly',
#  'NACHEXA8ly',
#  'NDP7g',
#  'EX_3thexddcoacrn[e]',
#  'HMR_0437',
#  'RE0453M',
#  'HMR_3649',
#  'HMR_8590',
#  'HMR_9178',
#  'RE2908M',
#  'EX_andrstndn[e]',
#  'PCHOLN15_HSABCt',
#  'RE3491C',
#  'HMR_0679',
#  'HEX4',
#  'r1614',
#  'RE3163R',
#  'r0670',
#  'HMR_6849',
#  'NAPQIhr',
#  'r0960',
#  'r0181',
#  'TRPGLUGLYr',
#  'FAOXC1811603m',
#  '2HIBUPGLUC_Sitr',
#  'RE3242R',
#  'PHYQt',
#  'GLUTRPALAt',
#  'PROTRPTHRr',
#  'r2064',
#  'A4GALTg',
#  'S26Tg',
#  'GLYCLTtd',
#  'r1646',
#  'DNDPt15m',
#  'RDH3a',
#  'EX_nfdlac[e]',
#  'HMR_6359',
#  'RE1846C',
#  'THRCYSNaEx',
#  'ACLYStm',
#  'HMR_6617',
#  'FAOXC121C101m',
#  'r0787',
#  'CLCFTRte',
#  'GLCNACT_U',
#  'EX_C05300[e]',
#  'HMR_2907',
#  'G14T7g',
#  'ODECOAtx',
#  'r1956',
#  'HMR_3583',
#  'EX_4ohbut[e]',
#  'S6T7g',
#  'DHCHOLESTANATEt',
#  'r1854',
#  'GLNyLATthc',
#  'PCHOL2LINL_HSt1e',
#  '3HIVAcm',
#  'TETDECAETH',
#  'VALPROTRPr',
#  'FVSCOAhc',
#  'r2434',
#  'DEOXFVStev',
#  'ACLEUte',
#  'r1573',
#  'PPCDC',
#  'ADPMAN',
#  'RE1516M',
#  'ACILEte',
#  'PROSTGE1t3',
#  'NEU35e',
#  'ATPS4mi',
#  'THRD_L',
#  'RE1903R',
#  'ACACT1x',
#  'r2498',
#  'EX_glyald[e]',
#  'HMR_0398',
#  'DIGALSGALSIDEATPte',
#  '3DHLCAt',
#  'r0295',
#  'HMR_9670',
#  'EX_C03681[e]',
#  'HISHISLYSt',
#  'HISGLNALAr',
#  'HMR_3453',
#  'HMR_2011',
#  'r1102',
#  'HMR_9605',
#  'RE2410C',
#  'HMR_5232',
#  'r1633',
#  'r1456',
#  'GALGT4',
#  'FAOXC3DC',
#  'r1497',
#  'HSD3B11',
#  'HMR_0419',
#  'DNDPt44m',
#  'r0679',
#  'RE0569C',
#  'EX_trideceth[e]',
#  ...}

# %% [markdown]
# ### Evaluate a set of tasks

# %%
# create a structure to hold all of these results - a dictionary
task_eval_results = {}

# for each k (tuple with algorithm and sample information) and result (dict with reaction presences)
for k, result in fastcore_res_dict.items():
    # using with statements to change the COBRA model temporarily
    # this is done to knock-out reaction not appearing the FASTCORE result
    with task_model as context_specific_model:
        # get reactions included in the sample-specific model
        protected = set([k for k, v in result.items() if v])
        # get reactions except the protected ones
        to_remove = all_reactions - protected
        for rid in to_remove:
            # knock-out reactions not in the model
            context_specific_model.reactions.get_by_id(rid).knock_out()

        # create a task evaluator instance with the context specific model and the supplied
        # task list and solver
        task_eval = TaskEvaluator(model=context_specific_model, tasks=task_list, solver='CPLEX')

        # get task names (for future reference)
        task_names = task_eval.tasks

        # use the batch_function from the TaskEvaluator class (takes the name of a loaded task,
        # a params dictionary with the task evaluator associated to the 'tev' key) and set the
        # amount of threads to be used
        batch_res_tasks = batch_run(TaskEvaluator.batch_function, task_names,
                                    {'tev': task_eval}, threads=1)
    # each element in the list of results in batch_res_tasks is a tuple of length 3:
    # 0 - boolean flag representing the task evaluation
    # 1 - Solution instance used to evaluate the task
    # 2 - A dictionary with reactions supposed to be active mapped to True/False
    # according to that criterion

    # keep only items 0 and 2 of the task result - we don't need the flux distribution
    task_csm_res = {k: (v[0], v[2]) for k, v in dict(zip(task_names, batch_res_tasks)).items()}
    print(k, len(protected), len([v for k, v in task_csm_res.items() if v[0]]), 'tasks completed.')
    # assign this dictionary to it's sample on the master results dictionary
    task_eval_results[k] = task_csm_res
# Out:
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8639__COBAMPGPRDOT__1 or _26__COBAMPGPRDOT__1 or _314__COBAMPGPRDOT__2 or _314__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1591__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1594__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10993__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6818__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _89874__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _92483__COBAMPGPRDOT__1 or _3948__COBAMPGPRDOT__2 or _55293__COBAMPGPRDOT__1 or (_3945__COBAMPGPRDOT__1 and _3939__COBAMPGPRDOT__1) or _3939__COBAMPGPRDOT__1 or _160287__COBAMPGPRDOT__1 or _3945__COBAMPGPRDOT__1 or _3948__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9123__COBAMPGPRDOT__1 or _9194__COBAMPGPRDOT__1 or _6566__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _57835__COBAMPGPRDOT__3 or _8671__COBAMPGPRDOT__1 or _57835__COBAMPGPRDOT__2 or _57835__COBAMPGPRDOT__1 or _57835__COBAMPGPRDOT__4
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_4967__COBAMPGPRDOT__2 and _1738__COBAMPGPRDOT__1 and _8050__COBAMPGPRDOT__1 and _1743__COBAMPGPRDOT__1) or (_4967__COBAMPGPRDOT__1 and _1738__COBAMPGPRDOT__1 and _8050__COBAMPGPRDOT__1 and _1743__COBAMPGPRDOT__1)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _130__COBAMPGPRDOT__1 or _127__COBAMPGPRDOT__1 or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or _131__COBAMPGPRDOT__1 or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or _128__COBAMPGPRDOT__1 or _137872__COBAMPGPRDOT__1 or (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1312__COBAMPGPRDOT__1 or _1312__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _117247__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _218__COBAMPGPRDOT__1 or _222__COBAMPGPRDOT__1 or _220__COBAMPGPRDOT__1 or _221__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _222__COBAMPGPRDOT__1 or _221__COBAMPGPRDOT__1 or _218__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _221__COBAMPGPRDOT__1 or _218__COBAMPGPRDOT__1 or _220__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _221__COBAMPGPRDOT__1 or _222__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3242__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _18__COBAMPGPRDOT__1 or _18__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2531__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _23498__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _55268__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51166__COBAMPGPRDOT__1 or _883__COBAMPGPRDOT__1 or _51166__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1644__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4128__COBAMPGPRDOT__1 or _4129__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _218__COBAMPGPRDOT__1 or _221__COBAMPGPRDOT__1 or _222__COBAMPGPRDOT__1 or _220__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _222__COBAMPGPRDOT__1 or _220__COBAMPGPRDOT__1 or _221__COBAMPGPRDOT__1 or _218__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10165__COBAMPGPRDOT__1 or _8604__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51380__COBAMPGPRDOT__1 or _2571__COBAMPGPRDOT__1 or _2572__COBAMPGPRDOT__1 or _2571__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2805__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2806__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4129__COBAMPGPRDOT__1 or _8639__COBAMPGPRDOT__1 or _26__COBAMPGPRDOT__1 or _314__COBAMPGPRDOT__2 or _314__COBAMPGPRDOT__1 or _4128__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8659__COBAMPGPRDOT__1 or _8659__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6799__COBAMPGPRDOT__1 or _6817__COBAMPGPRDOT__3 or _6799__COBAMPGPRDOT__2 or _6818__COBAMPGPRDOT__2 or _6817__COBAMPGPRDOT__2 or _6818__COBAMPGPRDOT__1 or _6817__COBAMPGPRDOT__1 or _6817__COBAMPGPRDOT__4 or _6818__COBAMPGPRDOT__3 or _6817__COBAMPGPRDOT__5
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4363__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6822__COBAMPGPRDOT__1 or _6818__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6573__COBAMPGPRDOT__1 or _6573__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _316__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3620__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6570__COBAMPGPRDOT__1 or _6571__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2348__COBAMPGPRDOT__5 or _2348__COBAMPGPRDOT__3 or _2348__COBAMPGPRDOT__1 or _2348__COBAMPGPRDOT__6 or _2352__COBAMPGPRDOT__1 or _2348__COBAMPGPRDOT__4 or _2348__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4125__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _53947__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51146__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8639__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51166__COBAMPGPRDOT__1 or _51166__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _28__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6529__COBAMPGPRDOT__1 or _6538__COBAMPGPRDOT__1 or _6540__COBAMPGPRDOT__1 or _6539__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _38__COBAMPGPRDOT__1 or _3032__COBAMPGPRDOT__1 or _10449__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_3030__COBAMPGPRDOT__1 and _3032__COBAMPGPRDOT__1) or _38__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _39__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6566__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _30__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _32__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9197__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _84532__COBAMPGPRDOT__1 or _79611__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6566__COBAMPGPRDOT__1 or _9123__COBAMPGPRDOT__1 or _9194__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _64841__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _55577__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5238__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _162417__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _43__COBAMPGPRDOT__1 or _43__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6572__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _47__COBAMPGPRDOT__1 or _47__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54187__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _26503__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _140838__COBAMPGPRDOT__1 or _54__COBAMPGPRDOT__1 or _51205__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _36__COBAMPGPRDOT__1 or _34__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _80724__COBAMPGPRDOT__1 or _36__COBAMPGPRDOT__1 or _35__COBAMPGPRDOT__1 or _34__COBAMPGPRDOT__1 or _84129__COBAMPGPRDOT__1 or _27034__COBAMPGPRDOT__1 or _28976__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3712__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _34__COBAMPGPRDOT__1 or _27034__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _134526__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51__COBAMPGPRDOT__1 or _51__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _95__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _50__COBAMPGPRDOT__1 or _48__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8309__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _52__COBAMPGPRDOT__1 or _52__COBAMPGPRDOT__3 or _52__COBAMPGPRDOT__2 or _55__COBAMPGPRDOT__1 or _51205__COBAMPGPRDOT__1 or _54__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _788__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _55902__COBAMPGPRDOT__1 or _65985__COBAMPGPRDOT__1 or _55902__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _84532__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _438__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1571__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _100__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3177__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _205__COBAMPGPRDOT__3 or _205__COBAMPGPRDOT__1 or _204__COBAMPGPRDOT__1 or _204__COBAMPGPRDOT__3 or _204__COBAMPGPRDOT__2 or _205__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _26289__COBAMPGPRDOT__1 or _26289__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _50808__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _26289__COBAMPGPRDOT__2 or _26289__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _262__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _112__COBAMPGPRDOT__1 or _55811__COBAMPGPRDOT__1 or _109__COBAMPGPRDOT__1 or _112__COBAMPGPRDOT__2 or _114__COBAMPGPRDOT__1 or _108__COBAMPGPRDOT__1 or _113__COBAMPGPRDOT__1 or _107__COBAMPGPRDOT__1 or _196883__COBAMPGPRDOT__1 or _115__COBAMPGPRDOT__1 or _111__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3177__COBAMPGPRDOT__1 or _2030__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9154__COBAMPGPRDOT__2 or _9154__COBAMPGPRDOT__1 or _64078__COBAMPGPRDOT__1 or _9153__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _55315__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2030__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11164__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _952__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1375__COBAMPGPRDOT__1 or _1375__COBAMPGPRDOT__3 or _1375__COBAMPGPRDOT__4 or _126129__COBAMPGPRDOT__1 or _1374__COBAMPGPRDOT__1 or _1375__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1376__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _788__COBAMPGPRDOT__1 or _788__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9060__COBAMPGPRDOT__1 or _9061__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _158__COBAMPGPRDOT__1 or _158__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _79369__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__1 or _11041__COBAMPGPRDOT__1 or _146712__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__1 or _93010__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__2 or _10331__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _79369__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__1 or _11041__COBAMPGPRDOT__1 or _146712__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__2 or _93010__COBAMPGPRDOT__1 or _10331__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _79369__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__1 or _11041__COBAMPGPRDOT__1 or _146712__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__1 or _93010__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__2 or _10678__COBAMPGPRDOT__2 or _10331__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10678__COBAMPGPRDOT__2 or _11041__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__2 or _93010__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__1 or _146712__COBAMPGPRDOT__1 or _79369__COBAMPGPRDOT__1 or _10331__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11041__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__1 or _93010__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__2 or _374907__COBAMPGPRDOT__1 or _146712__COBAMPGPRDOT__1 or _10331__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__2 or _79369__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10331__COBAMPGPRDOT__1 or _11041__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__2 or _10678__COBAMPGPRDOT__1 or _79369__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__2 or _93010__COBAMPGPRDOT__1 or _146712__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11041__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__1 or _93010__COBAMPGPRDOT__1 or _10331__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__1 or _146712__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__2 or _10678__COBAMPGPRDOT__2 or _79369__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _146712__COBAMPGPRDOT__1 or _79369__COBAMPGPRDOT__1 or _10331__COBAMPGPRDOT__1 or _374907__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__2 or _374907__COBAMPGPRDOT__2 or _10678__COBAMPGPRDOT__1 or _11041__COBAMPGPRDOT__1 or _93010__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _79814__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10555__COBAMPGPRDOT__1 or _137964__COBAMPGPRDOT__1 or _56895__COBAMPGPRDOT__1 or _56894__COBAMPGPRDOT__2 or _56894__COBAMPGPRDOT__1 or _55326__COBAMPGPRDOT__1 or _10554__COBAMPGPRDOT__1 or _129642__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _64902__COBAMPGPRDOT__1 or _64850__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _189__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3073__COBAMPGPRDOT__1 or _3074__COBAMPGPRDOT__1 or (_3073__COBAMPGPRDOT__1 and _3074__COBAMPGPRDOT__1)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10606__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8402__COBAMPGPRDOT__1 or _1468__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _64849__COBAMPGPRDOT__1 or _64849__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1645__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1109__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6718__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6510__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6509__COBAMPGPRDOT__1 or _6510__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _56301__COBAMPGPRDOT__1 and _6520__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6520__COBAMPGPRDOT__1 and _56301__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _212__COBAMPGPRDOT__1 or _23464__COBAMPGPRDOT__1 or _211__COBAMPGPRDOT__2 or _211__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _206358__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54407__COBAMPGPRDOT__1 or _6542__COBAMPGPRDOT__1 or _11254__COBAMPGPRDOT__1 or _6541__COBAMPGPRDOT__1 or _81539__COBAMPGPRDOT__1 or _55089__COBAMPGPRDOT__1 or _84889__COBAMPGPRDOT__1 or (_340024__COBAMPGPRDOT__1 and _57393__COBAMPGPRDOT__1) or (_340024__COBAMPGPRDOT__1 and _59272__COBAMPGPRDOT__1)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _2875__COBAMPGPRDOT__1 or _84706__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _92745__COBAMPGPRDOT__1 or _10991__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _127__COBAMPGPRDOT__1 or _284273__COBAMPGPRDOT__2 or _125__COBAMPGPRDOT__1 or _128__COBAMPGPRDOT__1 or _131__COBAMPGPRDOT__1 or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or _124__COBAMPGPRDOT__1 or _130__COBAMPGPRDOT__1 or _137872__COBAMPGPRDOT__1 or (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1) or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or _284273__COBAMPGPRDOT__1 or _126__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _130__COBAMPGPRDOT__1 or _125__COBAMPGPRDOT__1 or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or _128__COBAMPGPRDOT__1 or _126__COBAMPGPRDOT__1 or _284273__COBAMPGPRDOT__2 or _137872__COBAMPGPRDOT__1 or _127__COBAMPGPRDOT__1 or _124__COBAMPGPRDOT__1 or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or _284273__COBAMPGPRDOT__1 or (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1) or _131__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _126__COBAMPGPRDOT__1 or _137872__COBAMPGPRDOT__1 or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or _127__COBAMPGPRDOT__1 or _130__COBAMPGPRDOT__1 or _284273__COBAMPGPRDOT__1 or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or _128__COBAMPGPRDOT__1 or _124__COBAMPGPRDOT__1 or _125__COBAMPGPRDOT__1 or _284273__COBAMPGPRDOT__2 or _131__COBAMPGPRDOT__1 or (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: (_125__COBAMPGPRDOT__1 and _126__COBAMPGPRDOT__1) or _137872__COBAMPGPRDOT__1 or (_125__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1) or _127__COBAMPGPRDOT__1 or _130__COBAMPGPRDOT__1 or _284273__COBAMPGPRDOT__1 or _126__COBAMPGPRDOT__1 or _124__COBAMPGPRDOT__1 or _128__COBAMPGPRDOT__1 or _125__COBAMPGPRDOT__1 or _126__COBAMPGPRDOT__1 or _284273__COBAMPGPRDOT__2 or _131__COBAMPGPRDOT__1 or (_126__COBAMPGPRDOT__1 and _124__COBAMPGPRDOT__1)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10327__COBAMPGPRDOT__1 or _10327__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _216__COBAMPGPRDOT__1 or _8854__COBAMPGPRDOT__2 or _501__COBAMPGPRDOT__1 or _8854__COBAMPGPRDOT__1 or _223__COBAMPGPRDOT__1 or _224__COBAMPGPRDOT__1 or _8854__COBAMPGPRDOT__3
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _219__COBAMPGPRDOT__1 or _8659__COBAMPGPRDOT__1 or _217__COBAMPGPRDOT__1 or _8659__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _224__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _219__COBAMPGPRDOT__1 or _217__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _223__COBAMPGPRDOT__1 or _221__COBAMPGPRDOT__1 or _218__COBAMPGPRDOT__1 or _8854__COBAMPGPRDOT__1 or _8854__COBAMPGPRDOT__3 or _222__COBAMPGPRDOT__1 or _8854__COBAMPGPRDOT__2 or _224__COBAMPGPRDOT__1 or _219__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _239__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _247__COBAMPGPRDOT__1 or _246__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _240__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10327__COBAMPGPRDOT__2 or _8574__COBAMPGPRDOT__1 or _10327__COBAMPGPRDOT__1 or _231__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _23600__COBAMPGPRDOT__1 or _23600__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _23600__COBAMPGPRDOT__2 or _23600__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _115286__COBAMPGPRDOT__3 or _115286__COBAMPGPRDOT__2 or _115286__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _271__COBAMPGPRDOT__2 or _270__COBAMPGPRDOT__1 or _271__COBAMPGPRDOT__1 or _272__COBAMPGPRDOT__1 or _271__COBAMPGPRDOT__3
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _290__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6520__COBAMPGPRDOT__1 or _280__COBAMPGPRDOT__1 or _278__COBAMPGPRDOT__1 or _276__COBAMPGPRDOT__1 or _277__COBAMPGPRDOT__1 or (_6519__COBAMPGPRDOT__1 and _11136__COBAMPGPRDOT__1) or _276__COBAMPGPRDOT__2 or _279__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1375__COBAMPGPRDOT__3 or _1374__COBAMPGPRDOT__1 or _1375__COBAMPGPRDOT__2 or _1375__COBAMPGPRDOT__4 or _1375__COBAMPGPRDOT__1 or _126129__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10998__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _113451__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9057__COBAMPGPRDOT__1 and _6520__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _384__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _445__COBAMPGPRDOT__1 or _445__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11254__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _83884__COBAMPGPRDOT__1 or _10166__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _410__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _427__COBAMPGPRDOT__1 or _427__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9962__COBAMPGPRDOT__2 or _9963__COBAMPGPRDOT__1 or _9962__COBAMPGPRDOT__1 or _9963__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _80150__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _440__COBAMPGPRDOT__1 or _440__COBAMPGPRDOT__3 or _440__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _81539__COBAMPGPRDOT__1 or _11254__COBAMPGPRDOT__1 or _54407__COBAMPGPRDOT__1 or _55089__COBAMPGPRDOT__1 or (_340024__COBAMPGPRDOT__1 and _57393__COBAMPGPRDOT__1) or (_340024__COBAMPGPRDOT__1 and _59272__COBAMPGPRDOT__1)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _790__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6511__COBAMPGPRDOT__1 or _6505__COBAMPGPRDOT__1 or _6507__COBAMPGPRDOT__1 or _6506__COBAMPGPRDOT__1 or _6512__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8604__COBAMPGPRDOT__1 or _10165__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:116: UserWarning: Will not normalize rules with more than 20 average tokens per gene
#   'Will not normalize rules with more than ' + str(token_to_gene_ratio) + ' average tokens per gene')
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _954__COBAMPGPRDOT__1 or _954__COBAMPGPRDOT__2 or _953__COBAMPGPRDOT__1 or _956__COBAMPGPRDOT__1 or _955__COBAMPGPRDOT__1 or _957__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _954__COBAMPGPRDOT__2 or _954__COBAMPGPRDOT__1 or _953__COBAMPGPRDOT__1 or _956__COBAMPGPRDOT__1 or _955__COBAMPGPRDOT__1 or _957__COBAMPGPRDOT__1 or _377841__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _291__COBAMPGPRDOT__1 or _293__COBAMPGPRDOT__1 or _292__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _4126__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8706__COBAMPGPRDOT__4 or _8706__COBAMPGPRDOT__1 or _8706__COBAMPGPRDOT__3 or _8706__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8705__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10317__COBAMPGPRDOT__4 or _10317__COBAMPGPRDOT__1 or _10317__COBAMPGPRDOT__3 or _10317__COBAMPGPRDOT__2 or _10317__COBAMPGPRDOT__5
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10678__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10678__COBAMPGPRDOT__1 or _10678__COBAMPGPRDOT__2
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10331__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _84002__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _570__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _3141__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _140679__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8854__COBAMPGPRDOT__2 or _501__COBAMPGPRDOT__1 or _216__COBAMPGPRDOT__1 or _224__COBAMPGPRDOT__1 or _8854__COBAMPGPRDOT__3 or _223__COBAMPGPRDOT__1 or _8854__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8424__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _53630__COBAMPGPRDOT__1
# ...
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _7363__COBAMPGPRDOT__1 or _7364__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _0
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _7363__COBAMPGPRDOT__1 or _7364__COBAMPGPRDOT__1 or _10941__COBAMPGPRDOT__1 or _79799__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54659__COBAMPGPRDOT__1 or _7364__COBAMPGPRDOT__1 or _10941__COBAMPGPRDOT__1 or _79799__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1576__COBAMPGPRDOT__1 or _1577__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54659__COBAMPGPRDOT__1 or _54600__COBAMPGPRDOT__1 or _7364__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54657__COBAMPGPRDOT__1 or _7363__COBAMPGPRDOT__1 or _7364__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54659__COBAMPGPRDOT__1 or _54657__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1244__COBAMPGPRDOT__1 or _5243__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1576__COBAMPGPRDOT__1 or _1577__COBAMPGPRDOT__1 or _1558__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5446__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10599__COBAMPGPRDOT__1 or _11309__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1576__COBAMPGPRDOT__1 or _1577__COBAMPGPRDOT__1 or _1558__COBAMPGPRDOT__1 or _1565__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _37__COBAMPGPRDOT__1 or _3030__COBAMPGPRDOT__1 or _3032__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51__COBAMPGPRDOT__1 or _1962__COBAMPGPRDOT__1 or _3295__COBAMPGPRDOT__1 or _30__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1244__COBAMPGPRDOT__1 or _9429__COBAMPGPRDOT__1 or _8647__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1576__COBAMPGPRDOT__1 or (_4051__COBAMPGPRDOT__1 or _8529__COBAMPGPRDOT__1)
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1548__COBAMPGPRDOT__1 or _1571__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1559__COBAMPGPRDOT__1 or _1576__COBAMPGPRDOT__1 or _1558__COBAMPGPRDOT__1 or _1565__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1559__COBAMPGPRDOT__1 or _1558__COBAMPGPRDOT__1 or _1565__COBAMPGPRDOT__1 or _1557__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1557__COBAMPGPRDOT__1 or _1558__COBAMPGPRDOT__1 or _1559__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54600__COBAMPGPRDOT__1 or _54578__COBAMPGPRDOT__1 or _54658__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9154__COBAMPGPRDOT__1 or _9153__COBAMPGPRDOT__1 or _64078__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _7498__COBAMPGPRDOT__1 or _316__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _11309__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54659__COBAMPGPRDOT__1 or _54657__COBAMPGPRDOT__1 or _54658__COBAMPGPRDOT__1 or _54576__COBAMPGPRDOT__1 or _7364__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54659__COBAMPGPRDOT__1 or _54657__COBAMPGPRDOT__1 or _54600__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1558__COBAMPGPRDOT__1 or _1576__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _5243__COBAMPGPRDOT__1 or _9429__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1558__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54658__COBAMPGPRDOT__1 or _54659__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1559__COBAMPGPRDOT__1 or _1558__COBAMPGPRDOT__1 or _1576__COBAMPGPRDOT__1 or _1557__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _10965__COBAMPGPRDOT__1 or _122970__COBAMPGPRDOT__1 or _10005__COBAMPGPRDOT__1 or _26027__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1559__COBAMPGPRDOT__1 or _1576__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54575__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54658__COBAMPGPRDOT__1 or _54659__COBAMPGPRDOT__1 or _54657__COBAMPGPRDOT__1 or _54577__COBAMPGPRDOT__1 or _54576__COBAMPGPRDOT__1 or _54600__COBAMPGPRDOT__1 or _54575__COBAMPGPRDOT__1 or _7364__COBAMPGPRDOT__1 or _7367__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1559__COBAMPGPRDOT__1 or _1562__COBAMPGPRDOT__1 or _1557__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _51__COBAMPGPRDOT__1 or _1962__COBAMPGPRDOT__1 or _3295__COBAMPGPRDOT__1 or _30__COBAMPGPRDOT__1 or _1559__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _54658__COBAMPGPRDOT__1 or _54659__COBAMPGPRDOT__1 or _7364__COBAMPGPRDOT__1 or _54657__COBAMPGPRDOT__1 or _54578__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1559__COBAMPGPRDOT__1 or _1558__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _6579__COBAMPGPRDOT__1 or _11309__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _1244__COBAMPGPRDOT__1 or _9429__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _8714__COBAMPGPRDOT__1 or _10257__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# C:\Users\biosy\anaconda3\envs\s2m2_env\lib\site-packages\cobamp\gpr\core.py:41: UserWarning: Could not normalize this rule: _9016__COBAMPGPRDOT__1 or _7352__COBAMPGPRDOT__2 or _7352__COBAMPGPRDOT__1 or _7351__COBAMPGPRDOT__1 or _9016__COBAMPGPRDOT__2 or _7350__COBAMPGPRDOT__1 or _9481__COBAMPGPRDOT__1
#   warnings.warn('Could not normalize this rule: ' + rule)
# ('fastcore', 'ACH-001396') 0 15 tasks completed.
# {('fastcore', 'ACH-001396'): {'1': (False, {}),
#   '2': (False, {}),
#   '3': (False, {}),
#   '4': (False, {}),
#   '5': (False, {}),
#   '6': (False, {}),
#   '7': (True, {}),
#   '8': (False, {}),
#   '9': (False, {}),
#   '10': (False, {}),
#   '11': (False, {}),
#   '12': (False, {}),
#   '13': (False, {}),
#   '14': (False, {}),
#   '15': (False, {}),
#   '16': (False, {}),
#   '17': (False, {}),
#   '18': (False, {}),
#   '19': (False, {}),
#   '20': (False, {}),
#   '21': (False, {}),
#   '22': (False, {}),
#   '23': (False, {}),
#   '24': (False, {}),
#   '25': (False, {}),
#   '26': (False, {}),
#   '27': (False, {}),
#   '28': (False, {}),
#   '29': (False, {}),
#   '30': (False, {}),
#   '31': (False, {}),
#   '32': (False, {}),
#   '33': (False, {}),
#   '34': (False, {}),
#   '35': (False, {}),
#   '36': (False, {}),
#   '37': (False, {}),
#   '38': (False, {}),
#   '39': (False, {}),
#   '40': (False, {}),
#   '41': (False, {}),
#   '42': (False, {}),
#   '43': (False, {}),
#   '44': (False, {}),
#   '45': (False, {}),
#   '46': (False, {}),
#   '47': (False, {}),
#   '48': (False, {}),
#   '49': (False, {}),
#   '50': (False, {}),
#   '51': (False, {}),
#   '52': (False, {}),
#   '53': (False, {}),
#   '54': (False, {}),
#   '55': (False, {}),
#   '56': (False, {}),
#   '57': (False, {}),
#   '58': (False, {}),
#   '59': (False, {}),
#   '60': (False, {}),
#   '61': (False, {}),
#   '62': (False, {}),
#   '63': (False, {}),
#   '64': (False, {}),
#   '65': (False, {}),
#   '66': (False, {}),
#   '67': (False, {}),
#   '68': (False, {}),
#   '69': (False, {}),
#   '70': (False, {}),
#   '71': (False, {}),
#   '72': (False, {}),
#   '73': (False, {}),
#   '74': (False, {}),
#   '75': (False, {}),
#   '76': (False, {}),
#   '77': (False, {}),
#   '78': (False, {}),
#   '79': (False, {}),
#   '80': (False, {}),
#   '81': (False, {}),
#   '82': (True, {}),
#   '83': (False, {}),
#   '84': (False, {}),
#   '85': (False, {}),
#   '86': (False, {}),
#   '87': (False, {}),
#   '88': (False, {}),
#   '89': (False, {}),
#   '90': (False, {}),
#   '91': (False, {}),
#   '92': (False, {}),
#   '93': (False, {}),
#   '94': (False, {}),
#   '95': (False, {}),
#   '96': (False, {}),
#   '97': (False, {}),
#   '98': (False, {}),
#   '99': (True, {}),
#   '100': (False, {}),
#   '101': (False, {}),
#   '102': (False, {}),
#   '103': (True, {}),
#   '104': (False, {}),
#   '105': (False, {}),
#   '106': (True, {}),
#   '107': (False, {}),
#   '108': (True, {}),
#   '109': (False, {}),
#   '110': (False, {}),
#   '111': (True, {}),
#   '112': (False, {}),
#   '113': (False, {}),
#   '114': (False, {}),
#   '115': (True, {}),
#   '116': (False, {}),
#   '117': (False, {}),
#   '118': (False, {}),
#   '119': (False, {}),
#   '120': (False, {}),
#   '121': (False, {}),
#   '122': (False, {}),
#   '123': (True, {}),
#   '124': (False, {}),
#   '125': (False, {}),
#   '126': (False, {}),
#   '127': (False, {}),
#   '128': (False, {}),
#   '129': (False, {}),
#   '130': (False, {}),
#   '131': (True, {}),
#   '132': (False, {}),
#   '133': (True, {}),
#   '134': (False, {}),
#   '135': (False, {}),
#   '136': (False, {}),
#   '137': (False, {}),
#   '138': (False, {}),
#   '139': (False, {}),
#   '140': (False, {}),
#   '141': (True, {}),
#   '142': (False, {}),
#   '143': (False, {}),
#   '144': (False, {}),
#   '145': (False, {}),
#   '146': (False, {}),
#   '147': (True, {}),
#   '148': (False, {}),
#   '149': (False, {}),
#   '150': (False, {}),
#   '151': (False, {}),
#   '152': (False, {}),
#   '153': (False, {}),
#   '154': (False, {}),
#   '155': (False, {}),
#   '156': (False, {}),
#   '157': (False, {}),
#   '158': (False, {}),
#   '159': (False, {}),
#   '160': (False, {}),
#   '161': (False, {}),
#   '162': (False, {}),
#   '163': (False, {}),
#   '164': (False, {}),
#   '165': (False, {}),
#   '166': (False, {}),
#   '167': (False, {}),
#   '168': (False, {}),
#   '169': (False, {}),
#   '170': (False, {}),
#   '171': (False, {}),
#   '172': (True, {}),
#   '173': (False, {}),
#   '174': (True, {}),
#   '175': (False, {}),
#   '176': (False, {}),
#   '177': (False, {}),
#   '178': (False, {}),
#   '179': (False, {}),
#   '180': (False, {}),
#   '181': (False, {}),
#   '182': (False, {}),
#   '183': (False, {}),
#   '184': (False, {}),
#   '185': (False, {}),
#   '186': (False, {}),
#   '187': (False, {}),
#   '188': (False, {}),
#   '189': (False, {}),
#   '190': (False, {}),
#   '191': (False, {}),
#   '192': (False, {}),
#   '193': (False, {}),
#   '194': (False, {}),
#   '195': (False, {}),
#   '196': (False, {}),
#   '197': (False, {}),
#   '200': (False, {}),
#   '201': (False, {}),
#   '202': (False, {}),
#   '203': (False, {}),
#   '204': (False, {}),
#   '205': (False, {}),
#   '206': (False, {}),
#   '207': (False, {}),
#   '208': (False, {}),
#   '209': (False, {}),
#   '210': (False, {})}}

# %%
# save these results for later analysis as a JSON file
with open('data/r3d_compact_task_results_ccle_bc_new_nodrains_only_feas.json', 'w') as f:
    f.write(JSONEncoder().encode([(k, v) for k, v in task_eval_results.items()]))
